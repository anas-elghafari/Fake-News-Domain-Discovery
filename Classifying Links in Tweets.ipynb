# %%
import sklearn
import pickle
from collections import defaultdict
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
import random, string, itertools
import numpy as np

# %%
#reading in the fake news tweets
fn_tweets = pickle.load(open("fn_seen.p", "rb"))
len(fn_tweets)
# Out:
# 20600

# %%
#reading in the MSM tweets:
msm_tweets = pickle.load(open('msm_seen.p',"rb"))
print(len(msm_tweets))
msm_tweets_sample = random.choices(population= list(msm_tweets.values()), k=50000)
print(len(msm_tweets_sample))
# Out:
# 446100
# 50000

# %%
def process(tweet, operations, cgrams, wgrams):
    r = tweet
    grams = []
    
    if 'cap' in operations:
        r = tweet.lower()
        
    if 'spaces' in operations:
        r = r.split()
        r = " ".join([w.strip() for w in r])
        
    if 'rt' in operations:
        r = r.split()
        r = " ".join([w for w in r if not w.lower() == "rt"])
    
    if 'mentions' in operations:
        r = r.split()
        r = " ".join([w for w in r if not w.startswith("@")])
        
    if 'urls' in operations:
        r = r.split()
        r = " ".join([w for w in r if not w.startswith("http")])
        
    if 'poses' in operations:
        r = r.replace("'s", "") #removes posessives
        
    if 'punct' in operations:
        r = "".join([c for c in r if not c in string.punctuation])
        
    if 'boundries' in operations:
        r = "< " + r + " >"
        
    if 'char-grams' in operations:
        for leng in cgrams:
            grams.extend([r[i:i+leng] for i in range(len(r)-leng+1)])
            
    if 'word-grams' in operations:
        r = r.split()
        for leng in wgrams:
            lgrams = [r[i:i+leng] for i in range(len(r)-leng+1)]
            grams.extend([" ".join(g) for g in lgrams])
    
    if grams== []:
        return r
    else:
        return grams

# %%
alltweets = [x for x in itertools.chain(fn_tweets.values(), msm_tweets_sample)]
print("number of all tweets: ", len(alltweets))
# Out:
# number of all tweets:  70600

# %%
alllinks = [y for x in itertools.chain(fn_tweets.values(), msm_tweets.values()) for y in x[5]]
print("number of all links: ", len(alllinks))
# Out:
# number of all links:  489259

# %%
from re import sub, MULTILINE
def remove_url_corpus(text):
    new_text = sub(r'(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’]))', '', text, flags=MULTILINE)
    return new_text

# %%
#testing URL removal
for t in alltweets[0:200]: 
    l = t[5][0]
    print("tweet before removing url:")
    print(t[4])
    print("\ntweet after removing url:")
    t_after = remove_url_corpus(t[4]) 
    print(t_after)
    print(len(t[4]), len(t_after))
    assert len(t[4]) != len(t_after)
    print("*"*50)

# %%
operations = ['punct', 'spaces', 'mentions', 'urls', 'char-grams', 'boundries',  'word-grams']
process(alltweets[16][4], operations, [1], [2,3])
# Out:
# ['<',
#  ' ',
#  '🎥',
#  ' ',
#  'G',
#  'o',
#  't',
#  't',
#  'a',
#  ' ',
#  'G',
#  'i',
#  'v',
#  'e',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  ' ',
#  'w',
#  'o',
#  'r',
#  'l',
#  'd',
#  ' ',
#  'b',
#  'a',
#  'c',
#  'k',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'G',
#  'o',
#  'd',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'A',
#  'b',
#  'r',
#  'a',
#  'h',
#  'a',
#  'm',
#  ' ',
#  'I',
#  's',
#  'a',
#  'a',
#  'c',
#  ' ',
#  'a',
#  'm',
#  'p',
#  ' ',
#  'J',
#  'a',
#  'c',
#  'o',
#  'b',
#  ' ',
#  '✝',
#  '🙏',
#  '✡',
#  '️',
#  ' ',
#  '>',
#  '< 🎥',
#  '🎥 Gotta',
#  'Gotta Give',
#  'Give this',
#  'this world',
#  'world back',
#  'back to',
#  'to God',
#  'God of',
#  'of Abraham',
#  'Abraham Isaac',
#  'Isaac amp',
#  'amp Jacob',
#  'Jacob ✝🙏✡️',
#  '✝🙏✡️ >',
#  '< 🎥 Gotta',
#  '🎥 Gotta Give',
#  'Gotta Give this',
#  'Give this world',
#  'this world back',
#  'world back to',
#  'back to God',
#  'to God of',
#  'God of Abraham',
#  'of Abraham Isaac',
#  'Abraham Isaac amp',
#  'Isaac amp Jacob',
#  'amp Jacob ✝🙏✡️',
#  'Jacob ✝🙏✡️ >']

# %%
# %%time
vecs_to_ids = dict()
operations = ['spaces', 'mentions', 'urls', 'punct', 'poses', 'rt', 'word-grams']
for t in fn_tweets.values():
    v = process(t[4], operations, [], [2,3])
    vecs_to_ids[tuple(v)] = ('fake', t[3])
    
for t in msm_tweets_sample:
    v = process(t[4], operations, [], [2,3])
    vecs_to_ids[tuple(v)] = ('msm', t[3])
# Out:
# Wall time: 19 s

# %%
# %%time
#constructing vectors of words only
grams1_to_ids = dict()
operations = ['punct', 'poses', 'spaces', 'mentions', 'urls', 'word-grams']
for t in fn_tweets.values():
    v = process(t[4], operations, [], [1])
    grams1_to_ids[tuple(v)] = ('fake', t[3])
    
for t in msm_tweets_sample:
    v = process(t[4], operations, [], [1])
    grams1_to_ids[tuple(v)] = ('msm', t[3])
# Out:
# Wall time: 14 s

# %%
print(len(alltweets))
print(len(vecs_to_ids))
print("count of fake news tweets after removing duplicates: ", len([x for x in vecs_to_ids.values() if x[0] == 'fake']))
print("count of msm tweets after removing duplicates: ", len([x for x in vecs_to_ids.values() if x[0] == 'msm']))
# Out:
# 70600
# 47116
# count of fake news tweets after removing duplicates:  10431
# count of msm tweets after removing duplicates:  36685

# %%
def select_dimensions(instances, max_cutoff_ratio, min_cutoff_ratio):
    features = defaultdict(lambda: 0)
    for current_instance in instances:
        for d in set(current_instance):
            features[d] +=1
            
    max_cutoff = len(instances)*max_cutoff_ratio
    min_cutoff = len(instances)*min_cutoff_ratio
    print("\n\nNumber of instances: ", len(instances))
    print("Total number of possible features: ", len(features))
    print("All features occuring in", max_cutoff, "instances or more, and all features occuring in", min_cutoff, 
          "instances or fewer, will be dropped")
    features_above_cutoff = [f for f in features if features[f]>max_cutoff]
    features_below_cutoff =  [f for f in features if features[f]<min_cutoff]
    selected_features = sorted([f for f in features if features[f]>=min_cutoff and features[f]<= max_cutoff])
    print("\nfeatures above cutoff:\n", len(features_above_cutoff))
    print("Examples: 20 features that were above the cutoff:\n", features_above_cutoff[:20])
    print("\nfeatures below cutoff:\n",  len(features_below_cutoff))
    print("Examples: 20 features that were below the cutoff:\n", features_below_cutoff[:20], "\n\n")
    print("\nNumber of remaining features: ", len(selected_features), "\n\n")
    print("Examples: 20 features remaining:\n", selected_features[:20], "\n\n")
    return selected_features


def insts_to_vecs(insts, dimensions):
    vecs = np.zeros(shape = [len(insts), len(dimensions)], dtype='uint')
    for i, (inst, words) in enumerate(insts):
        t_start = time.time()
        print("building vector for instance:", inst)
        words_dict = {w[0]:w[1] for w in words}
        vec = np.array([0 if not d in words_dict else words_dict[d] for d in dimensions])
        vecs[i] = (vec)
        t = time.time()- t_start
        print("finished in ", t, "\n")
    return vecs

# %%
# %%time
vecs = []
labels = []
ids = []

for v, l in vecs_to_ids.items():
    vecs.append(v)
    labels.append(l[0])
    ids.append(l[1])
    
sg = select_dimensions(vecs, 1, 0)
print("\n\nnumber of dimensions: ", len(sg))
# Out:
# Number of instances:  46278
# Total number of possible features:  829458
# All features occuring in 46278 instances or more, and all features occuring in 0 instances or fewer, will be dropped
#
# features above cutoff:
#  0
# Examples: 20 features that were above the cutoff:
#  []
#
# features below cutoff:
#  0
# Examples: 20 features that were below the cutoff:
#  []
#
#
#
# Number of remaining features:  829458
#
#
# Examples: 20 features remaining:
#  ['0', '0 0', '0 0 trading', '0 0Apple', '0 0Apple confirms', '0 Story', '0 Story w', '0 These', '0 These kids', '0 about', '0 about legal', '0 coverage', '0 coverage And', '0 data', '0 data Net', '0 dead', '0 trading', '0 trading PG', '000 Venezuela', '000 dollars']
#
#
#
#
# number of dimensions:  829458
# Wall time: 3.55 s

# %%
# %%time
vecs = []
labels = []
ids = []

for v, l in grams1_to_ids.items():
    vecs.append(v)
    labels.append(l[0])
    ids.append(l[1])
    
grams1 = select_dimensions(vecs, 0.9, 0.0005)
print("\n\nnumber of dimensions: ", len(grams1))
# Out:
# Number of instances:  46305
# Total number of possible features:  71597
# All features occuring in 41674.5 instances or more, and all features occuring in 23.1525 instances or fewer, will be dropped
#
# features above cutoff:
#  0
# Examples: 20 features that were above the cutoff:
#  []
#
# features below cutoff:
#  67665
# Examples: 20 features that were below the cutoff:
#  ['cocaine', 'amppowerbut', 'Snopes', 'FBIDOJ', 'newsso', 'smuggling', 'tremendous', 'daughters', 'therefore', 'McGraw', 'anti2A', 'husband', 'Socialism', 'Patriot', 'Gary', 'Sinise', 'Highest', 'Civilians', 'Proud', 'Honor']
#
#
#
# Number of remaining features:  3932
#
#
# Examples: 20 features remaining:
#  ['1', '10', '100', '1000', '10000', '100000', '11', '12', '13', '14', '15', '16', '17', '18', '19', '1st', '2', '20', '200', '2013']
#
#
#
#
# number of dimensions:  3932
# Wall time: 506 ms

# %%
def mutual_information(vecs, grams, labels):
    labels_count = {l:0 for l in labels}
    grams_count = {g:{l:0 for l in labels} for g in grams}
    #print(labels_count)
    #print(grams_count)
    for k, v in vecs.items():
        #print("key: ",k)
        #print("val: ", v)
        vset = set(k)
        label= v[0]
        #print("label: ", label)
        for gram in k:
            if not k in grams_count:
                continue
            grams_count[gram][label] +=1
        labels_count[label] +=1
    
    print("labels count: ", labels_count)
    labels_prop = {l:(labels_count[l]/len(vecs)) for l in labels}
    print("labels_prop: ", labels_prop)
    mi = dict()
    for g, gcounts in grams_count.items():
        gcountsum = sum([x for x in gcounts.values()])
        if gcountsum == 0:
            gcountsum = 1
        #print("gcountsum: ", gcountsum)
        gprops = {l:((gcounts[l]/gcountsum) / labels_prop[l]) for l in labels}
        #print("ggroups: ", gprops)
        mi[g] = gprops
        
    return grams_count, mi

# %%
gc, mi= mutual_information(vecs_to_ids, sg, ['msm', 'fake'])
# Out:
# labels count:  {'msm': 36042, 'fake': 10236}
# labels_prop:  {'msm': 0.7788149876831324, 'fake': 0.22118501231686763}

# %%
gc1, mi1 = mutual_information(grams1_to_ids, grams1, ['msm', 'fake'])
# Out:
# labels count:  {'msm': 36066, 'fake': 10239}
# labels_prop:  {'msm': 0.7788791707159054, 'fake': 0.2211208292840946}

# %%
mi1_top_fake = sorted([x for x in mi1.items()], key=lambda x: x[1]['fake'], reverse=True)
mi1_top_msm = sorted([x for x in mi1.items()], key=lambda x: x[1]['msm'], reverse=True)

# %%
print("\n\n".join([str(x) for x in mi1_top_fake[0:1000]]))
# Out:
# ('1', {'msm': 0.0, 'fake': 0.0})
#
# ('10', {'msm': 0.0, 'fake': 0.0})
#
# ('100', {'msm': 0.0, 'fake': 0.0})
#
# ('1000', {'msm': 0.0, 'fake': 0.0})
#
# ('10000', {'msm': 0.0, 'fake': 0.0})
#
# ('100000', {'msm': 0.0, 'fake': 0.0})
#
# ('11', {'msm': 0.0, 'fake': 0.0})
#
# ('12', {'msm': 0.0, 'fake': 0.0})
#
# ('13', {'msm': 0.0, 'fake': 0.0})
#
# ('14', {'msm': 0.0, 'fake': 0.0})
#
# ('15', {'msm': 0.0, 'fake': 0.0})
#
# ('16', {'msm': 0.0, 'fake': 0.0})
#
# ('17', {'msm': 0.0, 'fake': 0.0})
#
# ('18', {'msm': 0.0, 'fake': 0.0})
#
# ('19', {'msm': 0.0, 'fake': 0.0})
#
# ('1st', {'msm': 0.0, 'fake': 0.0})
#
# ('2', {'msm': 0.0, 'fake': 0.0})
#
# ('20', {'msm': 0.0, 'fake': 0.0})
#
# ('200', {'msm': 0.0, 'fake': 0.0})
#
# ('2013', {'msm': 0.0, 'fake': 0.0})
#
# ('2014', {'msm': 0.0, 'fake': 0.0})
#
# ('2015', {'msm': 0.0, 'fake': 0.0})
#
# ('2016', {'msm': 0.0, 'fake': 0.0})
#
# ('2017', {'msm': 0.0, 'fake': 0.0})
#
# ('2018', {'msm': 0.0, 'fake': 0.0})
#
# ('2019', {'msm': 0.0, 'fake': 0.0})
#
# ('2020', {'msm': 0.0, 'fake': 0.0})
#
# ('21', {'msm': 0.0, 'fake': 0.0})
#
# ('22', {'msm': 0.0, 'fake': 0.0})
#
# ('23', {'msm': 0.0, 'fake': 0.0})
#
# ('24', {'msm': 0.0, 'fake': 0.0})
#
# ('25', {'msm': 0.0, 'fake': 0.0})
#
# ('26', {'msm': 0.0, 'fake': 0.0})
#
# ('28', {'msm': 0.0, 'fake': 0.0})
#
# ('29', {'msm': 0.0, 'fake': 0.0})
#
# ('2A', {'msm': 0.0, 'fake': 0.0})
#
# ('2nd', {'msm': 0.0, 'fake': 0.0})
#
# ('3', {'msm': 0.0, 'fake': 0.0})
#
# ('30', {'msm': 0.0, 'fake': 0.0})
#
# ('300', {'msm': 0.0, 'fake': 0.0})
#
# ('30day', {'msm': 0.0, 'fake': 0.0})
#
# ('35', {'msm': 0.0, 'fake': 0.0})
#
# ('3YrOld', {'msm': 0.0, 'fake': 0.0})
#
# ('3rd', {'msm': 0.0, 'fake': 0.0})
#
# ('4', {'msm': 0.0, 'fake': 0.0})
#
# ('40', {'msm': 0.0, 'fake': 0.0})
#
# ('400', {'msm': 0.0, 'fake': 0.0})
#
# ('43', {'msm': 0.0, 'fake': 0.0})
#
# ('44', {'msm': 0.0, 'fake': 0.0})
#
# ('45', {'msm': 0.0, 'fake': 0.0})
#
# ('4th', {'msm': 0.0, 'fake': 0.0})
#
# ('5', {'msm': 0.0, 'fake': 0.0})
#
# ('50', {'msm': 0.0, 'fake': 0.0})
#
# ('500', {'msm': 0.0, 'fake': 0.0})
#
# ('53', {'msm': 0.0, 'fake': 0.0})
#
# ('54', {'msm': 0.0, 'fake': 0.0})
#
# ('5G', {'msm': 0.0, 'fake': 0.0})
#
# ('6', {'msm': 0.0, 'fake': 0.0})
#
# ('60', {'msm': 0.0, 'fake': 0.0})
#
# ('65', {'msm': 0.0, 'fake': 0.0})
#
# ('7', {'msm': 0.0, 'fake': 0.0})
#
# ('70', {'msm': 0.0, 'fake': 0.0})
#
# ('700', {'msm': 0.0, 'fake': 0.0})
#
# ('71', {'msm': 0.0, 'fake': 0.0})
#
# ('75', {'msm': 0.0, 'fake': 0.0})
#
# ('76', {'msm': 0.0, 'fake': 0.0})
#
# ('7News', {'msm': 0.0, 'fake': 0.0})
#
# ('8', {'msm': 0.0, 'fake': 0.0})
#
# ('80', {'msm': 0.0, 'fake': 0.0})
#
# ('9', {'msm': 0.0, 'fake': 0.0})
#
# ('90', {'msm': 0.0, 'fake': 0.0})
#
# ('911', {'msm': 0.0, 'fake': 0.0})
#
# ('97', {'msm': 0.0, 'fake': 0.0})
#
# ('A', {'msm': 0.0, 'fake': 0.0})
#
# ('AAG', {'msm': 0.0, 'fake': 0.0})
#
# ('ABC', {'msm': 0.0, 'fake': 0.0})
#
# ('ABOUT', {'msm': 0.0, 'fake': 0.0})
#
# ('AG', {'msm': 0.0, 'fake': 0.0})
#
# ('AI', {'msm': 0.0, 'fake': 0.0})
#
# ('ALL', {'msm': 0.0, 'fake': 0.0})
#
# ('AMERICA', {'msm': 0.0, 'fake': 0.0})
#
# ('AMP', {'msm': 0.0, 'fake': 0.0})
#
# ('AND', {'msm': 0.0, 'fake': 0.0})
#
# ('AP', {'msm': 0.0, 'fake': 0.0})
#
# ('AR', {'msm': 0.0, 'fake': 0.0})
#
# ('AR15', {'msm': 0.0, 'fake': 0.0})
#
# ('ARE', {'msm': 0.0, 'fake': 0.0})
#
# ('ASSOCIATED', {'msm': 0.0, 'fake': 0.0})
#
# ('AT', {'msm': 0.0, 'fake': 0.0})
#
# ('AWAKE', {'msm': 0.0, 'fake': 0.0})
#
# ('About', {'msm': 0.0, 'fake': 0.0})
#
# ('Abuse', {'msm': 0.0, 'fake': 0.0})
#
# ('According', {'msm': 0.0, 'fake': 0.0})
#
# ('Accused', {'msm': 0.0, 'fake': 0.0})
#
# ('Across', {'msm': 0.0, 'fake': 0.0})
#
# ('Act', {'msm': 0.0, 'fake': 0.0})
#
# ('Action', {'msm': 0.0, 'fake': 0.0})
#
# ('Actions', {'msm': 0.0, 'fake': 0.0})
#
# ('Actor', {'msm': 0.0, 'fake': 0.0})
#
# ('Actress', {'msm': 0.0, 'fake': 0.0})
#
# ('Actually', {'msm': 0.0, 'fake': 0.0})
#
# ('Adam', {'msm': 0.0, 'fake': 0.0})
#
# ('Add', {'msm': 0.0, 'fake': 0.0})
#
# ('Administration', {'msm': 0.0, 'fake': 0.0})
#
# ('Admits', {'msm': 0.0, 'fake': 0.0})
#
# ('Afghanistan', {'msm': 0.0, 'fake': 0.0})
#
# ('Africa', {'msm': 0.0, 'fake': 0.0})
#
# ('African', {'msm': 0.0, 'fake': 0.0})
#
# ('After', {'msm': 0.0, 'fake': 0.0})
#
# ('Again', {'msm': 0.0, 'fake': 0.0})
#
# ('Against', {'msm': 0.0, 'fake': 0.0})
#
# ('Age', {'msm': 0.0, 'fake': 0.0})
#
# ('Agency', {'msm': 0.0, 'fake': 0.0})
#
# ('Agent', {'msm': 0.0, 'fake': 0.0})
#
# ('Agreement', {'msm': 0.0, 'fake': 0.0})
#
# ('Agrees', {'msm': 0.0, 'fake': 0.0})
#
# ('Aide', {'msm': 0.0, 'fake': 0.0})
#
# ('Air', {'msm': 0.0, 'fake': 0.0})
#
# ('Airbnb', {'msm': 0.0, 'fake': 0.0})
#
# ('Airlines', {'msm': 0.0, 'fake': 0.0})
#
# ('Alien', {'msm': 0.0, 'fake': 0.0})
#
# ('Aliens', {'msm': 0.0, 'fake': 0.0})
#
# ('All', {'msm': 0.0, 'fake': 0.0})
#
# ('Alleged', {'msm': 0.0, 'fake': 0.0})
#
# ('Also', {'msm': 0.0, 'fake': 0.0})
#
# ('Alternative', {'msm': 0.0, 'fake': 0.0})
#
# ('Always', {'msm': 0.0, 'fake': 0.0})
#
# ('Amazing', {'msm': 0.0, 'fake': 0.0})
#
# ('Amazon', {'msm': 0.0, 'fake': 0.0})
#
# ('Amendment', {'msm': 0.0, 'fake': 0.0})
#
# ('America', {'msm': 0.0, 'fake': 0.0})
#
# ('American', {'msm': 0.0, 'fake': 0.0})
#
# ('Americans', {'msm': 0.0, 'fake': 0.0})
#
# ('America’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Amid', {'msm': 0.0, 'fake': 0.0})
#
# ('An', {'msm': 0.0, 'fake': 0.0})
#
# ('Analysis', {'msm': 0.0, 'fake': 0.0})
#
# ('Anbang', {'msm': 0.0, 'fake': 0.0})
#
# ('Ancient', {'msm': 0.0, 'fake': 0.0})
#
# ('And', {'msm': 0.0, 'fake': 0.0})
#
# ('Andrew', {'msm': 0.0, 'fake': 0.0})
#
# ('Android', {'msm': 0.0, 'fake': 0.0})
#
# ('Angeles', {'msm': 0.0, 'fake': 0.0})
#
# ('Announces', {'msm': 0.0, 'fake': 0.0})
#
# ('Annual', {'msm': 0.0, 'fake': 0.0})
#
# ('Anon', {'msm': 0.0, 'fake': 0.0})
#
# ('Another', {'msm': 0.0, 'fake': 0.0})
#
# ('Antarctica', {'msm': 0.0, 'fake': 0.0})
#
# ('Any', {'msm': 0.0, 'fake': 0.0})
#
# ('Anyone', {'msm': 0.0, 'fake': 0.0})
#
# ('App', {'msm': 0.0, 'fake': 0.0})
#
# ('Apple', {'msm': 0.0, 'fake': 0.0})
#
# ('April', {'msm': 0.0, 'fake': 0.0})
#
# ('Arabia', {'msm': 0.0, 'fake': 0.0})
#
# ('Archaeologists', {'msm': 0.0, 'fake': 0.0})
#
# ('Archbishop', {'msm': 0.0, 'fake': 0.0})
#
# ('Arctic', {'msm': 0.0, 'fake': 0.0})
#
# ('Are', {'msm': 0.0, 'fake': 0.0})
#
# ('Area', {'msm': 0.0, 'fake': 0.0})
#
# ('Arizona', {'msm': 0.0, 'fake': 0.0})
#
# ('Arm', {'msm': 0.0, 'fake': 0.0})
#
# ('Armed', {'msm': 0.0, 'fake': 0.0})
#
# ('Arming', {'msm': 0.0, 'fake': 0.0})
#
# ('Army', {'msm': 0.0, 'fake': 0.0})
#
# ('Around', {'msm': 0.0, 'fake': 0.0})
#
# ('Arrest', {'msm': 0.0, 'fake': 0.0})
#
# ('Arrested', {'msm': 0.0, 'fake': 0.0})
#
# ('Art', {'msm': 0.0, 'fake': 0.0})
#
# ('Article', {'msm': 0.0, 'fake': 0.0})
#
# ('Artificial', {'msm': 0.0, 'fake': 0.0})
#
# ('ArtificialIntelligence', {'msm': 0.0, 'fake': 0.0})
#
# ('As', {'msm': 0.0, 'fake': 0.0})
#
# ('Asia', {'msm': 0.0, 'fake': 0.0})
#
# ('Asian', {'msm': 0.0, 'fake': 0.0})
#
# ('Ask', {'msm': 0.0, 'fake': 0.0})
#
# ('Asked', {'msm': 0.0, 'fake': 0.0})
#
# ('Assad', {'msm': 0.0, 'fake': 0.0})
#
# ('Assange', {'msm': 0.0, 'fake': 0.0})
#
# ('Assault', {'msm': 0.0, 'fake': 0.0})
#
# ('Association', {'msm': 0.0, 'fake': 0.0})
#
# ('At', {'msm': 0.0, 'fake': 0.0})
#
# ('Athletes', {'msm': 0.0, 'fake': 0.0})
#
# ('Atlanta', {'msm': 0.0, 'fake': 0.0})
#
# ('Atlantic', {'msm': 0.0, 'fake': 0.0})
#
# ('Attack', {'msm': 0.0, 'fake': 0.0})
#
# ('Attacks', {'msm': 0.0, 'fake': 0.0})
#
# ('Attorney', {'msm': 0.0, 'fake': 0.0})
#
# ('Australia', {'msm': 0.0, 'fake': 0.0})
#
# ('Australian', {'msm': 0.0, 'fake': 0.0})
#
# ('Author', {'msm': 0.0, 'fake': 0.0})
#
# ('Auto', {'msm': 0.0, 'fake': 0.0})
#
# ('Avoid', {'msm': 0.0, 'fake': 0.0})
#
# ('Awards', {'msm': 0.0, 'fake': 0.0})
#
# ('Away', {'msm': 0.0, 'fake': 0.0})
#
# ('BB4SP', {'msm': 0.0, 'fake': 0.0})
#
# ('BE', {'msm': 0.0, 'fake': 0.0})
#
# ('BIG', {'msm': 0.0, 'fake': 0.0})
#
# ('BREAKING', {'msm': 0.0, 'fake': 0.0})
#
# ('BS', {'msm': 0.0, 'fake': 0.0})
#
# ('BUSTED', {'msm': 0.0, 'fake': 0.0})
#
# ('Baby', {'msm': 0.0, 'fake': 0.0})
#
# ('Back', {'msm': 0.0, 'fake': 0.0})
#
# ('Bad', {'msm': 0.0, 'fake': 0.0})
#
# ('Ban', {'msm': 0.0, 'fake': 0.0})
#
# ('BanAssaultWeapons', {'msm': 0.0, 'fake': 0.0})
#
# ('Bank', {'msm': 0.0, 'fake': 0.0})
#
# ('Bankruptcy', {'msm': 0.0, 'fake': 0.0})
#
# ('Banks', {'msm': 0.0, 'fake': 0.0})
#
# ('Bans', {'msm': 0.0, 'fake': 0.0})
#
# ('Barack', {'msm': 0.0, 'fake': 0.0})
#
# ('Bay', {'msm': 0.0, 'fake': 0.0})
#
# ('Be', {'msm': 0.0, 'fake': 0.0})
#
# ('Bear', {'msm': 0.0, 'fake': 0.0})
#
# ('Beast', {'msm': 0.0, 'fake': 0.0})
#
# ('Beat', {'msm': 0.0, 'fake': 0.0})
#
# ('Because', {'msm': 0.0, 'fake': 0.0})
#
# ('Become', {'msm': 0.0, 'fake': 0.0})
#
# ('Becoming', {'msm': 0.0, 'fake': 0.0})
#
# ('Been', {'msm': 0.0, 'fake': 0.0})
#
# ('Before', {'msm': 0.0, 'fake': 0.0})
#
# ('Behind', {'msm': 0.0, 'fake': 0.0})
#
# ('Beijing', {'msm': 0.0, 'fake': 0.0})
#
# ('Being', {'msm': 0.0, 'fake': 0.0})
#
# ('Believe', {'msm': 0.0, 'fake': 0.0})
#
# ('Benedict', {'msm': 0.0, 'fake': 0.0})
#
# ('Berkshire', {'msm': 0.0, 'fake': 0.0})
#
# ('Berlin', {'msm': 0.0, 'fake': 0.0})
#
# ('Bernie', {'msm': 0.0, 'fake': 0.0})
#
# ('Best', {'msm': 0.0, 'fake': 0.0})
#
# ('Better', {'msm': 0.0, 'fake': 0.0})
#
# ('Between', {'msm': 0.0, 'fake': 0.0})
#
# ('Beyond', {'msm': 0.0, 'fake': 0.0})
#
# ('Bible', {'msm': 0.0, 'fake': 0.0})
#
# ('Bid', {'msm': 0.0, 'fake': 0.0})
#
# ('Big', {'msm': 0.0, 'fake': 0.0})
#
# ('BigData', {'msm': 0.0, 'fake': 0.0})
#
# ('Biggest', {'msm': 0.0, 'fake': 0.0})
#
# ('Bill', {'msm': 0.0, 'fake': 0.0})
#
# ('Billion', {'msm': 0.0, 'fake': 0.0})
#
# ('Billionaire', {'msm': 0.0, 'fake': 0.0})
#
# ('Billy', {'msm': 0.0, 'fake': 0.0})
#
# ('Bitcoin', {'msm': 0.0, 'fake': 0.0})
#
# ('Black', {'msm': 0.0, 'fake': 0.0})
#
# ('BlackPanther', {'msm': 0.0, 'fake': 0.0})
#
# ('Blockchain', {'msm': 0.0, 'fake': 0.0})
#
# ('Bloomberg', {'msm': 0.0, 'fake': 0.0})
#
# ('Blows', {'msm': 0.0, 'fake': 0.0})
#
# ('Blue', {'msm': 0.0, 'fake': 0.0})
#
# ('Board', {'msm': 0.0, 'fake': 0.0})
#
# ('Body', {'msm': 0.0, 'fake': 0.0})
#
# ('Boko', {'msm': 0.0, 'fake': 0.0})
#
# ('Bollywood', {'msm': 0.0, 'fake': 0.0})
#
# ('Bomb', {'msm': 0.0, 'fake': 0.0})
#
# ('Bombshell', {'msm': 0.0, 'fake': 0.0})
#
# ('Book', {'msm': 0.0, 'fake': 0.0})
#
# ('Books', {'msm': 0.0, 'fake': 0.0})
#
# ('Border', {'msm': 0.0, 'fake': 0.0})
#
# ('Boss', {'msm': 0.0, 'fake': 0.0})
#
# ('Boston', {'msm': 0.0, 'fake': 0.0})
#
# ('Both', {'msm': 0.0, 'fake': 0.0})
#
# ('Box', {'msm': 0.0, 'fake': 0.0})
#
# ('Boy', {'msm': 0.0, 'fake': 0.0})
#
# ('Boycott', {'msm': 0.0, 'fake': 0.0})
#
# ('BoycottNRA', {'msm': 0.0, 'fake': 0.0})
#
# ('Boys', {'msm': 0.0, 'fake': 0.0})
#
# ('Brain', {'msm': 0.0, 'fake': 0.0})
#
# ('Brand', {'msm': 0.0, 'fake': 0.0})
#
# ('Brazil', {'msm': 0.0, 'fake': 0.0})
#
# ('Break', {'msm': 0.0, 'fake': 0.0})
#
# ('Breaking', {'msm': 0.0, 'fake': 0.0})
#
# ('Breaks', {'msm': 0.0, 'fake': 0.0})
#
# ('Brexit', {'msm': 0.0, 'fake': 0.0})
#
# ('Briefing', {'msm': 0.0, 'fake': 0.0})
#
# ('Bring', {'msm': 0.0, 'fake': 0.0})
#
# ('Britain', {'msm': 0.0, 'fake': 0.0})
#
# ('British', {'msm': 0.0, 'fake': 0.0})
#
# ('Broadcom', {'msm': 0.0, 'fake': 0.0})
#
# ('Broward', {'msm': 0.0, 'fake': 0.0})
#
# ('Brown', {'msm': 0.0, 'fake': 0.0})
#
# ('Brutal', {'msm': 0.0, 'fake': 0.0})
#
# ('Buffett', {'msm': 0.0, 'fake': 0.0})
#
# ('Building', {'msm': 0.0, 'fake': 0.0})
#
# ('Bush', {'msm': 0.0, 'fake': 0.0})
#
# ('Business', {'msm': 0.0, 'fake': 0.0})
#
# ('Busted', {'msm': 0.0, 'fake': 0.0})
#
# ('But', {'msm': 0.0, 'fake': 0.0})
#
# ('Buy', {'msm': 0.0, 'fake': 0.0})
#
# ('By', {'msm': 0.0, 'fake': 0.0})
#
# ('C', {'msm': 0.0, 'fake': 0.0})
#
# ('CA', {'msm': 0.0, 'fake': 0.0})
#
# ('CBS', {'msm': 0.0, 'fake': 0.0})
#
# ('CDC', {'msm': 0.0, 'fake': 0.0})
#
# ('CEO', {'msm': 0.0, 'fake': 0.0})
#
# ('CEOs', {'msm': 0.0, 'fake': 0.0})
#
# ('CFO', {'msm': 0.0, 'fake': 0.0})
#
# ('CIA', {'msm': 0.0, 'fake': 0.0})
#
# ('CNBC', {'msm': 0.0, 'fake': 0.0})
#
# ('CNN', {'msm': 0.0, 'fake': 0.0})
#
# ('CNNMoney', {'msm': 0.0, 'fake': 0.0})
#
# ('CNNPolitics', {'msm': 0.0, 'fake': 0.0})
#
# ('CPAC', {'msm': 0.0, 'fake': 0.0})
#
# ('CPAC2018', {'msm': 0.0, 'fake': 0.0})
#
# ('California', {'msm': 0.0, 'fake': 0.0})
#
# ('Call', {'msm': 0.0, 'fake': 0.0})
#
# ('Called', {'msm': 0.0, 'fake': 0.0})
#
# ('Calls', {'msm': 0.0, 'fake': 0.0})
#
# ('Camera', {'msm': 0.0, 'fake': 0.0})
#
# ('Camp', {'msm': 0.0, 'fake': 0.0})
#
# ('Campaign', {'msm': 0.0, 'fake': 0.0})
#
# ('Can', {'msm': 0.0, 'fake': 0.0})
#
# ('Canada', {'msm': 0.0, 'fake': 0.0})
#
# ('Canadian', {'msm': 0.0, 'fake': 0.0})
#
# ('Cancer', {'msm': 0.0, 'fake': 0.0})
#
# ('Cannabis', {'msm': 0.0, 'fake': 0.0})
#
# ('Cant', {'msm': 0.0, 'fake': 0.0})
#
# ('Can’t', {'msm': 0.0, 'fake': 0.0})
#
# ('Capital', {'msm': 0.0, 'fake': 0.0})
#
# ('Capitol', {'msm': 0.0, 'fake': 0.0})
#
# ('Car', {'msm': 0.0, 'fake': 0.0})
#
# ('Care', {'msm': 0.0, 'fake': 0.0})
#
# ('Career', {'msm': 0.0, 'fake': 0.0})
#
# ('Carolina', {'msm': 0.0, 'fake': 0.0})
#
# ('Carter', {'msm': 0.0, 'fake': 0.0})
#
# ('Case', {'msm': 0.0, 'fake': 0.0})
#
# ('Castro', {'msm': 0.0, 'fake': 0.0})
#
# ('Castro’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Catholic', {'msm': 0.0, 'fake': 0.0})
#
# ('Caught', {'msm': 0.0, 'fake': 0.0})
#
# ('Caused', {'msm': 0.0, 'fake': 0.0})
#
# ('Celebrity', {'msm': 0.0, 'fake': 0.0})
#
# ('Center', {'msm': 0.0, 'fake': 0.0})
#
# ('Central', {'msm': 0.0, 'fake': 0.0})
#
# ('Ceremony', {'msm': 0.0, 'fake': 0.0})
#
# ('Chairman', {'msm': 0.0, 'fake': 0.0})
#
# ('Chambers', {'msm': 0.0, 'fake': 0.0})
#
# ('Change', {'msm': 0.0, 'fake': 0.0})
#
# ('Changed', {'msm': 0.0, 'fake': 0.0})
#
# ('Changes', {'msm': 0.0, 'fake': 0.0})
#
# ('Channel', {'msm': 0.0, 'fake': 0.0})
#
# ('Charges', {'msm': 0.0, 'fake': 0.0})
#
# ('Check', {'msm': 0.0, 'fake': 0.0})
#
# ('Chicago', {'msm': 0.0, 'fake': 0.0})
#
# ('Chief', {'msm': 0.0, 'fake': 0.0})
#
# ('Child', {'msm': 0.0, 'fake': 0.0})
#
# ('Children', {'msm': 0.0, 'fake': 0.0})
#
# ('China', {'msm': 0.0, 'fake': 0.0})
#
# ('China’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Chinese', {'msm': 0.0, 'fake': 0.0})
#
# ('Chris', {'msm': 0.0, 'fake': 0.0})
#
# ('Christian', {'msm': 0.0, 'fake': 0.0})
#
# ('Christians', {'msm': 0.0, 'fake': 0.0})
#
# ('Chubb', {'msm': 0.0, 'fake': 0.0})
#
# ('Church', {'msm': 0.0, 'fake': 0.0})
#
# ('Circle', {'msm': 0.0, 'fake': 0.0})
#
# ('City', {'msm': 0.0, 'fake': 0.0})
#
# ('Civil', {'msm': 0.0, 'fake': 0.0})
#
# ('Claim', {'msm': 0.0, 'fake': 0.0})
#
# ('Claimed', {'msm': 0.0, 'fake': 0.0})
#
# ('Claiming', {'msm': 0.0, 'fake': 0.0})
#
# ('Claims', {'msm': 0.0, 'fake': 0.0})
#
# ('Classic', {'msm': 0.0, 'fake': 0.0})
#
# ('Climate', {'msm': 0.0, 'fake': 0.0})
#
# ('Clinton', {'msm': 0.0, 'fake': 0.0})
#
# ('Clintons', {'msm': 0.0, 'fake': 0.0})
#
# ('Closing', {'msm': 0.0, 'fake': 0.0})
#
# ('Cloud', {'msm': 0.0, 'fake': 0.0})
#
# ('Club', {'msm': 0.0, 'fake': 0.0})
#
# ('Co', {'msm': 0.0, 'fake': 0.0})
#
# ('Coal', {'msm': 0.0, 'fake': 0.0})
#
# ('Coast', {'msm': 0.0, 'fake': 0.0})
#
# ('College', {'msm': 0.0, 'fake': 0.0})
#
# ('Collusion', {'msm': 0.0, 'fake': 0.0})
#
# ('Come', {'msm': 0.0, 'fake': 0.0})
#
# ('Comey', {'msm': 0.0, 'fake': 0.0})
#
# ('Coming', {'msm': 0.0, 'fake': 0.0})
#
# ('Committee', {'msm': 0.0, 'fake': 0.0})
#
# ('Common', {'msm': 0.0, 'fake': 0.0})
#
# ('Communist', {'msm': 0.0, 'fake': 0.0})
#
# ('Community', {'msm': 0.0, 'fake': 0.0})
#
# ('Companies', {'msm': 0.0, 'fake': 0.0})
#
# ('Company', {'msm': 0.0, 'fake': 0.0})
#
# ('Conference', {'msm': 0.0, 'fake': 0.0})
#
# ('Confirms', {'msm': 0.0, 'fake': 0.0})
#
# ('Congress', {'msm': 0.0, 'fake': 0.0})
#
# ('Congressional', {'msm': 0.0, 'fake': 0.0})
#
# ('Conservative', {'msm': 0.0, 'fake': 0.0})
#
# ('Conservatives', {'msm': 0.0, 'fake': 0.0})
#
# ('Considers', {'msm': 0.0, 'fake': 0.0})
#
# ('Conspiracy', {'msm': 0.0, 'fake': 0.0})
#
# ('Constitution', {'msm': 0.0, 'fake': 0.0})
#
# ('Content', {'msm': 0.0, 'fake': 0.0})
#
# ('Continues', {'msm': 0.0, 'fake': 0.0})
#
# ('Control', {'msm': 0.0, 'fake': 0.0})
#
# ('Cooper', {'msm': 0.0, 'fake': 0.0})
#
# ('Cop', {'msm': 0.0, 'fake': 0.0})
#
# ('Cops', {'msm': 0.0, 'fake': 0.0})
#
# ('Corbyn', {'msm': 0.0, 'fake': 0.0})
#
# ('Corporate', {'msm': 0.0, 'fake': 0.0})
#
# ('Corruption', {'msm': 0.0, 'fake': 0.0})
#
# ('Cost', {'msm': 0.0, 'fake': 0.0})
#
# ('Could', {'msm': 0.0, 'fake': 0.0})
#
# ('CouldBeatTrumpIn2020', {'msm': 0.0, 'fake': 0.0})
#
# ('Council', {'msm': 0.0, 'fake': 0.0})
#
# ('Country', {'msm': 0.0, 'fake': 0.0})
#
# ('County', {'msm': 0.0, 'fake': 0.0})
#
# ('Couple', {'msm': 0.0, 'fake': 0.0})
#
# ('Court', {'msm': 0.0, 'fake': 0.0})
#
# ('Cover', {'msm': 0.0, 'fake': 0.0})
#
# ('Crash', {'msm': 0.0, 'fake': 0.0})
#
# ('Criminal', {'msm': 0.0, 'fake': 0.0})
#
# ('Crisis', {'msm': 0.0, 'fake': 0.0})
#
# ('CrisisActors', {'msm': 0.0, 'fake': 0.0})
#
# ('Cruz', {'msm': 0.0, 'fake': 0.0})
#
# ('Crypto', {'msm': 0.0, 'fake': 0.0})
#
# ('Cryptocurrency', {'msm': 0.0, 'fake': 0.0})
#
# ('Cuba', {'msm': 0.0, 'fake': 0.0})
#
# ('Cuban', {'msm': 0.0, 'fake': 0.0})
#
# ('Culture', {'msm': 0.0, 'fake': 0.0})
#
# ('Cunningham', {'msm': 0.0, 'fake': 0.0})
#
# ('Cup', {'msm': 0.0, 'fake': 0.0})
#
# ('Cure', {'msm': 0.0, 'fake': 0.0})
#
# ('Curling', {'msm': 0.0, 'fake': 0.0})
#
# ('Customer', {'msm': 0.0, 'fake': 0.0})
#
# ('Cut', {'msm': 0.0, 'fake': 0.0})
#
# ('Cuts', {'msm': 0.0, 'fake': 0.0})
#
# ('Cutting', {'msm': 0.0, 'fake': 0.0})
#
# ('Cyber', {'msm': 0.0, 'fake': 0.0})
#
# ('DACA', {'msm': 0.0, 'fake': 0.0})
#
# ('DC', {'msm': 0.0, 'fake': 0.0})
#
# ('DNA', {'msm': 0.0, 'fake': 0.0})
#
# ('DNC', {'msm': 0.0, 'fake': 0.0})
#
# ('DO', {'msm': 0.0, 'fake': 0.0})
#
# ('DOJ', {'msm': 0.0, 'fake': 0.0})
#
# ('DONT', {'msm': 0.0, 'fake': 0.0})
#
# ('Dad', {'msm': 0.0, 'fake': 0.0})
#
# ('Daily', {'msm': 0.0, 'fake': 0.0})
#
# ('DailyNews', {'msm': 0.0, 'fake': 0.0})
#
# ('Daimler', {'msm': 0.0, 'fake': 0.0})
#
# ('Dallas', {'msm': 0.0, 'fake': 0.0})
#
# ('Damascus', {'msm': 0.0, 'fake': 0.0})
#
# ('Dana', {'msm': 0.0, 'fake': 0.0})
#
# ('Dangerous', {'msm': 0.0, 'fake': 0.0})
#
# ('Dark', {'msm': 0.0, 'fake': 0.0})
#
# ('Data', {'msm': 0.0, 'fake': 0.0})
#
# ('Daughter', {'msm': 0.0, 'fake': 0.0})
#
# ('David', {'msm': 0.0, 'fake': 0.0})
#
# ('Day', {'msm': 0.0, 'fake': 0.0})
#
# ('Days', {'msm': 0.0, 'fake': 0.0})
#
# ('De', {'msm': 0.0, 'fake': 0.0})
#
# ('Dead', {'msm': 0.0, 'fake': 0.0})
#
# ('Deadly', {'msm': 0.0, 'fake': 0.0})
#
# ('Deal', {'msm': 0.0, 'fake': 0.0})
#
# ('Dear', {'msm': 0.0, 'fake': 0.0})
#
# ('Death', {'msm': 0.0, 'fake': 0.0})
#
# ('Deaths', {'msm': 0.0, 'fake': 0.0})
#
# ('Debate', {'msm': 0.0, 'fake': 0.0})
#
# ('Deep', {'msm': 0.0, 'fake': 0.0})
#
# ('DeepLearning', {'msm': 0.0, 'fake': 0.0})
#
# ('Defense', {'msm': 0.0, 'fake': 0.0})
#
# ('Degas', {'msm': 0.0, 'fake': 0.0})
#
# ('Delta', {'msm': 0.0, 'fake': 0.0})
#
# ('Dem', {'msm': 0.0, 'fake': 0.0})
#
# ('Demand', {'msm': 0.0, 'fake': 0.0})
#
# ('Demands', {'msm': 0.0, 'fake': 0.0})
#
# ('Democrat', {'msm': 0.0, 'fake': 0.0})
#
# ('DemocratMemo', {'msm': 0.0, 'fake': 0.0})
#
# ('Democratic', {'msm': 0.0, 'fake': 0.0})
#
# ('Democrats', {'msm': 0.0, 'fake': 0.0})
#
# ('Dems', {'msm': 0.0, 'fake': 0.0})
#
# ('Denzel', {'msm': 0.0, 'fake': 0.0})
#
# ('Department', {'msm': 0.0, 'fake': 0.0})
#
# ('Dept', {'msm': 0.0, 'fake': 0.0})
#
# ('Deputy', {'msm': 0.0, 'fake': 0.0})
#
# ('Despite', {'msm': 0.0, 'fake': 0.0})
#
# ('Devin', {'msm': 0.0, 'fake': 0.0})
#
# ('Dianne', {'msm': 0.0, 'fake': 0.0})
#
# ('Did', {'msm': 0.0, 'fake': 0.0})
#
# ('Didnt', {'msm': 0.0, 'fake': 0.0})
#
# ('Didn’t', {'msm': 0.0, 'fake': 0.0})
#
# ('Diego', {'msm': 0.0, 'fake': 0.0})
#
# ('Dies', {'msm': 0.0, 'fake': 0.0})
#
# ('Different', {'msm': 0.0, 'fake': 0.0})
#
# ('Digital', {'msm': 0.0, 'fake': 0.0})
#
# ('Director', {'msm': 0.0, 'fake': 0.0})
#
# ('Dirty', {'msm': 0.0, 'fake': 0.0})
#
# ('DisClose', {'msm': 0.0, 'fake': 0.0})
#
# ('DiscloseTVwww', {'msm': 0.0, 'fake': 0.0})
#
# ('Discovered', {'msm': 0.0, 'fake': 0.0})
#
# ('Disease', {'msm': 0.0, 'fake': 0.0})
#
# ('Disgusting', {'msm': 0.0, 'fake': 0.0})
#
# ('Disney', {'msm': 0.0, 'fake': 0.0})
#
# ('Do', {'msm': 0.0, 'fake': 0.0})
#
# ('Doctor', {'msm': 0.0, 'fake': 0.0})
#
# ('Doctors', {'msm': 0.0, 'fake': 0.0})
#
# ('Documents', {'msm': 0.0, 'fake': 0.0})
#
# ('Does', {'msm': 0.0, 'fake': 0.0})
#
# ('Doesnt', {'msm': 0.0, 'fake': 0.0})
#
# ('Dog', {'msm': 0.0, 'fake': 0.0})
#
# ('Doing', {'msm': 0.0, 'fake': 0.0})
#
# ('Dollar', {'msm': 0.0, 'fake': 0.0})
#
# ('Domestic', {'msm': 0.0, 'fake': 0.0})
#
# ('Don', {'msm': 0.0, 'fake': 0.0})
#
# ('Donald', {'msm': 0.0, 'fake': 0.0})
#
# ('DonaldTrump', {'msm': 0.0, 'fake': 0.0})
#
# ('Dont', {'msm': 0.0, 'fake': 0.0})
#
# ('Don’t', {'msm': 0.0, 'fake': 0.0})
#
# ('Dossier', {'msm': 0.0, 'fake': 0.0})
#
# ('Douglas', {'msm': 0.0, 'fake': 0.0})
#
# ('Down', {'msm': 0.0, 'fake': 0.0})
#
# ('Dr', {'msm': 0.0, 'fake': 0.0})
#
# ('Dreamer', {'msm': 0.0, 'fake': 0.0})
#
# ('Dreamers', {'msm': 0.0, 'fake': 0.0})
#
# ('Drinking', {'msm': 0.0, 'fake': 0.0})
#
# ('Drive', {'msm': 0.0, 'fake': 0.0})
#
# ('Dropbox', {'msm': 0.0, 'fake': 0.0})
#
# ('Drops', {'msm': 0.0, 'fake': 0.0})
#
# ('Drug', {'msm': 0.0, 'fake': 0.0})
#
# ('Drugs', {'msm': 0.0, 'fake': 0.0})
#
# ('Dubai', {'msm': 0.0, 'fake': 0.0})
#
# ('During', {'msm': 0.0, 'fake': 0.0})
#
# ('E', {'msm': 0.0, 'fake': 0.0})
#
# ('ECB', {'msm': 0.0, 'fake': 0.0})
#
# ('EMETNEWSPRESS', {'msm': 0.0, 'fake': 0.0})
#
# ('EU', {'msm': 0.0, 'fake': 0.0})
#
# ('EXCLUSIVE', {'msm': 0.0, 'fake': 0.0})
#
# ('Early', {'msm': 0.0, 'fake': 0.0})
#
# ('Earth', {'msm': 0.0, 'fake': 0.0})
#
# ('East', {'msm': 0.0, 'fake': 0.0})
#
# ('Eastern', {'msm': 0.0, 'fake': 0.0})
#
# ('Eat', {'msm': 0.0, 'fake': 0.0})
#
# ('Eating', {'msm': 0.0, 'fake': 0.0})
#
# ('Economic', {'msm': 0.0, 'fake': 0.0})
#
# ('Economy', {'msm': 0.0, 'fake': 0.0})
#
# ('Education', {'msm': 0.0, 'fake': 0.0})
#
# ('Egypt', {'msm': 0.0, 'fake': 0.0})
#
# ('El', {'msm': 0.0, 'fake': 0.0})
#
# ('Election', {'msm': 0.0, 'fake': 0.0})
#
# ('Elections', {'msm': 0.0, 'fake': 0.0})
#
# ('Electric', {'msm': 0.0, 'fake': 0.0})
#
# ('Elite', {'msm': 0.0, 'fake': 0.0})
#
# ('Elizabeth', {'msm': 0.0, 'fake': 0.0})
#
# ('Elon', {'msm': 0.0, 'fake': 0.0})
#
# ('Email', {'msm': 0.0, 'fake': 0.0})
#
# ('Embassy', {'msm': 0.0, 'fake': 0.0})
#
# ('Emma', {'msm': 0.0, 'fake': 0.0})
#
# ('Employee', {'msm': 0.0, 'fake': 0.0})
#
# ('Employees', {'msm': 0.0, 'fake': 0.0})
#
# ('End', {'msm': 0.0, 'fake': 0.0})
#
# ('Energy', {'msm': 0.0, 'fake': 0.0})
#
# ('England', {'msm': 0.0, 'fake': 0.0})
#
# ('English', {'msm': 0.0, 'fake': 0.0})
#
# ('Enough', {'msm': 0.0, 'fake': 0.0})
#
# ('Enterprise', {'msm': 0.0, 'fake': 0.0})
#
# ('Entire', {'msm': 0.0, 'fake': 0.0})
#
# ('Entrepreneur', {'msm': 0.0, 'fake': 0.0})
#
# ('Entrepreneurs', {'msm': 0.0, 'fake': 0.0})
#
# ('Epic', {'msm': 0.0, 'fake': 0.0})
#
# ('Epidemic', {'msm': 0.0, 'fake': 0.0})
#
# ('Eric', {'msm': 0.0, 'fake': 0.0})
#
# ('Ester', {'msm': 0.0, 'fake': 0.0})
#
# ('Europe', {'msm': 0.0, 'fake': 0.0})
#
# ('European', {'msm': 0.0, 'fake': 0.0})
#
# ('Even', {'msm': 0.0, 'fake': 0.0})
#
# ('Event', {'msm': 0.0, 'fake': 0.0})
#
# ('Ever', {'msm': 0.0, 'fake': 0.0})
#
# ('Every', {'msm': 0.0, 'fake': 0.0})
#
# ('Everyone', {'msm': 0.0, 'fake': 0.0})
#
# ('Everything', {'msm': 0.0, 'fake': 0.0})
#
# ('Evidence', {'msm': 0.0, 'fake': 0.0})
#
# ('Evil', {'msm': 0.0, 'fake': 0.0})
#
# ('Exactly', {'msm': 0.0, 'fake': 0.0})
#
# ('Excellent', {'msm': 0.0, 'fake': 0.0})
#
# ('Exclusive', {'msm': 0.0, 'fake': 0.0})
#
# ('Executive', {'msm': 0.0, 'fake': 0.0})
#
# ('Experts', {'msm': 0.0, 'fake': 0.0})
#
# ('Exposed', {'msm': 0.0, 'fake': 0.0})
#
# ('Exposes', {'msm': 0.0, 'fake': 0.0})
#
# ('FBI', {'msm': 0.0, 'fake': 0.0})
#
# ('FBIControl', {'msm': 0.0, 'fake': 0.0})
#
# ('FBIReformNow', {'msm': 0.0, 'fake': 0.0})
#
# ('FCC', {'msm': 0.0, 'fake': 0.0})
#
# ('FDA', {'msm': 0.0, 'fake': 0.0})
#
# ('FEMA', {'msm': 0.0, 'fake': 0.0})
#
# ('FISA', {'msm': 0.0, 'fake': 0.0})
#
# ('FISAMemo', {'msm': 0.0, 'fake': 0.0})
#
# ('FL', {'msm': 0.0, 'fake': 0.0})
#
# ('FOR', {'msm': 0.0, 'fake': 0.0})
#
# ('FOX', {'msm': 0.0, 'fake': 0.0})
#
# ('FROM', {'msm': 0.0, 'fake': 0.0})
#
# ('FYI', {'msm': 0.0, 'fake': 0.0})
#
# ('Fabray', {'msm': 0.0, 'fake': 0.0})
#
# ('Face', {'msm': 0.0, 'fake': 0.0})
#
# ('Facebook', {'msm': 0.0, 'fake': 0.0})
#
# ('Faces', {'msm': 0.0, 'fake': 0.0})
#
# ('Facts', {'msm': 0.0, 'fake': 0.0})
#
# ('Fake', {'msm': 0.0, 'fake': 0.0})
#
# ('FakeNews', {'msm': 0.0, 'fake': 0.0})
#
# ('Falls', {'msm': 0.0, 'fake': 0.0})
#
# ('False', {'msm': 0.0, 'fake': 0.0})
#
# ('Family', {'msm': 0.0, 'fake': 0.0})
#
# ('Fashion', {'msm': 0.0, 'fake': 0.0})
#
# ('Father', {'msm': 0.0, 'fake': 0.0})
#
# ('Fear', {'msm': 0.0, 'fake': 0.0})
#
# ('Feb', {'msm': 0.0, 'fake': 0.0})
#
# ('February', {'msm': 0.0, 'fake': 0.0})
#
# ('Fed', {'msm': 0.0, 'fake': 0.0})
#
# ('Federal', {'msm': 0.0, 'fake': 0.0})
#
# ('Feinstein', {'msm': 0.0, 'fake': 0.0})
#
# ('Female', {'msm': 0.0, 'fake': 0.0})
#
# ('Festival', {'msm': 0.0, 'fake': 0.0})
#
# ('Fidel', {'msm': 0.0, 'fake': 0.0})
#
# ('Fight', {'msm': 0.0, 'fake': 0.0})
#
# ('Fights', {'msm': 0.0, 'fake': 0.0})
#
# ('Figure', {'msm': 0.0, 'fake': 0.0})
#
# ('Files', {'msm': 0.0, 'fake': 0.0})
#
# ('Film', {'msm': 0.0, 'fake': 0.0})
#
# ('Final', {'msm': 0.0, 'fake': 0.0})
#
# ('Finally', {'msm': 0.0, 'fake': 0.0})
#
# ('Finance', {'msm': 0.0, 'fake': 0.0})
#
# ('Financial', {'msm': 0.0, 'fake': 0.0})
#
# ('Find', {'msm': 0.0, 'fake': 0.0})
#
# ('Finds', {'msm': 0.0, 'fake': 0.0})
#
# ('Fintech', {'msm': 0.0, 'fake': 0.0})
#
# ('Fire', {'msm': 0.0, 'fake': 0.0})
#
# ('Fired', {'msm': 0.0, 'fake': 0.0})
#
# ('First', {'msm': 0.0, 'fake': 0.0})
#
# ('FisaMemo', {'msm': 0.0, 'fake': 0.0})
#
# ('Five', {'msm': 0.0, 'fake': 0.0})
#
# ('Fla', {'msm': 0.0, 'fake': 0.0})
#
# ('Flag', {'msm': 0.0, 'fake': 0.0})
#
# ('Flight', {'msm': 0.0, 'fake': 0.0})
#
# ('Florida', {'msm': 0.0, 'fake': 0.0})
#
# ('Flu', {'msm': 0.0, 'fake': 0.0})
#
# ('Flynn', {'msm': 0.0, 'fake': 0.0})
#
# ('Follow', {'msm': 0.0, 'fake': 0.0})
#
# ('FollowTheWhiteRabbit', {'msm': 0.0, 'fake': 0.0})
#
# ('Food', {'msm': 0.0, 'fake': 0.0})
#
# ('Foods', {'msm': 0.0, 'fake': 0.0})
#
# ('Footage', {'msm': 0.0, 'fake': 0.0})
#
# ('For', {'msm': 0.0, 'fake': 0.0})
#
# ('Forbes', {'msm': 0.0, 'fake': 0.0})
#
# ('Force', {'msm': 0.0, 'fake': 0.0})
#
# ('Forced', {'msm': 0.0, 'fake': 0.0})
#
# ('Forces', {'msm': 0.0, 'fake': 0.0})
#
# ('Foreign', {'msm': 0.0, 'fake': 0.0})
#
# ('Forget', {'msm': 0.0, 'fake': 0.0})
#
# ('Former', {'msm': 0.0, 'fake': 0.0})
#
# ('Found', {'msm': 0.0, 'fake': 0.0})
#
# ('Foundation', {'msm': 0.0, 'fake': 0.0})
#
# ('Four', {'msm': 0.0, 'fake': 0.0})
#
# ('Fox', {'msm': 0.0, 'fake': 0.0})
#
# ('FoxNews', {'msm': 0.0, 'fake': 0.0})
#
# ('France', {'msm': 0.0, 'fake': 0.0})
#
# ('Francis', {'msm': 0.0, 'fake': 0.0})
#
# ('Francisco', {'msm': 0.0, 'fake': 0.0})
#
# ('Fraud', {'msm': 0.0, 'fake': 0.0})
#
# ('Freak', {'msm': 0.0, 'fake': 0.0})
#
# ('Free', {'msm': 0.0, 'fake': 0.0})
#
# ('Freedom', {'msm': 0.0, 'fake': 0.0})
#
# ('French', {'msm': 0.0, 'fake': 0.0})
#
# ('Friday', {'msm': 0.0, 'fake': 0.0})
#
# ('From', {'msm': 0.0, 'fake': 0.0})
#
# ('Frozen', {'msm': 0.0, 'fake': 0.0})
#
# ('Full', {'msm': 0.0, 'fake': 0.0})
#
# ('Fund', {'msm': 0.0, 'fake': 0.0})
#
# ('Funds', {'msm': 0.0, 'fake': 0.0})
#
# ('Future', {'msm': 0.0, 'fake': 0.0})
#
# ('GE', {'msm': 0.0, 'fake': 0.0})
#
# ('GO', {'msm': 0.0, 'fake': 0.0})
#
# ('GOP', {'msm': 0.0, 'fake': 0.0})
#
# ('Galaxy', {'msm': 0.0, 'fake': 0.0})
#
# ('Game', {'msm': 0.0, 'fake': 0.0})
#
# ('Games', {'msm': 0.0, 'fake': 0.0})
#
# ('Gates', {'msm': 0.0, 'fake': 0.0})
#
# ('Gay', {'msm': 0.0, 'fake': 0.0})
#
# ('Geely', {'msm': 0.0, 'fake': 0.0})
#
# ('General', {'msm': 0.0, 'fake': 0.0})
#
# ('George', {'msm': 0.0, 'fake': 0.0})
#
# ('Georgia', {'msm': 0.0, 'fake': 0.0})
#
# ('German', {'msm': 0.0, 'fake': 0.0})
#
# ('Germany', {'msm': 0.0, 'fake': 0.0})
#
# ('Get', {'msm': 0.0, 'fake': 0.0})
#
# ('Gets', {'msm': 0.0, 'fake': 0.0})
#
# ('Getting', {'msm': 0.0, 'fake': 0.0})
#
# ('Ghouta', {'msm': 0.0, 'fake': 0.0})
#
# ('Giant', {'msm': 0.0, 'fake': 0.0})
#
# ('Girl', {'msm': 0.0, 'fake': 0.0})
#
# ('Girls', {'msm': 0.0, 'fake': 0.0})
#
# ('Give', {'msm': 0.0, 'fake': 0.0})
#
# ('Given', {'msm': 0.0, 'fake': 0.0})
#
# ('Gives', {'msm': 0.0, 'fake': 0.0})
#
# ('Glad', {'msm': 0.0, 'fake': 0.0})
#
# ('Global', {'msm': 0.0, 'fake': 0.0})
#
# ('Go', {'msm': 0.0, 'fake': 0.0})
#
# ('God', {'msm': 0.0, 'fake': 0.0})
#
# ('Goes', {'msm': 0.0, 'fake': 0.0})
#
# ('Going', {'msm': 0.0, 'fake': 0.0})
#
# ('Gold', {'msm': 0.0, 'fake': 0.0})
#
# ('Golden', {'msm': 0.0, 'fake': 0.0})
#
# ('Goldman', {'msm': 0.0, 'fake': 0.0})
#
# ('Good', {'msm': 0.0, 'fake': 0.0})
#
# ('Google', {'msm': 0.0, 'fake': 0.0})
#
# ('Got', {'msm': 0.0, 'fake': 0.0})
#
# ('Gov', {'msm': 0.0, 'fake': 0.0})
#
# ('Government', {'msm': 0.0, 'fake': 0.0})
#
# ('Governments', {'msm': 0.0, 'fake': 0.0})
#
# ('Governor', {'msm': 0.0, 'fake': 0.0})
#
# ('Govt', {'msm': 0.0, 'fake': 0.0})
#
# ('Gowdy', {'msm': 0.0, 'fake': 0.0})
#
# ('Graham', {'msm': 0.0, 'fake': 0.0})
#
# ('Grand', {'msm': 0.0, 'fake': 0.0})
#
# ('Great', {'msm': 0.0, 'fake': 0.0})
#
# ('GreatAwakening', {'msm': 0.0, 'fake': 0.0})
#
# ('Greatest', {'msm': 0.0, 'fake': 0.0})
#
# ('Green', {'msm': 0.0, 'fake': 0.0})
#
# ('Greitens', {'msm': 0.0, 'fake': 0.0})
#
# ('Group', {'msm': 0.0, 'fake': 0.0})
#
# ('Grow', {'msm': 0.0, 'fake': 0.0})
#
# ('Guide', {'msm': 0.0, 'fake': 0.0})
#
# ('Guilty', {'msm': 0.0, 'fake': 0.0})
#
# ('Guinea', {'msm': 0.0, 'fake': 0.0})
#
# ('Gun', {'msm': 0.0, 'fake': 0.0})
#
# ('GunControl', {'msm': 0.0, 'fake': 0.0})
#
# ('GunControlNow', {'msm': 0.0, 'fake': 0.0})
#
# ('GunReformNow', {'msm': 0.0, 'fake': 0.0})
#
# ('Guns', {'msm': 0.0, 'fake': 0.0})
#
# ('Gus', {'msm': 0.0, 'fake': 0.0})
#
# ('Guy', {'msm': 0.0, 'fake': 0.0})
#
# ('HAVE', {'msm': 0.0, 'fake': 0.0})
#
# ('HE', {'msm': 0.0, 'fake': 0.0})
#
# ('HERE', {'msm': 0.0, 'fake': 0.0})
#
# ('HR', {'msm': 0.0, 'fake': 0.0})
#
# ('Had', {'msm': 0.0, 'fake': 0.0})
#
# ('Haiti', {'msm': 0.0, 'fake': 0.0})
#
# ('Hall', {'msm': 0.0, 'fake': 0.0})
#
# ('Happened', {'msm': 0.0, 'fake': 0.0})
#
# ('Happens', {'msm': 0.0, 'fake': 0.0})
#
# ('Haram', {'msm': 0.0, 'fake': 0.0})
#
# ('Hard', {'msm': 0.0, 'fake': 0.0})
#
# ('Harris', {'msm': 0.0, 'fake': 0.0})
#
# ('Harvey', {'msm': 0.0, 'fake': 0.0})
#
# ('Has', {'msm': 0.0, 'fake': 0.0})
#
# ('Hathaway', {'msm': 0.0, 'fake': 0.0})
#
# ('Have', {'msm': 0.0, 'fake': 0.0})
#
# ('Having', {'msm': 0.0, 'fake': 0.0})
#
# ('Hawaii', {'msm': 0.0, 'fake': 0.0})
#
# ('He', {'msm': 0.0, 'fake': 0.0})
#
# ('Head', {'msm': 0.0, 'fake': 0.0})
#
# ('Headlines', {'msm': 0.0, 'fake': 0.0})
#
# ('Health', {'msm': 0.0, 'fake': 0.0})
#
# ('Hear', {'msm': 0.0, 'fake': 0.0})
#
# ('Heart', {'msm': 0.0, 'fake': 0.0})
#
# ('Heather', {'msm': 0.0, 'fake': 0.0})
#
# ('Hell', {'msm': 0.0, 'fake': 0.0})
#
# ('Help', {'msm': 0.0, 'fake': 0.0})
#
# ('Helped', {'msm': 0.0, 'fake': 0.0})
#
# ('Her', {'msm': 0.0, 'fake': 0.0})
#
# ('Here', {'msm': 0.0, 'fake': 0.0})
#
# ('Here’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Hero', {'msm': 0.0, 'fake': 0.0})
#
# ('Hertz', {'msm': 0.0, 'fake': 0.0})
#
# ('Hey', {'msm': 0.0, 'fake': 0.0})
#
# ('He’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Hidden', {'msm': 0.0, 'fake': 0.0})
#
# ('Hiding', {'msm': 0.0, 'fake': 0.0})
#
# ('High', {'msm': 0.0, 'fake': 0.0})
#
# ('Hill', {'msm': 0.0, 'fake': 0.0})
#
# ('Hillary', {'msm': 0.0, 'fake': 0.0})
#
# ('Him', {'msm': 0.0, 'fake': 0.0})
#
# ('His', {'msm': 0.0, 'fake': 0.0})
#
# ('History', {'msm': 0.0, 'fake': 0.0})
#
# ('Hit', {'msm': 0.0, 'fake': 0.0})
#
# ('Hockey', {'msm': 0.0, 'fake': 0.0})
#
# ('Hogg', {'msm': 0.0, 'fake': 0.0})
#
# ('Hold', {'msm': 0.0, 'fake': 0.0})
#
# ('Hollywood', {'msm': 0.0, 'fake': 0.0})
#
# ('Holy', {'msm': 0.0, 'fake': 0.0})
#
# ('Home', {'msm': 0.0, 'fake': 0.0})
#
# ('Homeless', {'msm': 0.0, 'fake': 0.0})
#
# ('Hook', {'msm': 0.0, 'fake': 0.0})
#
# ('Hope', {'msm': 0.0, 'fake': 0.0})
#
# ('Hot', {'msm': 0.0, 'fake': 0.0})
#
# ('Hotel', {'msm': 0.0, 'fake': 0.0})
#
# ('Hotels', {'msm': 0.0, 'fake': 0.0})
#
# ('House', {'msm': 0.0, 'fake': 0.0})
#
# ('Houston', {'msm': 0.0, 'fake': 0.0})
#
# ('How', {'msm': 0.0, 'fake': 0.0})
#
# ('Huawei', {'msm': 0.0, 'fake': 0.0})
#
# ('HuffPost', {'msm': 0.0, 'fake': 0.0})
#
# ('Huge', {'msm': 0.0, 'fake': 0.0})
#
# ('Human', {'msm': 0.0, 'fake': 0.0})
#
# ('Humans', {'msm': 0.0, 'fake': 0.0})
#
# ('Hundreds', {'msm': 0.0, 'fake': 0.0})
#
# ('I', {'msm': 0.0, 'fake': 0.0})
#
# ('ICE', {'msm': 0.0, 'fake': 0.0})
#
# ('ICYMI', {'msm': 0.0, 'fake': 0.0})
#
# ('II', {'msm': 0.0, 'fake': 0.0})
#
# ('IN', {'msm': 0.0, 'fake': 0.0})
#
# ('IOC', {'msm': 0.0, 'fake': 0.0})
#
# ('IPO', {'msm': 0.0, 'fake': 0.0})
#
# ('IRS', {'msm': 0.0, 'fake': 0.0})
#
# ('IS', {'msm': 0.0, 'fake': 0.0})
#
# ('ISIS', {'msm': 0.0, 'fake': 0.0})
#
# ('IT', {'msm': 0.0, 'fake': 0.0})
#
# ('Ice', {'msm': 0.0, 'fake': 0.0})
#
# ('Id', {'msm': 0.0, 'fake': 0.0})
#
# ('Idea', {'msm': 0.0, 'fake': 0.0})
#
# ('If', {'msm': 0.0, 'fake': 0.0})
#
# ('Ill', {'msm': 0.0, 'fake': 0.0})
#
# ('Illegal', {'msm': 0.0, 'fake': 0.0})
#
# ('Illuminati', {'msm': 0.0, 'fake': 0.0})
#
# ('Im', {'msm': 0.0, 'fake': 0.0})
#
# ('Immigrants', {'msm': 0.0, 'fake': 0.0})
#
# ('Immigration', {'msm': 0.0, 'fake': 0.0})
#
# ('Important', {'msm': 0.0, 'fake': 0.0})
#
# ('In', {'msm': 0.0, 'fake': 0.0})
#
# ('Inc', {'msm': 0.0, 'fake': 0.0})
#
# ('Incredible', {'msm': 0.0, 'fake': 0.0})
#
# ('India', {'msm': 0.0, 'fake': 0.0})
#
# ('Indian', {'msm': 0.0, 'fake': 0.0})
#
# ('Indonesia', {'msm': 0.0, 'fake': 0.0})
#
# ('Industry', {'msm': 0.0, 'fake': 0.0})
#
# ('Ingraham', {'msm': 0.0, 'fake': 0.0})
#
# ('Inside', {'msm': 0.0, 'fake': 0.0})
#
# ('Instagram', {'msm': 0.0, 'fake': 0.0})
#
# ('Instead', {'msm': 0.0, 'fake': 0.0})
#
# ('Intel', {'msm': 0.0, 'fake': 0.0})
#
# ('Intelligence', {'msm': 0.0, 'fake': 0.0})
#
# ('Interesting', {'msm': 0.0, 'fake': 0.0})
#
# ('International', {'msm': 0.0, 'fake': 0.0})
#
# ('Internet', {'msm': 0.0, 'fake': 0.0})
#
# ('Interview', {'msm': 0.0, 'fake': 0.0})
#
# ('Into', {'msm': 0.0, 'fake': 0.0})
#
# ('Investigation', {'msm': 0.0, 'fake': 0.0})
#
# ('Investment', {'msm': 0.0, 'fake': 0.0})
#
# ('Investors', {'msm': 0.0, 'fake': 0.0})
#
# ('Involved', {'msm': 0.0, 'fake': 0.0})
#
# ('IoT', {'msm': 0.0, 'fake': 0.0})
#
# ('Iowa', {'msm': 0.0, 'fake': 0.0})
#
# ('Iran', {'msm': 0.0, 'fake': 0.0})
#
# ('Iranian', {'msm': 0.0, 'fake': 0.0})
#
# ('Iraq', {'msm': 0.0, 'fake': 0.0})
#
# ('Is', {'msm': 0.0, 'fake': 0.0})
#
# ('Islamic', {'msm': 0.0, 'fake': 0.0})
#
# ('Island', {'msm': 0.0, 'fake': 0.0})
#
# ('Isnt', {'msm': 0.0, 'fake': 0.0})
#
# ('Israel', {'msm': 0.0, 'fake': 0.0})
#
# ('Israeli', {'msm': 0.0, 'fake': 0.0})
#
# ('Issues', {'msm': 0.0, 'fake': 0.0})
#
# ('It', {'msm': 0.0, 'fake': 0.0})
#
# ('Italian', {'msm': 0.0, 'fake': 0.0})
#
# ('Italians', {'msm': 0.0, 'fake': 0.0})
#
# ('Italy', {'msm': 0.0, 'fake': 0.0})
#
# ('Its', {'msm': 0.0, 'fake': 0.0})
#
# ('It’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Ivanka', {'msm': 0.0, 'fake': 0.0})
#
# ('Ive', {'msm': 0.0, 'fake': 0.0})
#
# ('I’ll', {'msm': 0.0, 'fake': 0.0})
#
# ('I’m', {'msm': 0.0, 'fake': 0.0})
#
# ('I’ve', {'msm': 0.0, 'fake': 0.0})
#
# ('J', {'msm': 0.0, 'fake': 0.0})
#
# ('JUST', {'msm': 0.0, 'fake': 0.0})
#
# ('Jackson', {'msm': 0.0, 'fake': 0.0})
#
# ('Jail', {'msm': 0.0, 'fake': 0.0})
#
# ('James', {'msm': 0.0, 'fake': 0.0})
#
# ('January', {'msm': 0.0, 'fake': 0.0})
#
# ('Janus', {'msm': 0.0, 'fake': 0.0})
#
# ('Japan', {'msm': 0.0, 'fake': 0.0})
#
# ('Japanese', {'msm': 0.0, 'fake': 0.0})
#
# ('Jared', {'msm': 0.0, 'fake': 0.0})
#
# ('Jeanine', {'msm': 0.0, 'fake': 0.0})
#
# ('Jeff', {'msm': 0.0, 'fake': 0.0})
#
# ('Jenner', {'msm': 0.0, 'fake': 0.0})
#
# ('Jennifer', {'msm': 0.0, 'fake': 0.0})
#
# ('Jeremy', {'msm': 0.0, 'fake': 0.0})
#
# ('Jerry', {'msm': 0.0, 'fake': 0.0})
#
# ('Jerusalem', {'msm': 0.0, 'fake': 0.0})
#
# ('Jesus', {'msm': 0.0, 'fake': 0.0})
#
# ('Jewish', {'msm': 0.0, 'fake': 0.0})
#
# ('Jim', {'msm': 0.0, 'fake': 0.0})
#
# ('Jimmy', {'msm': 0.0, 'fake': 0.0})
#
# ('Jinping', {'msm': 0.0, 'fake': 0.0})
#
# ('Job', {'msm': 0.0, 'fake': 0.0})
#
# ('Jobs', {'msm': 0.0, 'fake': 0.0})
#
# ('Joe', {'msm': 0.0, 'fake': 0.0})
#
# ('John', {'msm': 0.0, 'fake': 0.0})
#
# ('Join', {'msm': 0.0, 'fake': 0.0})
#
# ('Jones', {'msm': 0.0, 'fake': 0.0})
#
# ('Jong', {'msm': 0.0, 'fake': 0.0})
#
# ('Journal', {'msm': 0.0, 'fake': 0.0})
#
# ('Jr', {'msm': 0.0, 'fake': 0.0})
#
# ('Judge', {'msm': 0.0, 'fake': 0.0})
#
# ('Just', {'msm': 0.0, 'fake': 0.0})
#
# ('Justice', {'msm': 0.0, 'fake': 0.0})
#
# ('Justin', {'msm': 0.0, 'fake': 0.0})
#
# ('KFC', {'msm': 0.0, 'fake': 0.0})
#
# ('Kansas', {'msm': 0.0, 'fake': 0.0})
#
# ('Keep', {'msm': 0.0, 'fake': 0.0})
#
# ('Kelly', {'msm': 0.0, 'fake': 0.0})
#
# ('Kentucky', {'msm': 0.0, 'fake': 0.0})
#
# ('Kenworthy', {'msm': 0.0, 'fake': 0.0})
#
# ('Kerry', {'msm': 0.0, 'fake': 0.0})
#
# ('Kevin', {'msm': 0.0, 'fake': 0.0})
#
# ('Key', {'msm': 0.0, 'fake': 0.0})
#
# ('Kids', {'msm': 0.0, 'fake': 0.0})
#
# ('Kill', {'msm': 0.0, 'fake': 0.0})
#
# ('Killed', {'msm': 0.0, 'fake': 0.0})
#
# ('Killing', {'msm': 0.0, 'fake': 0.0})
#
# ('Kills', {'msm': 0.0, 'fake': 0.0})
#
# ('Kim', {'msm': 0.0, 'fake': 0.0})
#
# ('King', {'msm': 0.0, 'fake': 0.0})
#
# ('Knew', {'msm': 0.0, 'fake': 0.0})
#
# ('Know', {'msm': 0.0, 'fake': 0.0})
#
# ('Korea', {'msm': 0.0, 'fake': 0.0})
#
# ('Korean', {'msm': 0.0, 'fake': 0.0})
#
# ('Koreans', {'msm': 0.0, 'fake': 0.0})
#
# ('Kremlin', {'msm': 0.0, 'fake': 0.0})
#
# ('Kurdish', {'msm': 0.0, 'fake': 0.0})
#
# ('Kushner', {'msm': 0.0, 'fake': 0.0})
#
# ('Kylie', {'msm': 0.0, 'fake': 0.0})
#
# ('L', {'msm': 0.0, 'fake': 0.0})
#
# ('LA', {'msm': 0.0, 'fake': 0.0})
#
# ('LGBT', {'msm': 0.0, 'fake': 0.0})
#
# ('LOL', {'msm': 0.0, 'fake': 0.0})
#
# ('La', {'msm': 0.0, 'fake': 0.0})
#
# ('Labour', {'msm': 0.0, 'fake': 0.0})
#
# ('Land', {'msm': 0.0, 'fake': 0.0})
#
# ('Las', {'msm': 0.0, 'fake': 0.0})
#
# ('Last', {'msm': 0.0, 'fake': 0.0})
#
# ('Later', {'msm': 0.0, 'fake': 0.0})
#
# ('Latest', {'msm': 0.0, 'fake': 0.0})
#
# ('Launches', {'msm': 0.0, 'fake': 0.0})
#
# ('Laura', {'msm': 0.0, 'fake': 0.0})
#
# ('Law', {'msm': 0.0, 'fake': 0.0})
#
# ('Lawmaker', {'msm': 0.0, 'fake': 0.0})
#
# ('Lawmakers', {'msm': 0.0, 'fake': 0.0})
#
# ('Lawrence', {'msm': 0.0, 'fake': 0.0})
#
# ('Laws', {'msm': 0.0, 'fake': 0.0})
#
# ('Lawsuit', {'msm': 0.0, 'fake': 0.0})
#
# ('LeBron', {'msm': 0.0, 'fake': 0.0})
#
# ('Lead', {'msm': 0.0, 'fake': 0.0})
#
# ('Leader', {'msm': 0.0, 'fake': 0.0})
#
# ('Leaders', {'msm': 0.0, 'fake': 0.0})
#
# ('Leadership', {'msm': 0.0, 'fake': 0.0})
#
# ('League', {'msm': 0.0, 'fake': 0.0})
#
# ('Learn', {'msm': 0.0, 'fake': 0.0})
#
# ('Learned', {'msm': 0.0, 'fake': 0.0})
#
# ('Learning', {'msm': 0.0, 'fake': 0.0})
#
# ('Least', {'msm': 0.0, 'fake': 0.0})
#
# ('Leave', {'msm': 0.0, 'fake': 0.0})
#
# ('Leaves', {'msm': 0.0, 'fake': 0.0})
#
# ('Leaving', {'msm': 0.0, 'fake': 0.0})
#
# ('Ledecka', {'msm': 0.0, 'fake': 0.0})
#
# ('Left', {'msm': 0.0, 'fake': 0.0})
#
# ('Legal', {'msm': 0.0, 'fake': 0.0})
#
# ('Leicester', {'msm': 0.0, 'fake': 0.0})
#
# ('Less', {'msm': 0.0, 'fake': 0.0})
#
# ('Lessons', {'msm': 0.0, 'fake': 0.0})
#
# ('Let', {'msm': 0.0, 'fake': 0.0})
#
# ('Letter', {'msm': 0.0, 'fake': 0.0})
#
# ('Let’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Lewinsky', {'msm': 0.0, 'fake': 0.0})
#
# ('Liberal', {'msm': 0.0, 'fake': 0.0})
#
# ('Liberals', {'msm': 0.0, 'fake': 0.0})
#
# ('Lie', {'msm': 0.0, 'fake': 0.0})
#
# ('Life', {'msm': 0.0, 'fake': 0.0})
#
# ('Light', {'msm': 0.0, 'fake': 0.0})
#
# ('Like', {'msm': 0.0, 'fake': 0.0})
#
# ('Likely', {'msm': 0.0, 'fake': 0.0})
#
# ('Limit', {'msm': 0.0, 'fake': 0.0})
#
# ('Lines', {'msm': 0.0, 'fake': 0.0})
#
# ('Link', {'msm': 0.0, 'fake': 0.0})
#
# ('List', {'msm': 0.0, 'fake': 0.0})
#
# ('Listen', {'msm': 0.0, 'fake': 0.0})
#
# ('Little', {'msm': 0.0, 'fake': 0.0})
#
# ('Live', {'msm': 0.0, 'fake': 0.0})
#
# ('Lives', {'msm': 0.0, 'fake': 0.0})
#
# ('Local', {'msm': 0.0, 'fake': 0.0})
#
# ('Locklear', {'msm': 0.0, 'fake': 0.0})
#
# ('Loesch', {'msm': 0.0, 'fake': 0.0})
#
# ('London', {'msm': 0.0, 'fake': 0.0})
#
# ('Long', {'msm': 0.0, 'fake': 0.0})
#
# ('Look', {'msm': 0.0, 'fake': 0.0})
#
# ('Looking', {'msm': 0.0, 'fake': 0.0})
#
# ('LookingForNewsgtgtgt', {'msm': 0.0, 'fake': 0.0})
#
# ('Looks', {'msm': 0.0, 'fake': 0.0})
#
# ('Lore', {'msm': 0.0, 'fake': 0.0})
#
# ('Los', {'msm': 0.0, 'fake': 0.0})
#
# ('LosAngeles', {'msm': 0.0, 'fake': 0.0})
#
# ('Losing', {'msm': 0.0, 'fake': 0.0})
#
# ('Lost', {'msm': 0.0, 'fake': 0.0})
#
# ('Louisiana', {'msm': 0.0, 'fake': 0.0})
#
# ('Love', {'msm': 0.0, 'fake': 0.0})
#
# ('MAGA', {'msm': 0.0, 'fake': 0.0})
#
# ('ML', {'msm': 0.0, 'fake': 0.0})
#
# ('MORE', {'msm': 0.0, 'fake': 0.0})
#
# ('MSM', {'msm': 0.0, 'fake': 0.0})
#
# ('MSNBC', {'msm': 0.0, 'fake': 0.0})
#
# ('MUST', {'msm': 0.0, 'fake': 0.0})
#
# ('MY', {'msm': 0.0, 'fake': 0.0})

# %%
print("\n\n".join([str(x) for x in mi1_top_msm[0:1000]]))
# Out:
# ('1', {'msm': 0.0, 'fake': 0.0})
#
# ('10', {'msm': 0.0, 'fake': 0.0})
#
# ('100', {'msm': 0.0, 'fake': 0.0})
#
# ('1000', {'msm': 0.0, 'fake': 0.0})
#
# ('10000', {'msm': 0.0, 'fake': 0.0})
#
# ('100000', {'msm': 0.0, 'fake': 0.0})
#
# ('11', {'msm': 0.0, 'fake': 0.0})
#
# ('12', {'msm': 0.0, 'fake': 0.0})
#
# ('13', {'msm': 0.0, 'fake': 0.0})
#
# ('14', {'msm': 0.0, 'fake': 0.0})
#
# ('15', {'msm': 0.0, 'fake': 0.0})
#
# ('16', {'msm': 0.0, 'fake': 0.0})
#
# ('17', {'msm': 0.0, 'fake': 0.0})
#
# ('18', {'msm': 0.0, 'fake': 0.0})
#
# ('19', {'msm': 0.0, 'fake': 0.0})
#
# ('1st', {'msm': 0.0, 'fake': 0.0})
#
# ('2', {'msm': 0.0, 'fake': 0.0})
#
# ('20', {'msm': 0.0, 'fake': 0.0})
#
# ('200', {'msm': 0.0, 'fake': 0.0})
#
# ('2013', {'msm': 0.0, 'fake': 0.0})
#
# ('2014', {'msm': 0.0, 'fake': 0.0})
#
# ('2015', {'msm': 0.0, 'fake': 0.0})
#
# ('2016', {'msm': 0.0, 'fake': 0.0})
#
# ('2017', {'msm': 0.0, 'fake': 0.0})
#
# ('2018', {'msm': 0.0, 'fake': 0.0})
#
# ('2019', {'msm': 0.0, 'fake': 0.0})
#
# ('2020', {'msm': 0.0, 'fake': 0.0})
#
# ('21', {'msm': 0.0, 'fake': 0.0})
#
# ('22', {'msm': 0.0, 'fake': 0.0})
#
# ('23', {'msm': 0.0, 'fake': 0.0})
#
# ('24', {'msm': 0.0, 'fake': 0.0})
#
# ('25', {'msm': 0.0, 'fake': 0.0})
#
# ('26', {'msm': 0.0, 'fake': 0.0})
#
# ('28', {'msm': 0.0, 'fake': 0.0})
#
# ('29', {'msm': 0.0, 'fake': 0.0})
#
# ('2A', {'msm': 0.0, 'fake': 0.0})
#
# ('2nd', {'msm': 0.0, 'fake': 0.0})
#
# ('3', {'msm': 0.0, 'fake': 0.0})
#
# ('30', {'msm': 0.0, 'fake': 0.0})
#
# ('300', {'msm': 0.0, 'fake': 0.0})
#
# ('30day', {'msm': 0.0, 'fake': 0.0})
#
# ('35', {'msm': 0.0, 'fake': 0.0})
#
# ('3YrOld', {'msm': 0.0, 'fake': 0.0})
#
# ('3rd', {'msm': 0.0, 'fake': 0.0})
#
# ('4', {'msm': 0.0, 'fake': 0.0})
#
# ('40', {'msm': 0.0, 'fake': 0.0})
#
# ('400', {'msm': 0.0, 'fake': 0.0})
#
# ('43', {'msm': 0.0, 'fake': 0.0})
#
# ('44', {'msm': 0.0, 'fake': 0.0})
#
# ('45', {'msm': 0.0, 'fake': 0.0})
#
# ('4th', {'msm': 0.0, 'fake': 0.0})
#
# ('5', {'msm': 0.0, 'fake': 0.0})
#
# ('50', {'msm': 0.0, 'fake': 0.0})
#
# ('500', {'msm': 0.0, 'fake': 0.0})
#
# ('53', {'msm': 0.0, 'fake': 0.0})
#
# ('54', {'msm': 0.0, 'fake': 0.0})
#
# ('5G', {'msm': 0.0, 'fake': 0.0})
#
# ('6', {'msm': 0.0, 'fake': 0.0})
#
# ('60', {'msm': 0.0, 'fake': 0.0})
#
# ('65', {'msm': 0.0, 'fake': 0.0})
#
# ('7', {'msm': 0.0, 'fake': 0.0})
#
# ('70', {'msm': 0.0, 'fake': 0.0})
#
# ('700', {'msm': 0.0, 'fake': 0.0})
#
# ('71', {'msm': 0.0, 'fake': 0.0})
#
# ('75', {'msm': 0.0, 'fake': 0.0})
#
# ('76', {'msm': 0.0, 'fake': 0.0})
#
# ('7News', {'msm': 0.0, 'fake': 0.0})
#
# ('8', {'msm': 0.0, 'fake': 0.0})
#
# ('80', {'msm': 0.0, 'fake': 0.0})
#
# ('9', {'msm': 0.0, 'fake': 0.0})
#
# ('90', {'msm': 0.0, 'fake': 0.0})
#
# ('911', {'msm': 0.0, 'fake': 0.0})
#
# ('97', {'msm': 0.0, 'fake': 0.0})
#
# ('A', {'msm': 0.0, 'fake': 0.0})
#
# ('AAG', {'msm': 0.0, 'fake': 0.0})
#
# ('ABC', {'msm': 0.0, 'fake': 0.0})
#
# ('ABOUT', {'msm': 0.0, 'fake': 0.0})
#
# ('AG', {'msm': 0.0, 'fake': 0.0})
#
# ('AI', {'msm': 0.0, 'fake': 0.0})
#
# ('ALL', {'msm': 0.0, 'fake': 0.0})
#
# ('AMERICA', {'msm': 0.0, 'fake': 0.0})
#
# ('AMP', {'msm': 0.0, 'fake': 0.0})
#
# ('AND', {'msm': 0.0, 'fake': 0.0})
#
# ('AP', {'msm': 0.0, 'fake': 0.0})
#
# ('AR', {'msm': 0.0, 'fake': 0.0})
#
# ('AR15', {'msm': 0.0, 'fake': 0.0})
#
# ('ARE', {'msm': 0.0, 'fake': 0.0})
#
# ('ASSOCIATED', {'msm': 0.0, 'fake': 0.0})
#
# ('AT', {'msm': 0.0, 'fake': 0.0})
#
# ('AWAKE', {'msm': 0.0, 'fake': 0.0})
#
# ('About', {'msm': 0.0, 'fake': 0.0})
#
# ('Abuse', {'msm': 0.0, 'fake': 0.0})
#
# ('According', {'msm': 0.0, 'fake': 0.0})
#
# ('Accused', {'msm': 0.0, 'fake': 0.0})
#
# ('Across', {'msm': 0.0, 'fake': 0.0})
#
# ('Act', {'msm': 0.0, 'fake': 0.0})
#
# ('Action', {'msm': 0.0, 'fake': 0.0})
#
# ('Actions', {'msm': 0.0, 'fake': 0.0})
#
# ('Actor', {'msm': 0.0, 'fake': 0.0})
#
# ('Actress', {'msm': 0.0, 'fake': 0.0})
#
# ('Actually', {'msm': 0.0, 'fake': 0.0})
#
# ('Adam', {'msm': 0.0, 'fake': 0.0})
#
# ('Add', {'msm': 0.0, 'fake': 0.0})
#
# ('Administration', {'msm': 0.0, 'fake': 0.0})
#
# ('Admits', {'msm': 0.0, 'fake': 0.0})
#
# ('Afghanistan', {'msm': 0.0, 'fake': 0.0})
#
# ('Africa', {'msm': 0.0, 'fake': 0.0})
#
# ('African', {'msm': 0.0, 'fake': 0.0})
#
# ('After', {'msm': 0.0, 'fake': 0.0})
#
# ('Again', {'msm': 0.0, 'fake': 0.0})
#
# ('Against', {'msm': 0.0, 'fake': 0.0})
#
# ('Age', {'msm': 0.0, 'fake': 0.0})
#
# ('Agency', {'msm': 0.0, 'fake': 0.0})
#
# ('Agent', {'msm': 0.0, 'fake': 0.0})
#
# ('Agreement', {'msm': 0.0, 'fake': 0.0})
#
# ('Agrees', {'msm': 0.0, 'fake': 0.0})
#
# ('Aide', {'msm': 0.0, 'fake': 0.0})
#
# ('Air', {'msm': 0.0, 'fake': 0.0})
#
# ('Airbnb', {'msm': 0.0, 'fake': 0.0})
#
# ('Airlines', {'msm': 0.0, 'fake': 0.0})
#
# ('Alien', {'msm': 0.0, 'fake': 0.0})
#
# ('Aliens', {'msm': 0.0, 'fake': 0.0})
#
# ('All', {'msm': 0.0, 'fake': 0.0})
#
# ('Alleged', {'msm': 0.0, 'fake': 0.0})
#
# ('Also', {'msm': 0.0, 'fake': 0.0})
#
# ('Alternative', {'msm': 0.0, 'fake': 0.0})
#
# ('Always', {'msm': 0.0, 'fake': 0.0})
#
# ('Amazing', {'msm': 0.0, 'fake': 0.0})
#
# ('Amazon', {'msm': 0.0, 'fake': 0.0})
#
# ('Amendment', {'msm': 0.0, 'fake': 0.0})
#
# ('America', {'msm': 0.0, 'fake': 0.0})
#
# ('American', {'msm': 0.0, 'fake': 0.0})
#
# ('Americans', {'msm': 0.0, 'fake': 0.0})
#
# ('America’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Amid', {'msm': 0.0, 'fake': 0.0})
#
# ('An', {'msm': 0.0, 'fake': 0.0})
#
# ('Analysis', {'msm': 0.0, 'fake': 0.0})
#
# ('Anbang', {'msm': 0.0, 'fake': 0.0})
#
# ('Ancient', {'msm': 0.0, 'fake': 0.0})
#
# ('And', {'msm': 0.0, 'fake': 0.0})
#
# ('Andrew', {'msm': 0.0, 'fake': 0.0})
#
# ('Android', {'msm': 0.0, 'fake': 0.0})
#
# ('Angeles', {'msm': 0.0, 'fake': 0.0})
#
# ('Announces', {'msm': 0.0, 'fake': 0.0})
#
# ('Annual', {'msm': 0.0, 'fake': 0.0})
#
# ('Anon', {'msm': 0.0, 'fake': 0.0})
#
# ('Another', {'msm': 0.0, 'fake': 0.0})
#
# ('Antarctica', {'msm': 0.0, 'fake': 0.0})
#
# ('Any', {'msm': 0.0, 'fake': 0.0})
#
# ('Anyone', {'msm': 0.0, 'fake': 0.0})
#
# ('App', {'msm': 0.0, 'fake': 0.0})
#
# ('Apple', {'msm': 0.0, 'fake': 0.0})
#
# ('April', {'msm': 0.0, 'fake': 0.0})
#
# ('Arabia', {'msm': 0.0, 'fake': 0.0})
#
# ('Archaeologists', {'msm': 0.0, 'fake': 0.0})
#
# ('Archbishop', {'msm': 0.0, 'fake': 0.0})
#
# ('Arctic', {'msm': 0.0, 'fake': 0.0})
#
# ('Are', {'msm': 0.0, 'fake': 0.0})
#
# ('Area', {'msm': 0.0, 'fake': 0.0})
#
# ('Arizona', {'msm': 0.0, 'fake': 0.0})
#
# ('Arm', {'msm': 0.0, 'fake': 0.0})
#
# ('Armed', {'msm': 0.0, 'fake': 0.0})
#
# ('Arming', {'msm': 0.0, 'fake': 0.0})
#
# ('Army', {'msm': 0.0, 'fake': 0.0})
#
# ('Around', {'msm': 0.0, 'fake': 0.0})
#
# ('Arrest', {'msm': 0.0, 'fake': 0.0})
#
# ('Arrested', {'msm': 0.0, 'fake': 0.0})
#
# ('Art', {'msm': 0.0, 'fake': 0.0})
#
# ('Article', {'msm': 0.0, 'fake': 0.0})
#
# ('Artificial', {'msm': 0.0, 'fake': 0.0})
#
# ('ArtificialIntelligence', {'msm': 0.0, 'fake': 0.0})
#
# ('As', {'msm': 0.0, 'fake': 0.0})
#
# ('Asia', {'msm': 0.0, 'fake': 0.0})
#
# ('Asian', {'msm': 0.0, 'fake': 0.0})
#
# ('Ask', {'msm': 0.0, 'fake': 0.0})
#
# ('Asked', {'msm': 0.0, 'fake': 0.0})
#
# ('Assad', {'msm': 0.0, 'fake': 0.0})
#
# ('Assange', {'msm': 0.0, 'fake': 0.0})
#
# ('Assault', {'msm': 0.0, 'fake': 0.0})
#
# ('Association', {'msm': 0.0, 'fake': 0.0})
#
# ('At', {'msm': 0.0, 'fake': 0.0})
#
# ('Athletes', {'msm': 0.0, 'fake': 0.0})
#
# ('Atlanta', {'msm': 0.0, 'fake': 0.0})
#
# ('Atlantic', {'msm': 0.0, 'fake': 0.0})
#
# ('Attack', {'msm': 0.0, 'fake': 0.0})
#
# ('Attacks', {'msm': 0.0, 'fake': 0.0})
#
# ('Attorney', {'msm': 0.0, 'fake': 0.0})
#
# ('Australia', {'msm': 0.0, 'fake': 0.0})
#
# ('Australian', {'msm': 0.0, 'fake': 0.0})
#
# ('Author', {'msm': 0.0, 'fake': 0.0})
#
# ('Auto', {'msm': 0.0, 'fake': 0.0})
#
# ('Avoid', {'msm': 0.0, 'fake': 0.0})
#
# ('Awards', {'msm': 0.0, 'fake': 0.0})
#
# ('Away', {'msm': 0.0, 'fake': 0.0})
#
# ('BB4SP', {'msm': 0.0, 'fake': 0.0})
#
# ('BE', {'msm': 0.0, 'fake': 0.0})
#
# ('BIG', {'msm': 0.0, 'fake': 0.0})
#
# ('BREAKING', {'msm': 0.0, 'fake': 0.0})
#
# ('BS', {'msm': 0.0, 'fake': 0.0})
#
# ('BUSTED', {'msm': 0.0, 'fake': 0.0})
#
# ('Baby', {'msm': 0.0, 'fake': 0.0})
#
# ('Back', {'msm': 0.0, 'fake': 0.0})
#
# ('Bad', {'msm': 0.0, 'fake': 0.0})
#
# ('Ban', {'msm': 0.0, 'fake': 0.0})
#
# ('BanAssaultWeapons', {'msm': 0.0, 'fake': 0.0})
#
# ('Bank', {'msm': 0.0, 'fake': 0.0})
#
# ('Bankruptcy', {'msm': 0.0, 'fake': 0.0})
#
# ('Banks', {'msm': 0.0, 'fake': 0.0})
#
# ('Bans', {'msm': 0.0, 'fake': 0.0})
#
# ('Barack', {'msm': 0.0, 'fake': 0.0})
#
# ('Bay', {'msm': 0.0, 'fake': 0.0})
#
# ('Be', {'msm': 0.0, 'fake': 0.0})
#
# ('Bear', {'msm': 0.0, 'fake': 0.0})
#
# ('Beast', {'msm': 0.0, 'fake': 0.0})
#
# ('Beat', {'msm': 0.0, 'fake': 0.0})
#
# ('Because', {'msm': 0.0, 'fake': 0.0})
#
# ('Become', {'msm': 0.0, 'fake': 0.0})
#
# ('Becoming', {'msm': 0.0, 'fake': 0.0})
#
# ('Been', {'msm': 0.0, 'fake': 0.0})
#
# ('Before', {'msm': 0.0, 'fake': 0.0})
#
# ('Behind', {'msm': 0.0, 'fake': 0.0})
#
# ('Beijing', {'msm': 0.0, 'fake': 0.0})
#
# ('Being', {'msm': 0.0, 'fake': 0.0})
#
# ('Believe', {'msm': 0.0, 'fake': 0.0})
#
# ('Benedict', {'msm': 0.0, 'fake': 0.0})
#
# ('Berkshire', {'msm': 0.0, 'fake': 0.0})
#
# ('Berlin', {'msm': 0.0, 'fake': 0.0})
#
# ('Bernie', {'msm': 0.0, 'fake': 0.0})
#
# ('Best', {'msm': 0.0, 'fake': 0.0})
#
# ('Better', {'msm': 0.0, 'fake': 0.0})
#
# ('Between', {'msm': 0.0, 'fake': 0.0})
#
# ('Beyond', {'msm': 0.0, 'fake': 0.0})
#
# ('Bible', {'msm': 0.0, 'fake': 0.0})
#
# ('Bid', {'msm': 0.0, 'fake': 0.0})
#
# ('Big', {'msm': 0.0, 'fake': 0.0})
#
# ('BigData', {'msm': 0.0, 'fake': 0.0})
#
# ('Biggest', {'msm': 0.0, 'fake': 0.0})
#
# ('Bill', {'msm': 0.0, 'fake': 0.0})
#
# ('Billion', {'msm': 0.0, 'fake': 0.0})
#
# ('Billionaire', {'msm': 0.0, 'fake': 0.0})
#
# ('Billy', {'msm': 0.0, 'fake': 0.0})
#
# ('Bitcoin', {'msm': 0.0, 'fake': 0.0})
#
# ('Black', {'msm': 0.0, 'fake': 0.0})
#
# ('BlackPanther', {'msm': 0.0, 'fake': 0.0})
#
# ('Blockchain', {'msm': 0.0, 'fake': 0.0})
#
# ('Bloomberg', {'msm': 0.0, 'fake': 0.0})
#
# ('Blows', {'msm': 0.0, 'fake': 0.0})
#
# ('Blue', {'msm': 0.0, 'fake': 0.0})
#
# ('Board', {'msm': 0.0, 'fake': 0.0})
#
# ('Body', {'msm': 0.0, 'fake': 0.0})
#
# ('Boko', {'msm': 0.0, 'fake': 0.0})
#
# ('Bollywood', {'msm': 0.0, 'fake': 0.0})
#
# ('Bomb', {'msm': 0.0, 'fake': 0.0})
#
# ('Bombshell', {'msm': 0.0, 'fake': 0.0})
#
# ('Book', {'msm': 0.0, 'fake': 0.0})
#
# ('Books', {'msm': 0.0, 'fake': 0.0})
#
# ('Border', {'msm': 0.0, 'fake': 0.0})
#
# ('Boss', {'msm': 0.0, 'fake': 0.0})
#
# ('Boston', {'msm': 0.0, 'fake': 0.0})
#
# ('Both', {'msm': 0.0, 'fake': 0.0})
#
# ('Box', {'msm': 0.0, 'fake': 0.0})
#
# ('Boy', {'msm': 0.0, 'fake': 0.0})
#
# ('Boycott', {'msm': 0.0, 'fake': 0.0})
#
# ('BoycottNRA', {'msm': 0.0, 'fake': 0.0})
#
# ('Boys', {'msm': 0.0, 'fake': 0.0})
#
# ('Brain', {'msm': 0.0, 'fake': 0.0})
#
# ('Brand', {'msm': 0.0, 'fake': 0.0})
#
# ('Brazil', {'msm': 0.0, 'fake': 0.0})
#
# ('Break', {'msm': 0.0, 'fake': 0.0})
#
# ('Breaking', {'msm': 0.0, 'fake': 0.0})
#
# ('Breaks', {'msm': 0.0, 'fake': 0.0})
#
# ('Brexit', {'msm': 0.0, 'fake': 0.0})
#
# ('Briefing', {'msm': 0.0, 'fake': 0.0})
#
# ('Bring', {'msm': 0.0, 'fake': 0.0})
#
# ('Britain', {'msm': 0.0, 'fake': 0.0})
#
# ('British', {'msm': 0.0, 'fake': 0.0})
#
# ('Broadcom', {'msm': 0.0, 'fake': 0.0})
#
# ('Broward', {'msm': 0.0, 'fake': 0.0})
#
# ('Brown', {'msm': 0.0, 'fake': 0.0})
#
# ('Brutal', {'msm': 0.0, 'fake': 0.0})
#
# ('Buffett', {'msm': 0.0, 'fake': 0.0})
#
# ('Building', {'msm': 0.0, 'fake': 0.0})
#
# ('Bush', {'msm': 0.0, 'fake': 0.0})
#
# ('Business', {'msm': 0.0, 'fake': 0.0})
#
# ('Busted', {'msm': 0.0, 'fake': 0.0})
#
# ('But', {'msm': 0.0, 'fake': 0.0})
#
# ('Buy', {'msm': 0.0, 'fake': 0.0})
#
# ('By', {'msm': 0.0, 'fake': 0.0})
#
# ('C', {'msm': 0.0, 'fake': 0.0})
#
# ('CA', {'msm': 0.0, 'fake': 0.0})
#
# ('CBS', {'msm': 0.0, 'fake': 0.0})
#
# ('CDC', {'msm': 0.0, 'fake': 0.0})
#
# ('CEO', {'msm': 0.0, 'fake': 0.0})
#
# ('CEOs', {'msm': 0.0, 'fake': 0.0})
#
# ('CFO', {'msm': 0.0, 'fake': 0.0})
#
# ('CIA', {'msm': 0.0, 'fake': 0.0})
#
# ('CNBC', {'msm': 0.0, 'fake': 0.0})
#
# ('CNN', {'msm': 0.0, 'fake': 0.0})
#
# ('CNNMoney', {'msm': 0.0, 'fake': 0.0})
#
# ('CNNPolitics', {'msm': 0.0, 'fake': 0.0})
#
# ('CPAC', {'msm': 0.0, 'fake': 0.0})
#
# ('CPAC2018', {'msm': 0.0, 'fake': 0.0})
#
# ('California', {'msm': 0.0, 'fake': 0.0})
#
# ('Call', {'msm': 0.0, 'fake': 0.0})
#
# ('Called', {'msm': 0.0, 'fake': 0.0})
#
# ('Calls', {'msm': 0.0, 'fake': 0.0})
#
# ('Camera', {'msm': 0.0, 'fake': 0.0})
#
# ('Camp', {'msm': 0.0, 'fake': 0.0})
#
# ('Campaign', {'msm': 0.0, 'fake': 0.0})
#
# ('Can', {'msm': 0.0, 'fake': 0.0})
#
# ('Canada', {'msm': 0.0, 'fake': 0.0})
#
# ('Canadian', {'msm': 0.0, 'fake': 0.0})
#
# ('Cancer', {'msm': 0.0, 'fake': 0.0})
#
# ('Cannabis', {'msm': 0.0, 'fake': 0.0})
#
# ('Cant', {'msm': 0.0, 'fake': 0.0})
#
# ('Can’t', {'msm': 0.0, 'fake': 0.0})
#
# ('Capital', {'msm': 0.0, 'fake': 0.0})
#
# ('Capitol', {'msm': 0.0, 'fake': 0.0})
#
# ('Car', {'msm': 0.0, 'fake': 0.0})
#
# ('Care', {'msm': 0.0, 'fake': 0.0})
#
# ('Career', {'msm': 0.0, 'fake': 0.0})
#
# ('Carolina', {'msm': 0.0, 'fake': 0.0})
#
# ('Carter', {'msm': 0.0, 'fake': 0.0})
#
# ('Case', {'msm': 0.0, 'fake': 0.0})
#
# ('Castro', {'msm': 0.0, 'fake': 0.0})
#
# ('Castro’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Catholic', {'msm': 0.0, 'fake': 0.0})
#
# ('Caught', {'msm': 0.0, 'fake': 0.0})
#
# ('Caused', {'msm': 0.0, 'fake': 0.0})
#
# ('Celebrity', {'msm': 0.0, 'fake': 0.0})
#
# ('Center', {'msm': 0.0, 'fake': 0.0})
#
# ('Central', {'msm': 0.0, 'fake': 0.0})
#
# ('Ceremony', {'msm': 0.0, 'fake': 0.0})
#
# ('Chairman', {'msm': 0.0, 'fake': 0.0})
#
# ('Chambers', {'msm': 0.0, 'fake': 0.0})
#
# ('Change', {'msm': 0.0, 'fake': 0.0})
#
# ('Changed', {'msm': 0.0, 'fake': 0.0})
#
# ('Changes', {'msm': 0.0, 'fake': 0.0})
#
# ('Channel', {'msm': 0.0, 'fake': 0.0})
#
# ('Charges', {'msm': 0.0, 'fake': 0.0})
#
# ('Check', {'msm': 0.0, 'fake': 0.0})
#
# ('Chicago', {'msm': 0.0, 'fake': 0.0})
#
# ('Chief', {'msm': 0.0, 'fake': 0.0})
#
# ('Child', {'msm': 0.0, 'fake': 0.0})
#
# ('Children', {'msm': 0.0, 'fake': 0.0})
#
# ('China', {'msm': 0.0, 'fake': 0.0})
#
# ('China’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Chinese', {'msm': 0.0, 'fake': 0.0})
#
# ('Chris', {'msm': 0.0, 'fake': 0.0})
#
# ('Christian', {'msm': 0.0, 'fake': 0.0})
#
# ('Christians', {'msm': 0.0, 'fake': 0.0})
#
# ('Chubb', {'msm': 0.0, 'fake': 0.0})
#
# ('Church', {'msm': 0.0, 'fake': 0.0})
#
# ('Circle', {'msm': 0.0, 'fake': 0.0})
#
# ('City', {'msm': 0.0, 'fake': 0.0})
#
# ('Civil', {'msm': 0.0, 'fake': 0.0})
#
# ('Claim', {'msm': 0.0, 'fake': 0.0})
#
# ('Claimed', {'msm': 0.0, 'fake': 0.0})
#
# ('Claiming', {'msm': 0.0, 'fake': 0.0})
#
# ('Claims', {'msm': 0.0, 'fake': 0.0})
#
# ('Classic', {'msm': 0.0, 'fake': 0.0})
#
# ('Climate', {'msm': 0.0, 'fake': 0.0})
#
# ('Clinton', {'msm': 0.0, 'fake': 0.0})
#
# ('Clintons', {'msm': 0.0, 'fake': 0.0})
#
# ('Closing', {'msm': 0.0, 'fake': 0.0})
#
# ('Cloud', {'msm': 0.0, 'fake': 0.0})
#
# ('Club', {'msm': 0.0, 'fake': 0.0})
#
# ('Co', {'msm': 0.0, 'fake': 0.0})
#
# ('Coal', {'msm': 0.0, 'fake': 0.0})
#
# ('Coast', {'msm': 0.0, 'fake': 0.0})
#
# ('College', {'msm': 0.0, 'fake': 0.0})
#
# ('Collusion', {'msm': 0.0, 'fake': 0.0})
#
# ('Come', {'msm': 0.0, 'fake': 0.0})
#
# ('Comey', {'msm': 0.0, 'fake': 0.0})
#
# ('Coming', {'msm': 0.0, 'fake': 0.0})
#
# ('Committee', {'msm': 0.0, 'fake': 0.0})
#
# ('Common', {'msm': 0.0, 'fake': 0.0})
#
# ('Communist', {'msm': 0.0, 'fake': 0.0})
#
# ('Community', {'msm': 0.0, 'fake': 0.0})
#
# ('Companies', {'msm': 0.0, 'fake': 0.0})
#
# ('Company', {'msm': 0.0, 'fake': 0.0})
#
# ('Conference', {'msm': 0.0, 'fake': 0.0})
#
# ('Confirms', {'msm': 0.0, 'fake': 0.0})
#
# ('Congress', {'msm': 0.0, 'fake': 0.0})
#
# ('Congressional', {'msm': 0.0, 'fake': 0.0})
#
# ('Conservative', {'msm': 0.0, 'fake': 0.0})
#
# ('Conservatives', {'msm': 0.0, 'fake': 0.0})
#
# ('Considers', {'msm': 0.0, 'fake': 0.0})
#
# ('Conspiracy', {'msm': 0.0, 'fake': 0.0})
#
# ('Constitution', {'msm': 0.0, 'fake': 0.0})
#
# ('Content', {'msm': 0.0, 'fake': 0.0})
#
# ('Continues', {'msm': 0.0, 'fake': 0.0})
#
# ('Control', {'msm': 0.0, 'fake': 0.0})
#
# ('Cooper', {'msm': 0.0, 'fake': 0.0})
#
# ('Cop', {'msm': 0.0, 'fake': 0.0})
#
# ('Cops', {'msm': 0.0, 'fake': 0.0})
#
# ('Corbyn', {'msm': 0.0, 'fake': 0.0})
#
# ('Corporate', {'msm': 0.0, 'fake': 0.0})
#
# ('Corruption', {'msm': 0.0, 'fake': 0.0})
#
# ('Cost', {'msm': 0.0, 'fake': 0.0})
#
# ('Could', {'msm': 0.0, 'fake': 0.0})
#
# ('CouldBeatTrumpIn2020', {'msm': 0.0, 'fake': 0.0})
#
# ('Council', {'msm': 0.0, 'fake': 0.0})
#
# ('Country', {'msm': 0.0, 'fake': 0.0})
#
# ('County', {'msm': 0.0, 'fake': 0.0})
#
# ('Couple', {'msm': 0.0, 'fake': 0.0})
#
# ('Court', {'msm': 0.0, 'fake': 0.0})
#
# ('Cover', {'msm': 0.0, 'fake': 0.0})
#
# ('Crash', {'msm': 0.0, 'fake': 0.0})
#
# ('Criminal', {'msm': 0.0, 'fake': 0.0})
#
# ('Crisis', {'msm': 0.0, 'fake': 0.0})
#
# ('CrisisActors', {'msm': 0.0, 'fake': 0.0})
#
# ('Cruz', {'msm': 0.0, 'fake': 0.0})
#
# ('Crypto', {'msm': 0.0, 'fake': 0.0})
#
# ('Cryptocurrency', {'msm': 0.0, 'fake': 0.0})
#
# ('Cuba', {'msm': 0.0, 'fake': 0.0})
#
# ('Cuban', {'msm': 0.0, 'fake': 0.0})
#
# ('Culture', {'msm': 0.0, 'fake': 0.0})
#
# ('Cunningham', {'msm': 0.0, 'fake': 0.0})
#
# ('Cup', {'msm': 0.0, 'fake': 0.0})
#
# ('Cure', {'msm': 0.0, 'fake': 0.0})
#
# ('Curling', {'msm': 0.0, 'fake': 0.0})
#
# ('Customer', {'msm': 0.0, 'fake': 0.0})
#
# ('Cut', {'msm': 0.0, 'fake': 0.0})
#
# ('Cuts', {'msm': 0.0, 'fake': 0.0})
#
# ('Cutting', {'msm': 0.0, 'fake': 0.0})
#
# ('Cyber', {'msm': 0.0, 'fake': 0.0})
#
# ('DACA', {'msm': 0.0, 'fake': 0.0})
#
# ('DC', {'msm': 0.0, 'fake': 0.0})
#
# ('DNA', {'msm': 0.0, 'fake': 0.0})
#
# ('DNC', {'msm': 0.0, 'fake': 0.0})
#
# ('DO', {'msm': 0.0, 'fake': 0.0})
#
# ('DOJ', {'msm': 0.0, 'fake': 0.0})
#
# ('DONT', {'msm': 0.0, 'fake': 0.0})
#
# ('Dad', {'msm': 0.0, 'fake': 0.0})
#
# ('Daily', {'msm': 0.0, 'fake': 0.0})
#
# ('DailyNews', {'msm': 0.0, 'fake': 0.0})
#
# ('Daimler', {'msm': 0.0, 'fake': 0.0})
#
# ('Dallas', {'msm': 0.0, 'fake': 0.0})
#
# ('Damascus', {'msm': 0.0, 'fake': 0.0})
#
# ('Dana', {'msm': 0.0, 'fake': 0.0})
#
# ('Dangerous', {'msm': 0.0, 'fake': 0.0})
#
# ('Dark', {'msm': 0.0, 'fake': 0.0})
#
# ('Data', {'msm': 0.0, 'fake': 0.0})
#
# ('Daughter', {'msm': 0.0, 'fake': 0.0})
#
# ('David', {'msm': 0.0, 'fake': 0.0})
#
# ('Day', {'msm': 0.0, 'fake': 0.0})
#
# ('Days', {'msm': 0.0, 'fake': 0.0})
#
# ('De', {'msm': 0.0, 'fake': 0.0})
#
# ('Dead', {'msm': 0.0, 'fake': 0.0})
#
# ('Deadly', {'msm': 0.0, 'fake': 0.0})
#
# ('Deal', {'msm': 0.0, 'fake': 0.0})
#
# ('Dear', {'msm': 0.0, 'fake': 0.0})
#
# ('Death', {'msm': 0.0, 'fake': 0.0})
#
# ('Deaths', {'msm': 0.0, 'fake': 0.0})
#
# ('Debate', {'msm': 0.0, 'fake': 0.0})
#
# ('Deep', {'msm': 0.0, 'fake': 0.0})
#
# ('DeepLearning', {'msm': 0.0, 'fake': 0.0})
#
# ('Defense', {'msm': 0.0, 'fake': 0.0})
#
# ('Degas', {'msm': 0.0, 'fake': 0.0})
#
# ('Delta', {'msm': 0.0, 'fake': 0.0})
#
# ('Dem', {'msm': 0.0, 'fake': 0.0})
#
# ('Demand', {'msm': 0.0, 'fake': 0.0})
#
# ('Demands', {'msm': 0.0, 'fake': 0.0})
#
# ('Democrat', {'msm': 0.0, 'fake': 0.0})
#
# ('DemocratMemo', {'msm': 0.0, 'fake': 0.0})
#
# ('Democratic', {'msm': 0.0, 'fake': 0.0})
#
# ('Democrats', {'msm': 0.0, 'fake': 0.0})
#
# ('Dems', {'msm': 0.0, 'fake': 0.0})
#
# ('Denzel', {'msm': 0.0, 'fake': 0.0})
#
# ('Department', {'msm': 0.0, 'fake': 0.0})
#
# ('Dept', {'msm': 0.0, 'fake': 0.0})
#
# ('Deputy', {'msm': 0.0, 'fake': 0.0})
#
# ('Despite', {'msm': 0.0, 'fake': 0.0})
#
# ('Devin', {'msm': 0.0, 'fake': 0.0})
#
# ('Dianne', {'msm': 0.0, 'fake': 0.0})
#
# ('Did', {'msm': 0.0, 'fake': 0.0})
#
# ('Didnt', {'msm': 0.0, 'fake': 0.0})
#
# ('Didn’t', {'msm': 0.0, 'fake': 0.0})
#
# ('Diego', {'msm': 0.0, 'fake': 0.0})
#
# ('Dies', {'msm': 0.0, 'fake': 0.0})
#
# ('Different', {'msm': 0.0, 'fake': 0.0})
#
# ('Digital', {'msm': 0.0, 'fake': 0.0})
#
# ('Director', {'msm': 0.0, 'fake': 0.0})
#
# ('Dirty', {'msm': 0.0, 'fake': 0.0})
#
# ('DisClose', {'msm': 0.0, 'fake': 0.0})
#
# ('DiscloseTVwww', {'msm': 0.0, 'fake': 0.0})
#
# ('Discovered', {'msm': 0.0, 'fake': 0.0})
#
# ('Disease', {'msm': 0.0, 'fake': 0.0})
#
# ('Disgusting', {'msm': 0.0, 'fake': 0.0})
#
# ('Disney', {'msm': 0.0, 'fake': 0.0})
#
# ('Do', {'msm': 0.0, 'fake': 0.0})
#
# ('Doctor', {'msm': 0.0, 'fake': 0.0})
#
# ('Doctors', {'msm': 0.0, 'fake': 0.0})
#
# ('Documents', {'msm': 0.0, 'fake': 0.0})
#
# ('Does', {'msm': 0.0, 'fake': 0.0})
#
# ('Doesnt', {'msm': 0.0, 'fake': 0.0})
#
# ('Dog', {'msm': 0.0, 'fake': 0.0})
#
# ('Doing', {'msm': 0.0, 'fake': 0.0})
#
# ('Dollar', {'msm': 0.0, 'fake': 0.0})
#
# ('Domestic', {'msm': 0.0, 'fake': 0.0})
#
# ('Don', {'msm': 0.0, 'fake': 0.0})
#
# ('Donald', {'msm': 0.0, 'fake': 0.0})
#
# ('DonaldTrump', {'msm': 0.0, 'fake': 0.0})
#
# ('Dont', {'msm': 0.0, 'fake': 0.0})
#
# ('Don’t', {'msm': 0.0, 'fake': 0.0})
#
# ('Dossier', {'msm': 0.0, 'fake': 0.0})
#
# ('Douglas', {'msm': 0.0, 'fake': 0.0})
#
# ('Down', {'msm': 0.0, 'fake': 0.0})
#
# ('Dr', {'msm': 0.0, 'fake': 0.0})
#
# ('Dreamer', {'msm': 0.0, 'fake': 0.0})
#
# ('Dreamers', {'msm': 0.0, 'fake': 0.0})
#
# ('Drinking', {'msm': 0.0, 'fake': 0.0})
#
# ('Drive', {'msm': 0.0, 'fake': 0.0})
#
# ('Dropbox', {'msm': 0.0, 'fake': 0.0})
#
# ('Drops', {'msm': 0.0, 'fake': 0.0})
#
# ('Drug', {'msm': 0.0, 'fake': 0.0})
#
# ('Drugs', {'msm': 0.0, 'fake': 0.0})
#
# ('Dubai', {'msm': 0.0, 'fake': 0.0})
#
# ('During', {'msm': 0.0, 'fake': 0.0})
#
# ('E', {'msm': 0.0, 'fake': 0.0})
#
# ('ECB', {'msm': 0.0, 'fake': 0.0})
#
# ('EMETNEWSPRESS', {'msm': 0.0, 'fake': 0.0})
#
# ('EU', {'msm': 0.0, 'fake': 0.0})
#
# ('EXCLUSIVE', {'msm': 0.0, 'fake': 0.0})
#
# ('Early', {'msm': 0.0, 'fake': 0.0})
#
# ('Earth', {'msm': 0.0, 'fake': 0.0})
#
# ('East', {'msm': 0.0, 'fake': 0.0})
#
# ('Eastern', {'msm': 0.0, 'fake': 0.0})
#
# ('Eat', {'msm': 0.0, 'fake': 0.0})
#
# ('Eating', {'msm': 0.0, 'fake': 0.0})
#
# ('Economic', {'msm': 0.0, 'fake': 0.0})
#
# ('Economy', {'msm': 0.0, 'fake': 0.0})
#
# ('Education', {'msm': 0.0, 'fake': 0.0})
#
# ('Egypt', {'msm': 0.0, 'fake': 0.0})
#
# ('El', {'msm': 0.0, 'fake': 0.0})
#
# ('Election', {'msm': 0.0, 'fake': 0.0})
#
# ('Elections', {'msm': 0.0, 'fake': 0.0})
#
# ('Electric', {'msm': 0.0, 'fake': 0.0})
#
# ('Elite', {'msm': 0.0, 'fake': 0.0})
#
# ('Elizabeth', {'msm': 0.0, 'fake': 0.0})
#
# ('Elon', {'msm': 0.0, 'fake': 0.0})
#
# ('Email', {'msm': 0.0, 'fake': 0.0})
#
# ('Embassy', {'msm': 0.0, 'fake': 0.0})
#
# ('Emma', {'msm': 0.0, 'fake': 0.0})
#
# ('Employee', {'msm': 0.0, 'fake': 0.0})
#
# ('Employees', {'msm': 0.0, 'fake': 0.0})
#
# ('End', {'msm': 0.0, 'fake': 0.0})
#
# ('Energy', {'msm': 0.0, 'fake': 0.0})
#
# ('England', {'msm': 0.0, 'fake': 0.0})
#
# ('English', {'msm': 0.0, 'fake': 0.0})
#
# ('Enough', {'msm': 0.0, 'fake': 0.0})
#
# ('Enterprise', {'msm': 0.0, 'fake': 0.0})
#
# ('Entire', {'msm': 0.0, 'fake': 0.0})
#
# ('Entrepreneur', {'msm': 0.0, 'fake': 0.0})
#
# ('Entrepreneurs', {'msm': 0.0, 'fake': 0.0})
#
# ('Epic', {'msm': 0.0, 'fake': 0.0})
#
# ('Epidemic', {'msm': 0.0, 'fake': 0.0})
#
# ('Eric', {'msm': 0.0, 'fake': 0.0})
#
# ('Ester', {'msm': 0.0, 'fake': 0.0})
#
# ('Europe', {'msm': 0.0, 'fake': 0.0})
#
# ('European', {'msm': 0.0, 'fake': 0.0})
#
# ('Even', {'msm': 0.0, 'fake': 0.0})
#
# ('Event', {'msm': 0.0, 'fake': 0.0})
#
# ('Ever', {'msm': 0.0, 'fake': 0.0})
#
# ('Every', {'msm': 0.0, 'fake': 0.0})
#
# ('Everyone', {'msm': 0.0, 'fake': 0.0})
#
# ('Everything', {'msm': 0.0, 'fake': 0.0})
#
# ('Evidence', {'msm': 0.0, 'fake': 0.0})
#
# ('Evil', {'msm': 0.0, 'fake': 0.0})
#
# ('Exactly', {'msm': 0.0, 'fake': 0.0})
#
# ('Excellent', {'msm': 0.0, 'fake': 0.0})
#
# ('Exclusive', {'msm': 0.0, 'fake': 0.0})
#
# ('Executive', {'msm': 0.0, 'fake': 0.0})
#
# ('Experts', {'msm': 0.0, 'fake': 0.0})
#
# ('Exposed', {'msm': 0.0, 'fake': 0.0})
#
# ('Exposes', {'msm': 0.0, 'fake': 0.0})
#
# ('FBI', {'msm': 0.0, 'fake': 0.0})
#
# ('FBIControl', {'msm': 0.0, 'fake': 0.0})
#
# ('FBIReformNow', {'msm': 0.0, 'fake': 0.0})
#
# ('FCC', {'msm': 0.0, 'fake': 0.0})
#
# ('FDA', {'msm': 0.0, 'fake': 0.0})
#
# ('FEMA', {'msm': 0.0, 'fake': 0.0})
#
# ('FISA', {'msm': 0.0, 'fake': 0.0})
#
# ('FISAMemo', {'msm': 0.0, 'fake': 0.0})
#
# ('FL', {'msm': 0.0, 'fake': 0.0})
#
# ('FOR', {'msm': 0.0, 'fake': 0.0})
#
# ('FOX', {'msm': 0.0, 'fake': 0.0})
#
# ('FROM', {'msm': 0.0, 'fake': 0.0})
#
# ('FYI', {'msm': 0.0, 'fake': 0.0})
#
# ('Fabray', {'msm': 0.0, 'fake': 0.0})
#
# ('Face', {'msm': 0.0, 'fake': 0.0})
#
# ('Facebook', {'msm': 0.0, 'fake': 0.0})
#
# ('Faces', {'msm': 0.0, 'fake': 0.0})
#
# ('Facts', {'msm': 0.0, 'fake': 0.0})
#
# ('Fake', {'msm': 0.0, 'fake': 0.0})
#
# ('FakeNews', {'msm': 0.0, 'fake': 0.0})
#
# ('Falls', {'msm': 0.0, 'fake': 0.0})
#
# ('False', {'msm': 0.0, 'fake': 0.0})
#
# ('Family', {'msm': 0.0, 'fake': 0.0})
#
# ('Fashion', {'msm': 0.0, 'fake': 0.0})
#
# ('Father', {'msm': 0.0, 'fake': 0.0})
#
# ('Fear', {'msm': 0.0, 'fake': 0.0})
#
# ('Feb', {'msm': 0.0, 'fake': 0.0})
#
# ('February', {'msm': 0.0, 'fake': 0.0})
#
# ('Fed', {'msm': 0.0, 'fake': 0.0})
#
# ('Federal', {'msm': 0.0, 'fake': 0.0})
#
# ('Feinstein', {'msm': 0.0, 'fake': 0.0})
#
# ('Female', {'msm': 0.0, 'fake': 0.0})
#
# ('Festival', {'msm': 0.0, 'fake': 0.0})
#
# ('Fidel', {'msm': 0.0, 'fake': 0.0})
#
# ('Fight', {'msm': 0.0, 'fake': 0.0})
#
# ('Fights', {'msm': 0.0, 'fake': 0.0})
#
# ('Figure', {'msm': 0.0, 'fake': 0.0})
#
# ('Files', {'msm': 0.0, 'fake': 0.0})
#
# ('Film', {'msm': 0.0, 'fake': 0.0})
#
# ('Final', {'msm': 0.0, 'fake': 0.0})
#
# ('Finally', {'msm': 0.0, 'fake': 0.0})
#
# ('Finance', {'msm': 0.0, 'fake': 0.0})
#
# ('Financial', {'msm': 0.0, 'fake': 0.0})
#
# ('Find', {'msm': 0.0, 'fake': 0.0})
#
# ('Finds', {'msm': 0.0, 'fake': 0.0})
#
# ('Fintech', {'msm': 0.0, 'fake': 0.0})
#
# ('Fire', {'msm': 0.0, 'fake': 0.0})
#
# ('Fired', {'msm': 0.0, 'fake': 0.0})
#
# ('First', {'msm': 0.0, 'fake': 0.0})
#
# ('FisaMemo', {'msm': 0.0, 'fake': 0.0})
#
# ('Five', {'msm': 0.0, 'fake': 0.0})
#
# ('Fla', {'msm': 0.0, 'fake': 0.0})
#
# ('Flag', {'msm': 0.0, 'fake': 0.0})
#
# ('Flight', {'msm': 0.0, 'fake': 0.0})
#
# ('Florida', {'msm': 0.0, 'fake': 0.0})
#
# ('Flu', {'msm': 0.0, 'fake': 0.0})
#
# ('Flynn', {'msm': 0.0, 'fake': 0.0})
#
# ('Follow', {'msm': 0.0, 'fake': 0.0})
#
# ('FollowTheWhiteRabbit', {'msm': 0.0, 'fake': 0.0})
#
# ('Food', {'msm': 0.0, 'fake': 0.0})
#
# ('Foods', {'msm': 0.0, 'fake': 0.0})
#
# ('Footage', {'msm': 0.0, 'fake': 0.0})
#
# ('For', {'msm': 0.0, 'fake': 0.0})
#
# ('Forbes', {'msm': 0.0, 'fake': 0.0})
#
# ('Force', {'msm': 0.0, 'fake': 0.0})
#
# ('Forced', {'msm': 0.0, 'fake': 0.0})
#
# ('Forces', {'msm': 0.0, 'fake': 0.0})
#
# ('Foreign', {'msm': 0.0, 'fake': 0.0})
#
# ('Forget', {'msm': 0.0, 'fake': 0.0})
#
# ('Former', {'msm': 0.0, 'fake': 0.0})
#
# ('Found', {'msm': 0.0, 'fake': 0.0})
#
# ('Foundation', {'msm': 0.0, 'fake': 0.0})
#
# ('Four', {'msm': 0.0, 'fake': 0.0})
#
# ('Fox', {'msm': 0.0, 'fake': 0.0})
#
# ('FoxNews', {'msm': 0.0, 'fake': 0.0})
#
# ('France', {'msm': 0.0, 'fake': 0.0})
#
# ('Francis', {'msm': 0.0, 'fake': 0.0})
#
# ('Francisco', {'msm': 0.0, 'fake': 0.0})
#
# ('Fraud', {'msm': 0.0, 'fake': 0.0})
#
# ('Freak', {'msm': 0.0, 'fake': 0.0})
#
# ('Free', {'msm': 0.0, 'fake': 0.0})
#
# ('Freedom', {'msm': 0.0, 'fake': 0.0})
#
# ('French', {'msm': 0.0, 'fake': 0.0})
#
# ('Friday', {'msm': 0.0, 'fake': 0.0})
#
# ('From', {'msm': 0.0, 'fake': 0.0})
#
# ('Frozen', {'msm': 0.0, 'fake': 0.0})
#
# ('Full', {'msm': 0.0, 'fake': 0.0})
#
# ('Fund', {'msm': 0.0, 'fake': 0.0})
#
# ('Funds', {'msm': 0.0, 'fake': 0.0})
#
# ('Future', {'msm': 0.0, 'fake': 0.0})
#
# ('GE', {'msm': 0.0, 'fake': 0.0})
#
# ('GO', {'msm': 0.0, 'fake': 0.0})
#
# ('GOP', {'msm': 0.0, 'fake': 0.0})
#
# ('Galaxy', {'msm': 0.0, 'fake': 0.0})
#
# ('Game', {'msm': 0.0, 'fake': 0.0})
#
# ('Games', {'msm': 0.0, 'fake': 0.0})
#
# ('Gates', {'msm': 0.0, 'fake': 0.0})
#
# ('Gay', {'msm': 0.0, 'fake': 0.0})
#
# ('Geely', {'msm': 0.0, 'fake': 0.0})
#
# ('General', {'msm': 0.0, 'fake': 0.0})
#
# ('George', {'msm': 0.0, 'fake': 0.0})
#
# ('Georgia', {'msm': 0.0, 'fake': 0.0})
#
# ('German', {'msm': 0.0, 'fake': 0.0})
#
# ('Germany', {'msm': 0.0, 'fake': 0.0})
#
# ('Get', {'msm': 0.0, 'fake': 0.0})
#
# ('Gets', {'msm': 0.0, 'fake': 0.0})
#
# ('Getting', {'msm': 0.0, 'fake': 0.0})
#
# ('Ghouta', {'msm': 0.0, 'fake': 0.0})
#
# ('Giant', {'msm': 0.0, 'fake': 0.0})
#
# ('Girl', {'msm': 0.0, 'fake': 0.0})
#
# ('Girls', {'msm': 0.0, 'fake': 0.0})
#
# ('Give', {'msm': 0.0, 'fake': 0.0})
#
# ('Given', {'msm': 0.0, 'fake': 0.0})
#
# ('Gives', {'msm': 0.0, 'fake': 0.0})
#
# ('Glad', {'msm': 0.0, 'fake': 0.0})
#
# ('Global', {'msm': 0.0, 'fake': 0.0})
#
# ('Go', {'msm': 0.0, 'fake': 0.0})
#
# ('God', {'msm': 0.0, 'fake': 0.0})
#
# ('Goes', {'msm': 0.0, 'fake': 0.0})
#
# ('Going', {'msm': 0.0, 'fake': 0.0})
#
# ('Gold', {'msm': 0.0, 'fake': 0.0})
#
# ('Golden', {'msm': 0.0, 'fake': 0.0})
#
# ('Goldman', {'msm': 0.0, 'fake': 0.0})
#
# ('Good', {'msm': 0.0, 'fake': 0.0})
#
# ('Google', {'msm': 0.0, 'fake': 0.0})
#
# ('Got', {'msm': 0.0, 'fake': 0.0})
#
# ('Gov', {'msm': 0.0, 'fake': 0.0})
#
# ('Government', {'msm': 0.0, 'fake': 0.0})
#
# ('Governments', {'msm': 0.0, 'fake': 0.0})
#
# ('Governor', {'msm': 0.0, 'fake': 0.0})
#
# ('Govt', {'msm': 0.0, 'fake': 0.0})
#
# ('Gowdy', {'msm': 0.0, 'fake': 0.0})
#
# ('Graham', {'msm': 0.0, 'fake': 0.0})
#
# ('Grand', {'msm': 0.0, 'fake': 0.0})
#
# ('Great', {'msm': 0.0, 'fake': 0.0})
#
# ('GreatAwakening', {'msm': 0.0, 'fake': 0.0})
#
# ('Greatest', {'msm': 0.0, 'fake': 0.0})
#
# ('Green', {'msm': 0.0, 'fake': 0.0})
#
# ('Greitens', {'msm': 0.0, 'fake': 0.0})
#
# ('Group', {'msm': 0.0, 'fake': 0.0})
#
# ('Grow', {'msm': 0.0, 'fake': 0.0})
#
# ('Guide', {'msm': 0.0, 'fake': 0.0})
#
# ('Guilty', {'msm': 0.0, 'fake': 0.0})
#
# ('Guinea', {'msm': 0.0, 'fake': 0.0})
#
# ('Gun', {'msm': 0.0, 'fake': 0.0})
#
# ('GunControl', {'msm': 0.0, 'fake': 0.0})
#
# ('GunControlNow', {'msm': 0.0, 'fake': 0.0})
#
# ('GunReformNow', {'msm': 0.0, 'fake': 0.0})
#
# ('Guns', {'msm': 0.0, 'fake': 0.0})
#
# ('Gus', {'msm': 0.0, 'fake': 0.0})
#
# ('Guy', {'msm': 0.0, 'fake': 0.0})
#
# ('HAVE', {'msm': 0.0, 'fake': 0.0})
#
# ('HE', {'msm': 0.0, 'fake': 0.0})
#
# ('HERE', {'msm': 0.0, 'fake': 0.0})
#
# ('HR', {'msm': 0.0, 'fake': 0.0})
#
# ('Had', {'msm': 0.0, 'fake': 0.0})
#
# ('Haiti', {'msm': 0.0, 'fake': 0.0})
#
# ('Hall', {'msm': 0.0, 'fake': 0.0})
#
# ('Happened', {'msm': 0.0, 'fake': 0.0})
#
# ('Happens', {'msm': 0.0, 'fake': 0.0})
#
# ('Haram', {'msm': 0.0, 'fake': 0.0})
#
# ('Hard', {'msm': 0.0, 'fake': 0.0})
#
# ('Harris', {'msm': 0.0, 'fake': 0.0})
#
# ('Harvey', {'msm': 0.0, 'fake': 0.0})
#
# ('Has', {'msm': 0.0, 'fake': 0.0})
#
# ('Hathaway', {'msm': 0.0, 'fake': 0.0})
#
# ('Have', {'msm': 0.0, 'fake': 0.0})
#
# ('Having', {'msm': 0.0, 'fake': 0.0})
#
# ('Hawaii', {'msm': 0.0, 'fake': 0.0})
#
# ('He', {'msm': 0.0, 'fake': 0.0})
#
# ('Head', {'msm': 0.0, 'fake': 0.0})
#
# ('Headlines', {'msm': 0.0, 'fake': 0.0})
#
# ('Health', {'msm': 0.0, 'fake': 0.0})
#
# ('Hear', {'msm': 0.0, 'fake': 0.0})
#
# ('Heart', {'msm': 0.0, 'fake': 0.0})
#
# ('Heather', {'msm': 0.0, 'fake': 0.0})
#
# ('Hell', {'msm': 0.0, 'fake': 0.0})
#
# ('Help', {'msm': 0.0, 'fake': 0.0})
#
# ('Helped', {'msm': 0.0, 'fake': 0.0})
#
# ('Her', {'msm': 0.0, 'fake': 0.0})
#
# ('Here', {'msm': 0.0, 'fake': 0.0})
#
# ('Here’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Hero', {'msm': 0.0, 'fake': 0.0})
#
# ('Hertz', {'msm': 0.0, 'fake': 0.0})
#
# ('Hey', {'msm': 0.0, 'fake': 0.0})
#
# ('He’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Hidden', {'msm': 0.0, 'fake': 0.0})
#
# ('Hiding', {'msm': 0.0, 'fake': 0.0})
#
# ('High', {'msm': 0.0, 'fake': 0.0})
#
# ('Hill', {'msm': 0.0, 'fake': 0.0})
#
# ('Hillary', {'msm': 0.0, 'fake': 0.0})
#
# ('Him', {'msm': 0.0, 'fake': 0.0})
#
# ('His', {'msm': 0.0, 'fake': 0.0})
#
# ('History', {'msm': 0.0, 'fake': 0.0})
#
# ('Hit', {'msm': 0.0, 'fake': 0.0})
#
# ('Hockey', {'msm': 0.0, 'fake': 0.0})
#
# ('Hogg', {'msm': 0.0, 'fake': 0.0})
#
# ('Hold', {'msm': 0.0, 'fake': 0.0})
#
# ('Hollywood', {'msm': 0.0, 'fake': 0.0})
#
# ('Holy', {'msm': 0.0, 'fake': 0.0})
#
# ('Home', {'msm': 0.0, 'fake': 0.0})
#
# ('Homeless', {'msm': 0.0, 'fake': 0.0})
#
# ('Hook', {'msm': 0.0, 'fake': 0.0})
#
# ('Hope', {'msm': 0.0, 'fake': 0.0})
#
# ('Hot', {'msm': 0.0, 'fake': 0.0})
#
# ('Hotel', {'msm': 0.0, 'fake': 0.0})
#
# ('Hotels', {'msm': 0.0, 'fake': 0.0})
#
# ('House', {'msm': 0.0, 'fake': 0.0})
#
# ('Houston', {'msm': 0.0, 'fake': 0.0})
#
# ('How', {'msm': 0.0, 'fake': 0.0})
#
# ('Huawei', {'msm': 0.0, 'fake': 0.0})
#
# ('HuffPost', {'msm': 0.0, 'fake': 0.0})
#
# ('Huge', {'msm': 0.0, 'fake': 0.0})
#
# ('Human', {'msm': 0.0, 'fake': 0.0})
#
# ('Humans', {'msm': 0.0, 'fake': 0.0})
#
# ('Hundreds', {'msm': 0.0, 'fake': 0.0})
#
# ('I', {'msm': 0.0, 'fake': 0.0})
#
# ('ICE', {'msm': 0.0, 'fake': 0.0})
#
# ('ICYMI', {'msm': 0.0, 'fake': 0.0})
#
# ('II', {'msm': 0.0, 'fake': 0.0})
#
# ('IN', {'msm': 0.0, 'fake': 0.0})
#
# ('IOC', {'msm': 0.0, 'fake': 0.0})
#
# ('IPO', {'msm': 0.0, 'fake': 0.0})
#
# ('IRS', {'msm': 0.0, 'fake': 0.0})
#
# ('IS', {'msm': 0.0, 'fake': 0.0})
#
# ('ISIS', {'msm': 0.0, 'fake': 0.0})
#
# ('IT', {'msm': 0.0, 'fake': 0.0})
#
# ('Ice', {'msm': 0.0, 'fake': 0.0})
#
# ('Id', {'msm': 0.0, 'fake': 0.0})
#
# ('Idea', {'msm': 0.0, 'fake': 0.0})
#
# ('If', {'msm': 0.0, 'fake': 0.0})
#
# ('Ill', {'msm': 0.0, 'fake': 0.0})
#
# ('Illegal', {'msm': 0.0, 'fake': 0.0})
#
# ('Illuminati', {'msm': 0.0, 'fake': 0.0})
#
# ('Im', {'msm': 0.0, 'fake': 0.0})
#
# ('Immigrants', {'msm': 0.0, 'fake': 0.0})
#
# ('Immigration', {'msm': 0.0, 'fake': 0.0})
#
# ('Important', {'msm': 0.0, 'fake': 0.0})
#
# ('In', {'msm': 0.0, 'fake': 0.0})
#
# ('Inc', {'msm': 0.0, 'fake': 0.0})
#
# ('Incredible', {'msm': 0.0, 'fake': 0.0})
#
# ('India', {'msm': 0.0, 'fake': 0.0})
#
# ('Indian', {'msm': 0.0, 'fake': 0.0})
#
# ('Indonesia', {'msm': 0.0, 'fake': 0.0})
#
# ('Industry', {'msm': 0.0, 'fake': 0.0})
#
# ('Ingraham', {'msm': 0.0, 'fake': 0.0})
#
# ('Inside', {'msm': 0.0, 'fake': 0.0})
#
# ('Instagram', {'msm': 0.0, 'fake': 0.0})
#
# ('Instead', {'msm': 0.0, 'fake': 0.0})
#
# ('Intel', {'msm': 0.0, 'fake': 0.0})
#
# ('Intelligence', {'msm': 0.0, 'fake': 0.0})
#
# ('Interesting', {'msm': 0.0, 'fake': 0.0})
#
# ('International', {'msm': 0.0, 'fake': 0.0})
#
# ('Internet', {'msm': 0.0, 'fake': 0.0})
#
# ('Interview', {'msm': 0.0, 'fake': 0.0})
#
# ('Into', {'msm': 0.0, 'fake': 0.0})
#
# ('Investigation', {'msm': 0.0, 'fake': 0.0})
#
# ('Investment', {'msm': 0.0, 'fake': 0.0})
#
# ('Investors', {'msm': 0.0, 'fake': 0.0})
#
# ('Involved', {'msm': 0.0, 'fake': 0.0})
#
# ('IoT', {'msm': 0.0, 'fake': 0.0})
#
# ('Iowa', {'msm': 0.0, 'fake': 0.0})
#
# ('Iran', {'msm': 0.0, 'fake': 0.0})
#
# ('Iranian', {'msm': 0.0, 'fake': 0.0})
#
# ('Iraq', {'msm': 0.0, 'fake': 0.0})
#
# ('Is', {'msm': 0.0, 'fake': 0.0})
#
# ('Islamic', {'msm': 0.0, 'fake': 0.0})
#
# ('Island', {'msm': 0.0, 'fake': 0.0})
#
# ('Isnt', {'msm': 0.0, 'fake': 0.0})
#
# ('Israel', {'msm': 0.0, 'fake': 0.0})
#
# ('Israeli', {'msm': 0.0, 'fake': 0.0})
#
# ('Issues', {'msm': 0.0, 'fake': 0.0})
#
# ('It', {'msm': 0.0, 'fake': 0.0})
#
# ('Italian', {'msm': 0.0, 'fake': 0.0})
#
# ('Italians', {'msm': 0.0, 'fake': 0.0})
#
# ('Italy', {'msm': 0.0, 'fake': 0.0})
#
# ('Its', {'msm': 0.0, 'fake': 0.0})
#
# ('It’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Ivanka', {'msm': 0.0, 'fake': 0.0})
#
# ('Ive', {'msm': 0.0, 'fake': 0.0})
#
# ('I’ll', {'msm': 0.0, 'fake': 0.0})
#
# ('I’m', {'msm': 0.0, 'fake': 0.0})
#
# ('I’ve', {'msm': 0.0, 'fake': 0.0})
#
# ('J', {'msm': 0.0, 'fake': 0.0})
#
# ('JUST', {'msm': 0.0, 'fake': 0.0})
#
# ('Jackson', {'msm': 0.0, 'fake': 0.0})
#
# ('Jail', {'msm': 0.0, 'fake': 0.0})
#
# ('James', {'msm': 0.0, 'fake': 0.0})
#
# ('January', {'msm': 0.0, 'fake': 0.0})
#
# ('Janus', {'msm': 0.0, 'fake': 0.0})
#
# ('Japan', {'msm': 0.0, 'fake': 0.0})
#
# ('Japanese', {'msm': 0.0, 'fake': 0.0})
#
# ('Jared', {'msm': 0.0, 'fake': 0.0})
#
# ('Jeanine', {'msm': 0.0, 'fake': 0.0})
#
# ('Jeff', {'msm': 0.0, 'fake': 0.0})
#
# ('Jenner', {'msm': 0.0, 'fake': 0.0})
#
# ('Jennifer', {'msm': 0.0, 'fake': 0.0})
#
# ('Jeremy', {'msm': 0.0, 'fake': 0.0})
#
# ('Jerry', {'msm': 0.0, 'fake': 0.0})
#
# ('Jerusalem', {'msm': 0.0, 'fake': 0.0})
#
# ('Jesus', {'msm': 0.0, 'fake': 0.0})
#
# ('Jewish', {'msm': 0.0, 'fake': 0.0})
#
# ('Jim', {'msm': 0.0, 'fake': 0.0})
#
# ('Jimmy', {'msm': 0.0, 'fake': 0.0})
#
# ('Jinping', {'msm': 0.0, 'fake': 0.0})
#
# ('Job', {'msm': 0.0, 'fake': 0.0})
#
# ('Jobs', {'msm': 0.0, 'fake': 0.0})
#
# ('Joe', {'msm': 0.0, 'fake': 0.0})
#
# ('John', {'msm': 0.0, 'fake': 0.0})
#
# ('Join', {'msm': 0.0, 'fake': 0.0})
#
# ('Jones', {'msm': 0.0, 'fake': 0.0})
#
# ('Jong', {'msm': 0.0, 'fake': 0.0})
#
# ('Journal', {'msm': 0.0, 'fake': 0.0})
#
# ('Jr', {'msm': 0.0, 'fake': 0.0})
#
# ('Judge', {'msm': 0.0, 'fake': 0.0})
#
# ('Just', {'msm': 0.0, 'fake': 0.0})
#
# ('Justice', {'msm': 0.0, 'fake': 0.0})
#
# ('Justin', {'msm': 0.0, 'fake': 0.0})
#
# ('KFC', {'msm': 0.0, 'fake': 0.0})
#
# ('Kansas', {'msm': 0.0, 'fake': 0.0})
#
# ('Keep', {'msm': 0.0, 'fake': 0.0})
#
# ('Kelly', {'msm': 0.0, 'fake': 0.0})
#
# ('Kentucky', {'msm': 0.0, 'fake': 0.0})
#
# ('Kenworthy', {'msm': 0.0, 'fake': 0.0})
#
# ('Kerry', {'msm': 0.0, 'fake': 0.0})
#
# ('Kevin', {'msm': 0.0, 'fake': 0.0})
#
# ('Key', {'msm': 0.0, 'fake': 0.0})
#
# ('Kids', {'msm': 0.0, 'fake': 0.0})
#
# ('Kill', {'msm': 0.0, 'fake': 0.0})
#
# ('Killed', {'msm': 0.0, 'fake': 0.0})
#
# ('Killing', {'msm': 0.0, 'fake': 0.0})
#
# ('Kills', {'msm': 0.0, 'fake': 0.0})
#
# ('Kim', {'msm': 0.0, 'fake': 0.0})
#
# ('King', {'msm': 0.0, 'fake': 0.0})
#
# ('Knew', {'msm': 0.0, 'fake': 0.0})
#
# ('Know', {'msm': 0.0, 'fake': 0.0})
#
# ('Korea', {'msm': 0.0, 'fake': 0.0})
#
# ('Korean', {'msm': 0.0, 'fake': 0.0})
#
# ('Koreans', {'msm': 0.0, 'fake': 0.0})
#
# ('Kremlin', {'msm': 0.0, 'fake': 0.0})
#
# ('Kurdish', {'msm': 0.0, 'fake': 0.0})
#
# ('Kushner', {'msm': 0.0, 'fake': 0.0})
#
# ('Kylie', {'msm': 0.0, 'fake': 0.0})
#
# ('L', {'msm': 0.0, 'fake': 0.0})
#
# ('LA', {'msm': 0.0, 'fake': 0.0})
#
# ('LGBT', {'msm': 0.0, 'fake': 0.0})
#
# ('LOL', {'msm': 0.0, 'fake': 0.0})
#
# ('La', {'msm': 0.0, 'fake': 0.0})
#
# ('Labour', {'msm': 0.0, 'fake': 0.0})
#
# ('Land', {'msm': 0.0, 'fake': 0.0})
#
# ('Las', {'msm': 0.0, 'fake': 0.0})
#
# ('Last', {'msm': 0.0, 'fake': 0.0})
#
# ('Later', {'msm': 0.0, 'fake': 0.0})
#
# ('Latest', {'msm': 0.0, 'fake': 0.0})
#
# ('Launches', {'msm': 0.0, 'fake': 0.0})
#
# ('Laura', {'msm': 0.0, 'fake': 0.0})
#
# ('Law', {'msm': 0.0, 'fake': 0.0})
#
# ('Lawmaker', {'msm': 0.0, 'fake': 0.0})
#
# ('Lawmakers', {'msm': 0.0, 'fake': 0.0})
#
# ('Lawrence', {'msm': 0.0, 'fake': 0.0})
#
# ('Laws', {'msm': 0.0, 'fake': 0.0})
#
# ('Lawsuit', {'msm': 0.0, 'fake': 0.0})
#
# ('LeBron', {'msm': 0.0, 'fake': 0.0})
#
# ('Lead', {'msm': 0.0, 'fake': 0.0})
#
# ('Leader', {'msm': 0.0, 'fake': 0.0})
#
# ('Leaders', {'msm': 0.0, 'fake': 0.0})
#
# ('Leadership', {'msm': 0.0, 'fake': 0.0})
#
# ('League', {'msm': 0.0, 'fake': 0.0})
#
# ('Learn', {'msm': 0.0, 'fake': 0.0})
#
# ('Learned', {'msm': 0.0, 'fake': 0.0})
#
# ('Learning', {'msm': 0.0, 'fake': 0.0})
#
# ('Least', {'msm': 0.0, 'fake': 0.0})
#
# ('Leave', {'msm': 0.0, 'fake': 0.0})
#
# ('Leaves', {'msm': 0.0, 'fake': 0.0})
#
# ('Leaving', {'msm': 0.0, 'fake': 0.0})
#
# ('Ledecka', {'msm': 0.0, 'fake': 0.0})
#
# ('Left', {'msm': 0.0, 'fake': 0.0})
#
# ('Legal', {'msm': 0.0, 'fake': 0.0})
#
# ('Leicester', {'msm': 0.0, 'fake': 0.0})
#
# ('Less', {'msm': 0.0, 'fake': 0.0})
#
# ('Lessons', {'msm': 0.0, 'fake': 0.0})
#
# ('Let', {'msm': 0.0, 'fake': 0.0})
#
# ('Letter', {'msm': 0.0, 'fake': 0.0})
#
# ('Let’s', {'msm': 0.0, 'fake': 0.0})
#
# ('Lewinsky', {'msm': 0.0, 'fake': 0.0})
#
# ('Liberal', {'msm': 0.0, 'fake': 0.0})
#
# ('Liberals', {'msm': 0.0, 'fake': 0.0})
#
# ('Lie', {'msm': 0.0, 'fake': 0.0})
#
# ('Life', {'msm': 0.0, 'fake': 0.0})
#
# ('Light', {'msm': 0.0, 'fake': 0.0})
#
# ('Like', {'msm': 0.0, 'fake': 0.0})
#
# ('Likely', {'msm': 0.0, 'fake': 0.0})
#
# ('Limit', {'msm': 0.0, 'fake': 0.0})
#
# ('Lines', {'msm': 0.0, 'fake': 0.0})
#
# ('Link', {'msm': 0.0, 'fake': 0.0})
#
# ('List', {'msm': 0.0, 'fake': 0.0})
#
# ('Listen', {'msm': 0.0, 'fake': 0.0})
#
# ('Little', {'msm': 0.0, 'fake': 0.0})
#
# ('Live', {'msm': 0.0, 'fake': 0.0})
#
# ('Lives', {'msm': 0.0, 'fake': 0.0})
#
# ('Local', {'msm': 0.0, 'fake': 0.0})
#
# ('Locklear', {'msm': 0.0, 'fake': 0.0})
#
# ('Loesch', {'msm': 0.0, 'fake': 0.0})
#
# ('London', {'msm': 0.0, 'fake': 0.0})
#
# ('Long', {'msm': 0.0, 'fake': 0.0})
#
# ('Look', {'msm': 0.0, 'fake': 0.0})
#
# ('Looking', {'msm': 0.0, 'fake': 0.0})
#
# ('LookingForNewsgtgtgt', {'msm': 0.0, 'fake': 0.0})
#
# ('Looks', {'msm': 0.0, 'fake': 0.0})
#
# ('Lore', {'msm': 0.0, 'fake': 0.0})
#
# ('Los', {'msm': 0.0, 'fake': 0.0})
#
# ('LosAngeles', {'msm': 0.0, 'fake': 0.0})
#
# ('Losing', {'msm': 0.0, 'fake': 0.0})
#
# ('Lost', {'msm': 0.0, 'fake': 0.0})
#
# ('Louisiana', {'msm': 0.0, 'fake': 0.0})
#
# ('Love', {'msm': 0.0, 'fake': 0.0})
#
# ('MAGA', {'msm': 0.0, 'fake': 0.0})
#
# ('ML', {'msm': 0.0, 'fake': 0.0})
#
# ('MORE', {'msm': 0.0, 'fake': 0.0})
#
# ('MSM', {'msm': 0.0, 'fake': 0.0})
#
# ('MSNBC', {'msm': 0.0, 'fake': 0.0})
#
# ('MUST', {'msm': 0.0, 'fake': 0.0})
#
# ('MY', {'msm': 0.0, 'fake': 0.0})

# %%
mi_top_fake = sorted([x for x in mi.items()], key=lambda x: x[1]['fake'], reverse=True)

# %%
print("\n\n".join([str(x) for x in mi_top_fake[0:1000]]))
# Out:
# ('0', {'msm': 0.0, 'fake': 0.0})
#
# ('0 0', {'msm': 0.0, 'fake': 0.0})
#
# ('0 0 trading', {'msm': 0.0, 'fake': 0.0})
#
# ('0 0Apple', {'msm': 0.0, 'fake': 0.0})
#
# ('0 0Apple confirms', {'msm': 0.0, 'fake': 0.0})
#
# ('0 Story', {'msm': 0.0, 'fake': 0.0})
#
# ('0 Story w', {'msm': 0.0, 'fake': 0.0})
#
# ('0 These', {'msm': 0.0, 'fake': 0.0})
#
# ('0 These kids', {'msm': 0.0, 'fake': 0.0})
#
# ('0 about', {'msm': 0.0, 'fake': 0.0})
#
# ('0 about legal', {'msm': 0.0, 'fake': 0.0})
#
# ('0 coverage', {'msm': 0.0, 'fake': 0.0})
#
# ('0 coverage And', {'msm': 0.0, 'fake': 0.0})
#
# ('0 data', {'msm': 0.0, 'fake': 0.0})
#
# ('0 data Net', {'msm': 0.0, 'fake': 0.0})
#
# ('0 dead', {'msm': 0.0, 'fake': 0.0})
#
# ('0 trading', {'msm': 0.0, 'fake': 0.0})
#
# ('0 trading PG', {'msm': 0.0, 'fake': 0.0})
#
# ('000 Venezuela', {'msm': 0.0, 'fake': 0.0})
#
# ('000 dollars', {'msm': 0.0, 'fake': 0.0})
#
# ('000 dollars à', {'msm': 0.0, 'fake': 0.0})
#
# ('000 femmes', {'msm': 0.0, 'fake': 0.0})
#
# ('000 femmes victimes', {'msm': 0.0, 'fake': 0.0})
#
# ('000 filles', {'msm': 0.0, 'fake': 0.0})
#
# ('000 filles en', {'msm': 0.0, 'fake': 0.0})
#
# ('000 more', {'msm': 0.0, 'fake': 0.0})
#
# ('000 more per', {'msm': 0.0, 'fake': 0.0})
#
# ('000 price', {'msm': 0.0, 'fake': 0.0})
#
# ('000 price tag', {'msm': 0.0, 'fake': 0.0})
#
# ('000 via', {'msm': 0.0, 'fake': 0.0})
#
# ('002 Disney', {'msm': 0.0, 'fake': 0.0})
#
# ('002 Disney donates', {'msm': 0.0, 'fake': 0.0})
#
# ('007 Who', {'msm': 0.0, 'fake': 0.0})
#
# ('007 Who upset', {'msm': 0.0, 'fake': 0.0})
#
# ('007aec187ad24158bf46954698ef5cd4', {'msm': 0.0, 'fake': 0.0})
#
# ('007s are', {'msm': 0.0, 'fake': 0.0})
#
# ('007s are warning', {'msm': 0.0, 'fake': 0.0})
#
# ('00b9e3fd4c0e43798911ec29ebafc2c4', {'msm': 0.0, 'fake': 0.0})
#
# ('01 in', {'msm': 0.0, 'fake': 0.0})
#
# ('01 in January', {'msm': 0.0, 'fake': 0.0})
#
# ('010161f6f4b340b9a027d966a7859ebd', {'msm': 0.0, 'fake': 0.0})
#
# ('01152013 Washington', {'msm': 0.0, 'fake': 0.0})
#
# ('01152013 Washington Post', {'msm': 0.0, 'fake': 0.0})
#
# ('01202009 is', {'msm': 0.0, 'fake': 0.0})
#
# ('01202009 is solely', {'msm': 0.0, 'fake': 0.0})
#
# ('01596e4447d84a66beb2f53b9e579908', {'msm': 0.0, 'fake': 0.0})
#
# ('02 pct', {'msm': 0.0, 'fake': 0.0})
#
# ('02 pct mm', {'msm': 0.0, 'fake': 0.0})
#
# ('02 takes', {'msm': 0.0, 'fake': 0.0})
#
# ('02 takes the', {'msm': 0.0, 'fake': 0.0})
#
# ('020818 httpstcoVKED4Yp4g1', {'msm': 0.0, 'fake': 0.0})
#
# ('021818 in', {'msm': 0.0, 'fake': 0.0})
#
# ('021818 in greatawakening', {'msm': 0.0, 'fake': 0.0})
#
# ('022318 WHY', {'msm': 0.0, 'fake': 0.0})
#
# ('022318 WHY would', {'msm': 0.0, 'fake': 0.0})
#
# ('022318 Why', {'msm': 0.0, 'fake': 0.0})
#
# ('022318 Why Would', {'msm': 0.0, 'fake': 0.0})
#
# ('02232018 The', {'msm': 0.0, 'fake': 0.0})
#
# ('02232018 The Second', {'msm': 0.0, 'fake': 0.0})
#
# ('022418 Latest', {'msm': 0.0, 'fake': 0.0})
#
# ('022418 Latest QPosts', {'msm': 0.0, 'fake': 0.0})
#
# ('02Feb18 Josh', {'msm': 0.0, 'fake': 0.0})
#
# ('02Feb18 Josh Campbell', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 07時07分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 07時07分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 11時02分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 11時02分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 12時27分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 12時27分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 15時32分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 15時32分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 16時27分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 16時27分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 17時16分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 17時16分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月27日 05時27分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月27日 05時27分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('03168bb00b49403bb8918d726ad5fcd9', {'msm': 0.0, 'fake': 0.0})
#
# ('0331 FRIDAY', {'msm': 0.0, 'fake': 0.0})
#
# ('0331 FRIDAY The', {'msm': 0.0, 'fake': 0.0})
#
# ('04 for', {'msm': 0.0, 'fake': 0.0})
#
# ('04 for the', {'msm': 0.0, 'fake': 0.0})
#
# ('04 pct', {'msm': 0.0, 'fake': 0.0})
#
# ('04 the', {'msm': 0.0, 'fake': 0.0})
#
# ('04 the number', {'msm': 0.0, 'fake': 0.0})
#
# ('0406AM yOgA', {'msm': 0.0, 'fake': 0.0})
#
# ('0406AM yOgA AP', {'msm': 0.0, 'fake': 0.0})
#
# ('041117 Where', {'msm': 0.0, 'fake': 0.0})
#
# ('041117 Where is', {'msm': 0.0, 'fake': 0.0})
#
# ('044713042d2c42b385c1e521cc8c386c', {'msm': 0.0, 'fake': 0.0})
#
# ('05 in', {'msm': 0.0, 'fake': 0.0})
#
# ('05 in January', {'msm': 0.0, 'fake': 0.0})
#
# ('05 punti', {'msm': 0.0, 'fake': 0.0})
#
# ('05 punti circa', {'msm': 0.0, 'fake': 0.0})
#
# ('0500AM Click', {'msm': 0.0, 'fake': 0.0})
#
# ('0500AM Click Here', {'msm': 0.0, 'fake': 0.0})
#
# ('0500AM …', {'msm': 0.0, 'fake': 0.0})
#
# ('0500PM An', {'msm': 0.0, 'fake': 0.0})
#
# ('0500PM An 80s', {'msm': 0.0, 'fake': 0.0})
#
# ('0558a210160e46dd900d8c11ee52a5c4', {'msm': 0.0, 'fake': 0.0})
#
# ('05bp and', {'msm': 0.0, 'fake': 0.0})
#
# ('05bp and 30y', {'msm': 0.0, 'fake': 0.0})
#
# ('05時27分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('05時27分 引用元：Reuters ロイター', {'msm': 0.0, 'fake': 0.0})
#
# ('0625PM Two', {'msm': 0.0, 'fake': 0.0})
#
# ('0625PM Two LAPD', {'msm': 0.0, 'fake': 0.0})
#
# ('0630 1730', {'msm': 0.0, 'fake': 0.0})
#
# ('0630 1730 Feb', {'msm': 0.0, 'fake': 0.0})
#
# ('0640PM California', {'msm': 0.0, 'fake': 0.0})
#
# ('0640PM California Sounds', {'msm': 0.0, 'fake': 0.0})
#
# ('0646 JST', {'msm': 0.0, 'fake': 0.0})
#
# ('0646 JST 米投資会社バークシャー…', {'msm': 0.0, 'fake': 0.0})
#
# ('0710AM North', {'msm': 0.0, 'fake': 0.0})
#
# ('0710AM North Hollywood', {'msm': 0.0, 'fake': 0.0})
#
# ('072018 Sharing', {'msm': 0.0, 'fake': 0.0})
#
# ('072018 Sharing some', {'msm': 0.0, 'fake': 0.0})
#
# ('0735PM With', {'msm': 0.0, 'fake': 0.0})
#
# ('0735PM With a', {'msm': 0.0, 'fake': 0.0})
#
# ('07bp 10y', {'msm': 0.0, 'fake': 0.0})
#
# ('07bp 10y fell', {'msm': 0.0, 'fake': 0.0})
#
# ('07時07分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('07時07分 引用元：Reuters ロイター', {'msm': 0.0, 'fake': 0.0})
#
# ('08 percent', {'msm': 0.0, 'fake': 0.0})
#
# ('08 percent of', {'msm': 0.0, 'fake': 0.0})
#
# ('0800 am', {'msm': 0.0, 'fake': 0.0})
#
# ('0800 am Abend', {'msm': 0.0, 'fake': 0.0})
#
# ('084fc65ce27c42c9961fad9ca1f8a742', {'msm': 0.0, 'fake': 0.0})
#
# ('085 US', {'msm': 0.0, 'fake': 0.0})
#
# ('085 US Code', {'msm': 0.0, 'fake': 0.0})
#
# ('0911 until', {'msm': 0.0, 'fake': 0.0})
#
# ('0911 until now', {'msm': 0.0, 'fake': 0.0})
#
# ('0927bbea38d140ccb911f8fdea538035', {'msm': 0.0, 'fake': 0.0})
#
# ('0930 Feb', {'msm': 0.0, 'fake': 0.0})
#
# ('0930 Feb 28', {'msm': 0.0, 'fake': 0.0})
#
# ('09494d10e57642d1aa802ab503fae850', {'msm': 0.0, 'fake': 0.0})
#
# ('09c7eba347ac407f8698fb51f26e1123', {'msm': 0.0, 'fake': 0.0})
#
# ('09d7a5e2cda2464dad2ec21c66b2eb2a', {'msm': 0.0, 'fake': 0.0})
#
# ('0Apple confirms', {'msm': 0.0, 'fake': 0.0})
#
# ('0Apple confirms it', {'msm': 0.0, 'fake': 0.0})
#
# ('0B0Z0 ampOR', {'msm': 0.0, 'fake': 0.0})
#
# ('0B0Z0 ampOR HILDABEAST', {'msm': 0.0, 'fake': 0.0})
#
# ('0a32e8a02c6b4c239509f64c599d90ed', {'msm': 0.0, 'fake': 0.0})
#
# ('0b8921c64b0d45e7b3d87dcd832296eb', {'msm': 0.0, 'fake': 0.0})
#
# ('0c25b84b74f340f8a2daa46c628eeb1f', {'msm': 0.0, 'fake': 0.0})
#
# ('0c270a2baddc4ac292f169c87e248989', {'msm': 0.0, 'fake': 0.0})
#
# ('0c322a644bf04c078cdd396b0540e130', {'msm': 0.0, 'fake': 0.0})
#
# ('0e564bcca457428ba95c8e9f12bbccc9', {'msm': 0.0, 'fake': 0.0})
#
# ('0fff6249386645debfddd97e4b50d4f9', {'msm': 0.0, 'fake': 0.0})
#
# ('0io9 8', {'msm': 0.0, 'fake': 0.0})
#
# ('0io9 8 Ill', {'msm': 0.0, 'fake': 0.0})
#
# ('0′s and', {'msm': 0.0, 'fake': 0.0})
#
# ('0′s and 1′s', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2 3', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2 Por', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2017', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2017 at', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2018', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2018 GOP', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2018 theyll', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2019', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2019 And', {'msm': 0.0, 'fake': 0.0})
#
# ('1 81', {'msm': 0.0, 'fake': 0.0})
#
# ('1 81 higher', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Adolph', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Adolph Hitler', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Against', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Against Single', {'msm': 0.0, 'fake': 0.0})
#
# ('1 American', {'msm': 0.0, 'fake': 0.0})
#
# ('1 American Dem', {'msm': 0.0, 'fake': 0.0})
#
# ('1 And', {'msm': 0.0, 'fake': 0.0})
#
# ('1 And now', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Apple', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Apple hands', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Arming', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Arming teachers', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Because', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Because this', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Billion', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Billion From', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Billion at', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Billion in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Bitterness', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Bitterness 0', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Bridgeport', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Bridgeport CT', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Brutal', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Brutal Demand', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Brutal Question', {'msm': 0.0, 'fake': 0.0})
#
# ('1 CORINTHIANS', {'msm': 0.0, 'fake': 0.0})
#
# ('1 CORINTHIANS 13', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Captured', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Captured 82', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Characteristic', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Characteristic Every', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Clueless', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Clueless Don', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Coloca', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Coloca caixa', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Congress', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Congress add', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Create', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Create engaging', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Cure', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Curious', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Curious SEO', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DEPUTY', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DEPUTY NOT', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DJ', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DJ has', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DOJ', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DOJ failed', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Darkest', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Darkest Hour', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Day', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Day 553', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Dead', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Dead 3', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Debbie', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Debbie Wasserman', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Democratic', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Democratic turnout', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Detail', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Detail Blows', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Disturbing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Disturbing Detail', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Dow', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Dow adds', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Down', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Down amp', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Duke', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Duke close', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Embarrassing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Embarrassing Problem', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Episode', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Episode 3', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Final', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Final Post', {'msm': 0.0, 'fake': 0.0})
#
# ('1 GOPTaxScam', {'msm': 0.0, 'fake': 0.0})
#
# ('1 GOPTaxScam TheResistance', {'msm': 0.0, 'fake': 0.0})
#
# ('1 His', {'msm': 0.0, 'fake': 0.0})
#
# ('1 His first', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Holy', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Holy shit', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Hour', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Huge', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Huge Change', {'msm': 0.0, 'fake': 0.0})
#
# ('1 I', {'msm': 0.0, 'fake': 0.0})
#
# ('1 I wish', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Important', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Important Detail', {'msm': 0.0, 'fake': 0.0})
#
# ('1 In', {'msm': 0.0, 'fake': 0.0})
#
# ('1 In 3', {'msm': 0.0, 'fake': 0.0})
#
# ('1 India', {'msm': 0.0, 'fake': 0.0})
#
# ('1 India 2', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Ingraham', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Ingraham The', {'msm': 0.0, 'fake': 0.0})
#
# ('1 It', {'msm': 0.0, 'fake': 0.0})
#
# ('1 It occupied', {'msm': 0.0, 'fake': 0.0})
#
# ('1 It totally', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Kylie', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Kylie Jenner', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Leader', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Leader shows', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Lego', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Lego 2', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Lemon', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Lemon Peel', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Less', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Less Than', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Liter', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Liter of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 March', {'msm': 0.0, 'fake': 0.0})
#
# ('1 March Read', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Mile', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Mile Run', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million Bounty', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million Discarded', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million Immigrants', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million Kids', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million Years', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million he', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million to', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million via', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Monica', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Monica Crowley', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Month', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Month of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 NRA', {'msm': 0.0, 'fake': 0.0})
#
# ('1 NRA 0', {'msm': 0.0, 'fake': 0.0})
#
# ('1 NRA amp', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Nasty', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Nasty Line', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Neo', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Neo Nazis', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Nokia', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Nokia 7', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Official', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Official Hip', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Okay', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Okay so', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Other', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Other Prison', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Percent', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Philip', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Philip Morris', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Poll', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Poll Ranking', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Priority', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Priority HumanResources', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Problem', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Problem TCOT', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Reason', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Reason You', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Russian', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Russian source', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Sick', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Sick Thing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Simple', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Simple Question', {'msm': 0.0, 'fake': 0.0})
#
# ('1 So', {'msm': 0.0, 'fake': 0.0})
#
# ('1 So why', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Some', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Some news', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Surprising', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Surprising Chart', {'msm': 0.0, 'fake': 0.0})
#
# ('1 TO', {'msm': 0.0, 'fake': 0.0})
#
# ('1 TO A', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Tablespoon', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Tablespoon of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Take', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Take a', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Targeted…Sick', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The Cod', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The GOP', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The Gun', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The Supreme', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The album', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The has', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The man', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The work', {'msm': 0.0, 'fake': 0.0})
#
# ('1 TheWall', {'msm': 0.0, 'fake': 0.0})
#
# ('1 TheWall Outcome', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Thing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Thing From', {'msm': 0.0, 'fake': 0.0})
#
# ('1 This', {'msm': 0.0, 'fake': 0.0})
#
# ('1 This is', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Trillion', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Trillion Dollar', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Tweet', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Tweet via', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Two', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Two huge', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Unfortunately', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Unfortunately here', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Virginia', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Virginia allowed', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Virginia cruises', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Way', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Way To', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Who', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Who is', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Woe', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Woe unto', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Working', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Working with', {'msm': 0.0, 'fake': 0.0})
#
# ('1 You', {'msm': 0.0, 'fake': 0.0})
#
# ('1 You Need', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Your', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Your article', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Yuge', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Yuge Problem', {'msm': 0.0, 'fake': 0.0})
#
# ('1 after', {'msm': 0.0, 'fake': 0.0})
#
# ('1 after screaming', {'msm': 0.0, 'fake': 0.0})
#
# ('1 and', {'msm': 0.0, 'fake': 0.0})
#
# ('1 and 2', {'msm': 0.0, 'fake': 0.0})
#
# ('1 and burying', {'msm': 0.0, 'fake': 0.0})
#
# ('1 and displaces', {'msm': 0.0, 'fake': 0.0})
#
# ('1 and lost', {'msm': 0.0, 'fake': 0.0})
#
# ('1 as', {'msm': 0.0, 'fake': 0.0})
#
# ('1 as part', {'msm': 0.0, 'fake': 0.0})
#
# ('1 attack', {'msm': 0.0, 'fake': 0.0})
#
# ('1 attack amp', {'msm': 0.0, 'fake': 0.0})
#
# ('1 away', {'msm': 0.0, 'fake': 0.0})
#
# ('1 away from', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion RealEstate', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion at', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion but', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion club', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion deficit', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion made', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion real', {'msm': 0.0, 'fake': 0.0})
#
# ('1 brought', {'msm': 0.0, 'fake': 0.0})
#
# ('1 brought record', {'msm': 0.0, 'fake': 0.0})
#
# ('1 businessman', {'msm': 0.0, 'fake': 0.0})
#
# ('1 businessman doing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 but', {'msm': 0.0, 'fake': 0.0})
#
# ('1 but 4', {'msm': 0.0, 'fake': 0.0})
#
# ('1 but 4fucking', {'msm': 0.0, 'fake': 0.0})
#
# ('1 but the', {'msm': 0.0, 'fake': 0.0})
#
# ('1 by', {'msm': 0.0, 'fake': 0.0})
#
# ('1 by THE', {'msm': 0.0, 'fake': 0.0})
#
# ('1 by spending', {'msm': 0.0, 'fake': 0.0})
#
# ('1 cause', {'msm': 0.0, 'fake': 0.0})
#
# ('1 cause of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 communication', {'msm': 0.0, 'fake': 0.0})
#
# ('1 communication mistake', {'msm': 0.0, 'fake': 0.0})
#
# ('1 day', {'msm': 0.0, 'fake': 0.0})
#
# ('1 day be', {'msm': 0.0, 'fake': 0.0})
#
# ('1 deal', {'msm': 0.0, 'fake': 0.0})
#
# ('1 dealampto', {'msm': 0.0, 'fake': 0.0})
#
# ('1 dealampto keep', {'msm': 0.0, 'fake': 0.0})
#
# ('1 deputy', {'msm': 0.0, 'fake': 0.0})
#
# ('1 deputy was', {'msm': 0.0, 'fake': 0.0})
#
# ('1 died', {'msm': 0.0, 'fake': 0.0})
#
# ('1 died in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 do', {'msm': 0.0, 'fake': 0.0})
#
# ('1 do Santa', {'msm': 0.0, 'fake': 0.0})
#
# ('1 do VASFLAPALSANIND', {'msm': 0.0, 'fake': 0.0})
#
# ('1 do Vasco', {'msm': 0.0, 'fake': 0.0})
#
# ('1 dr', {'msm': 0.0, 'fake': 0.0})
#
# ('1 dr 27', {'msm': 0.0, 'fake': 0.0})
#
# ('1 extension', {'msm': 0.0, 'fake': 0.0})
#
# ('1 extension de', {'msm': 0.0, 'fake': 0.0})
#
# ('1 finale', {'msm': 0.0, 'fake': 0.0})
#
# ('1 finale And', {'msm': 0.0, 'fake': 0.0})
#
# ('1 for', {'msm': 0.0, 'fake': 0.0})
#
# ('1 for womenintech', {'msm': 0.0, 'fake': 0.0})
#
# ('1 guard', {'msm': 0.0, 'fake': 0.0})
#
# ('1 guard injured', {'msm': 0.0, 'fake': 0.0})
#
# ('1 her', {'msm': 0.0, 'fake': 0.0})
#
# ('1 her husband', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hired', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hired criminals', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hombre', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hombre 1', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hour', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hour Free', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hour they', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hurt', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hurt News', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in 10', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in 4', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in 5', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in AP', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in diplomatic', {'msm': 0.0, 'fake': 0.0})
#
# ('1 incredibly', {'msm': 0.0, 'fake': 0.0})
#
# ('1 incredibly stupid', {'msm': 0.0, 'fake': 0.0})
#
# ('1 injured', {'msm': 0.0, 'fake': 0.0})
#
# ('1 injured in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 kid', {'msm': 0.0, 'fake': 0.0})
#
# ('1 kid and', {'msm': 0.0, 'fake': 0.0})
#
# ('1 killed', {'msm': 0.0, 'fake': 0.0})
#
# ('1 killed others', {'msm': 0.0, 'fake': 0.0})
#
# ('1 legislative', {'msm': 0.0, 'fake': 0.0})
#
# ('1 legislative act', {'msm': 0.0, 'fake': 0.0})
#
# ('1 manchild', {'msm': 0.0, 'fake': 0.0})
#
# ('1 manchild Call', {'msm': 0.0, 'fake': 0.0})
#
# ('1 mil', {'msm': 0.0, 'fake': 0.0})
#
# ('1 mil from', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million Americans', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million CSGO', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million budget', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million painting', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million refugees', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million wager', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million wholly', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million worth', {'msm': 0.0, 'fake': 0.0})
#
# ('1 mth', {'msm': 0.0, 'fake': 0.0})
#
# ('1 mth after', {'msm': 0.0, 'fake': 0.0})
#
# ('1 number', {'msm': 0.0, 'fake': 0.0})
#
# ('1 number threatens', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of 4', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of 8', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of his', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of many', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of the', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of these', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of those', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of world’s', {'msm': 0.0, 'fake': 0.0})
#
# ('1 on', {'msm': 0.0, 'fake': 0.0})
#
# ('1 on Top', {'msm': 0.0, 'fake': 0.0})
#
# ('1 out', {'msm': 0.0, 'fake': 0.0})
#
# ('1 out of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 pacarana', {'msm': 0.0, 'fake': 0.0})
#
# ('1 pacarana espécie', {'msm': 0.0, 'fake': 0.0})
#
# ('1 per', {'msm': 0.0, 'fake': 0.0})
#
# ('1 per 26', {'msm': 0.0, 'fake': 0.0})
#
# ('1 percent', {'msm': 0.0, 'fake': 0.0})
#
# ('1 percent of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 playoffs', {'msm': 0.0, 'fake': 0.0})
#
# ('1 position', {'msm': 0.0, 'fake': 0.0})
#
# ('1 position in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 president', {'msm': 0.0, 'fake': 0.0})
#
# ('1 president in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 problem', {'msm': 0.0, 'fake': 0.0})
#
# ('1 problem on', {'msm': 0.0, 'fake': 0.0})
#
# ('1 prolife', {'msm': 0.0, 'fake': 0.0})
#
# ('1 prolife state', {'msm': 0.0, 'fake': 0.0})
#
# ('1 rape', {'msm': 0.0, 'fake': 0.0})
#
# ('1 rape accusation', {'msm': 0.0, 'fake': 0.0})
#
# ('1 restaurant', {'msm': 0.0, 'fake': 0.0})
#
# ('1 restaurant in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 scandal', {'msm': 0.0, 'fake': 0.0})
#
# ('1 scandal being', {'msm': 0.0, 'fake': 0.0})
#
# ('1 school', {'msm': 0.0, 'fake': 0.0})
#
# ('1 school I', {'msm': 0.0, 'fake': 0.0})
#
# ('1 school Schools', {'msm': 0.0, 'fake': 0.0})
#
# ('1 schoolSchools', {'msm': 0.0, 'fake': 0.0})
#
# ('1 schoolSchools YOU', {'msm': 0.0, 'fake': 0.0})
#
# ('1 seed', {'msm': 0.0, 'fake': 0.0})
#
# ('1 seed status', {'msm': 0.0, 'fake': 0.0})
#
# ('1 shred', {'msm': 0.0, 'fake': 0.0})
#
# ('1 shred of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 skill', {'msm': 0.0, 'fake': 0.0})
#
# ('1 skill he', {'msm': 0.0, 'fake': 0.0})
#
# ('1 spot', {'msm': 0.0, 'fake': 0.0})
#
# ('1 spot in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 step', {'msm': 0.0, 'fake': 0.0})
#
# ('1 step forward', {'msm': 0.0, 'fake': 0.0})
#
# ('1 stone”', {'msm': 0.0, 'fake': 0.0})
#
# ('1 story', {'msm': 0.0, 'fake': 0.0})
#
# ('1 story today', {'msm': 0.0, 'fake': 0.0})
#
# ('1 stupid', {'msm': 0.0, 'fake': 0.0})
#
# ('1 stupid or', {'msm': 0.0, 'fake': 0.0})
#
# ('1 the', {'msm': 0.0, 'fake': 0.0})
#
# ('1 the IAEA', {'msm': 0.0, 'fake': 0.0})
#
# ('1 thing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 thing I', {'msm': 0.0, 'fake': 0.0})
#
# ('1 to', {'msm': 0.0, 'fake': 0.0})
#
# ('1 to ensure', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trauma', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trauma hospital', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trauma hospitals', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion amp', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion dollar', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion mark', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion market', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion short', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion sovereign', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion this', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion valuation', {'msm': 0.0, 'fake': 0.0})
#
# ('1 use', {'msm': 0.0, 'fake': 0.0})
#
# ('1 use their', {'msm': 0.0, 'fake': 0.0})
#
# ('1 vaccines', {'msm': 0.0, 'fake': 0.0})
#
# ('1 vaccines dont', {'msm': 0.0, 'fake': 0.0})
#
# ('1 valeur', {'msm': 0.0, 'fake': 0.0})
#
# ('1 valeur de', {'msm': 0.0, 'fake': 0.0})
#
# ('1 very', {'msm': 0.0, 'fake': 0.0})
#
# ('1 very big', {'msm': 0.0, 'fake': 0.0})
#
# ('1 week', {'msm': 0.0, 'fake': 0.0})
#
# ('1 week old', {'msm': 0.0, 'fake': 0.0})
#
# ('1 week they’re', {'msm': 0.0, 'fake': 0.0})
#
# ('1 why', {'msm': 0.0, 'fake': 0.0})
#
# ('1 why we', {'msm': 0.0, 'fake': 0.0})
#
# ('1 with', {'msm': 0.0, 'fake': 0.0})
#
# ('1 with Dr', {'msm': 0.0, 'fake': 0.0})
#
# ('1 with Duke', {'msm': 0.0, 'fake': 0.0})
#
# ('1 wk', {'msm': 0.0, 'fake': 0.0})
#
# ('1 wk earlier', {'msm': 0.0, 'fake': 0.0})
#
# ('1 would', {'msm': 0.0, 'fake': 0.0})
#
# ('1 would benefit', {'msm': 0.0, 'fake': 0.0})
#
# ('1 wounded', {'msm': 0.0, 'fake': 0.0})
#
# ('1 wounded in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 y', {'msm': 0.0, 'fake': 0.0})
#
# ('1 y 2', {'msm': 0.0, 'fake': 0.0})
#
# ('1 year', {'msm': 0.0, 'fake': 0.0})
#
# ('1 year Obama’s', {'msm': 0.0, 'fake': 0.0})
#
# ('1 year since', {'msm': 0.0, 'fake': 0.0})
#
# ('1 you', {'msm': 0.0, 'fake': 0.0})
#
# ('1 you need', {'msm': 0.0, 'fake': 0.0})
#
# ('1 yr', {'msm': 0.0, 'fake': 0.0})
#
# ('1 yr old', {'msm': 0.0, 'fake': 0.0})
#
# ('1 –', {'msm': 0.0, 'fake': 0.0})
#
# ('1 – 3', {'msm': 0.0, 'fake': 0.0})
#
# ('1 – If', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2013by', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2013by Gunny', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2016', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2016 Obama', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2018', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2018 God', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2018 Moscow', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Amazon', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Amazon deals', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Americans', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Americans killed', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Americans may', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Americans oppose', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Ancient', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Ancient Artifacts', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Auguis', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Auguis sa', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Books', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Environment', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Films', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Online', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Pieces', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Billion', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Billion Files', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Breakthrough', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Breakthrough Technologies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Brutally', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Brutally Hilarious', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Budgeting', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Budgeting Tips', {'msm': 0.0, 'fake': 0.0})
#
# ('10 COOLEST', {'msm': 0.0, 'fake': 0.0})
#
# ('10 COOLEST CITIES', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Cities', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Cities For', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Comics', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Comics About', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Comics That', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Common', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Common American', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Common Headache', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Common Link', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Coolest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Coolest Cities', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Customer', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Customer Experience', {'msm': 0.0, 'fake': 0.0})
#
# ('10 DAYS', {'msm': 0.0, 'fake': 0.0})
#
# ('10 DAYS Is', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Days', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Days via', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Deadly', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Deadly Chemicals', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Delicious', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Delicious Ideas', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Dos', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Dos And', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Easy', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Easy Habits', {'msm': 0.0, 'fake': 0.0})
#
# ('10 February', {'msm': 0.0, 'fake': 0.0})
#
# ('10 February 26', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Flags', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Flags AI', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Foods', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Forbes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Forbes 2018', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Global', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Global Beauty', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Great', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Great Quotes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Greatest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Greatest Moments', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Happiest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Happiest Companies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Health', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Health Problems', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Herbs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Herbs and', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hilarious', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hilarious Pregnancy', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hot', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hot AI', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hot Data', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hot DataSecurity', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Huge', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Huge Doggos', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Immigration', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Immigration Bill', {'msm': 0.0, 'fake': 0.0})
#
# ('10 In', {'msm': 0.0, 'fake': 0.0})
#
# ('10 In This', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Journalism', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Journalism Brands', {'msm': 0.0, 'fake': 0.0})
#
# ('10 June', {'msm': 0.0, 'fake': 0.0})
#
# ('10 June 14th', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Killed', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Killed in', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Live', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Live updates', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Million', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Million Acres', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Million Africans', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Million Beverly', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Million of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Minutes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Minutes 12', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Mistakes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Mistakes Job', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Months', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Months Gluing', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Most', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Most Powerful', {'msm': 0.0, 'fake': 0.0})
#
# ('10 NBA', {'msm': 0.0, 'fake': 0.0})
#
# ('10 NBA general', {'msm': 0.0, 'fake': 0.0})
#
# ('10 National', {'msm': 0.0, 'fake': 0.0})
#
# ('10 National Parks', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Of The', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Of amp039RuPaulamp039s', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Olympic', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Olympic Games', {'msm': 0.0, 'fake': 0.0})
#
# ('10 PM', {'msm': 0.0, 'fake': 0.0})
#
# ('10 PM EST', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Pathogens', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Pathogens Of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Pathogens of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 People', {'msm': 0.0, 'fake': 0.0})
#
# ('10 People Confessed', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Possible', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Possible Causes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Powerful', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Powerful Herbs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Predictions', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Predictions For', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Pro', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Proven', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Proven Ways', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Reasons', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Reasons Why', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Reasons You', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Rohingya', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Rohingya men', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Rounds', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Rounds with', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Russians', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Russians who', {'msm': 0.0, 'fake': 0.0})
#
# ('10 San', {'msm': 0.0, 'fake': 0.0})
#
# ('10 San Bernadino', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Signs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Signs When', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Signs You', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Signs You’re', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Small', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Small Things', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Strategic', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Strategic CIO', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Strategic Insights', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Strongest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Strongest Markets', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Surprising', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Surprising AF', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Tablet', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Tablet Hides', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Tech', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Tech Firms', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things About', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things I', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things Millennials', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things That', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things You', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things Youre', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Times', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Times More', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Times People', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Times Women', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Trends', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Trends For', {'msm': 0.0, 'fake': 0.0})
#
# ('10 UCLA', {'msm': 0.0, 'fake': 0.0})
#
# ('10 UCLA women', {'msm': 0.0, 'fake': 0.0})
#
# ('10 UCLA…', {'msm': 0.0, 'fake': 0.0})
#
# ('10 US', {'msm': 0.0, 'fake': 0.0})
#
# ('10 US Terroirs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 US wineries', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Vehicles', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Vehicles for', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Vitamin', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Vitamin K', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Warning', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Warning Signs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Ways', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Ways Machine', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Ways MachineLearning', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Worst', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Worst Colleges', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Years', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Years Conservative', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Years In', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Years via', {'msm': 0.0, 'fake': 0.0})
#
# ('10 a', {'msm': 0.0, 'fake': 0.0})
#
# ('10 a Day', {'msm': 0.0, 'fake': 0.0})
#
# ('10 after', {'msm': 0.0, 'fake': 0.0})
#
# ('10 after Robin', {'msm': 0.0, 'fake': 0.0})
#
# ('10 am', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ans', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ans après', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ans l', {'msm': 0.0, 'fake': 0.0})
#
# ('10 arrested', {'msm': 0.0, 'fake': 0.0})
#
# ('10 arrested a', {'msm': 0.0, 'fake': 0.0})
#
# ('10 articles', {'msm': 0.0, 'fake': 0.0})
#
# ('10 articles a', {'msm': 0.0, 'fake': 0.0})
#
# ('10 at', {'msm': 0.0, 'fake': 0.0})
#
# ('10 at Veterans', {'msm': 0.0, 'fake': 0.0})
#
# ('10 at the', {'msm': 0.0, 'fake': 0.0})
#
# ('10 available', {'msm': 0.0, 'fake': 0.0})
#
# ('10 available players', {'msm': 0.0, 'fake': 0.0})
#
# ('10 azioni', {'msm': 0.0, 'fake': 0.0})
#
# ('10 azioni da', {'msm': 0.0, 'fake': 0.0})
#
# ('10 años', {'msm': 0.0, 'fake': 0.0})
#
# ('10 años de', {'msm': 0.0, 'fake': 0.0})
#
# ('10 bachelors', {'msm': 0.0, 'fake': 0.0})
#
# ('10 bachelors on', {'msm': 0.0, 'fake': 0.0})
#
# ('10 believe', {'msm': 0.0, 'fake': 0.0})
#
# ('10 believe Russia', {'msm': 0.0, 'fake': 0.0})
#
# ('10 best', {'msm': 0.0, 'fake': 0.0})
#
# ('10 best encore', {'msm': 0.0, 'fake': 0.0})
#
# ('10 best foods', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion Files', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion files', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion has', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion private', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billionpound', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billionpound Brexit', {'msm': 0.0, 'fake': 0.0})
#
# ('10 blacks', {'msm': 0.0, 'fake': 0.0})
#
# ('10 blacks are', {'msm': 0.0, 'fake': 0.0})
#
# ('10 breakthrough', {'msm': 0.0, 'fake': 0.0})
#
# ('10 breakthrough technologies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cases', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cases of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cases reported', {'msm': 0.0, 'fake': 0.0})
#
# ('10 categories', {'msm': 0.0, 'fake': 0.0})
#
# ('10 categories for', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cities', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cities for', {'msm': 0.0, 'fake': 0.0})
#
# ('10 college', {'msm': 0.0, 'fake': 0.0})
#
# ('10 college admissions', {'msm': 0.0, 'fake': 0.0})
#
# ('10 compact', {'msm': 0.0, 'fake': 0.0})
#
# ('10 compact cameras', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cruise', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cruise ships', {'msm': 0.0, 'fake': 0.0})
#
# ('10 curiosidades', {'msm': 0.0, 'fake': 0.0})
#
# ('10 curiosidades sobre', {'msm': 0.0, 'fake': 0.0})
#
# ('10 days', {'msm': 0.0, 'fake': 0.0})
#
# ('10 days Only', {'msm': 0.0, 'fake': 0.0})
#
# ('10 days after', {'msm': 0.0, 'fake': 0.0})
#
# ('10 days ago', {'msm': 0.0, 'fake': 0.0})
#
# ('10 days of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 de', {'msm': 0.0, 'fake': 0.0})
#
# ('10 de 10', {'msm': 0.0, 'fake': 0.0})
#
# ('10 de febrero', {'msm': 0.0, 'fake': 0.0})
#
# ('10 de métricas', {'msm': 0.0, 'fake': 0.0})
#
# ('10 deepening', {'msm': 0.0, 'fake': 0.0})
#
# ('10 deepening inequality', {'msm': 0.0, 'fake': 0.0})
#
# ('10 del', {'msm': 0.0, 'fake': 0.0})
#
# ('10 del TLC', {'msm': 0.0, 'fake': 0.0})
#
# ('10 du', {'msm': 0.0, 'fake': 0.0})
#
# ('10 du capital', {'msm': 0.0, 'fake': 0.0})
#
# ('10 earthquakes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 earthquakes a', {'msm': 0.0, 'fake': 0.0})
#
# ('10 economies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 economies have', {'msm': 0.0, 'fake': 0.0})
#
# ('10 edtech', {'msm': 0.0, 'fake': 0.0})
#
# ('10 edtech startups', {'msm': 0.0, 'fake': 0.0})
#
# ('10 favor', {'msm': 0.0, 'fake': 0.0})
#
# ('10 favor tighter', {'msm': 0.0, 'fake': 0.0})
#
# ('10 free', {'msm': 0.0, 'fake': 0.0})
#
# ('10 free fullpage', {'msm': 0.0, 'fake': 0.0})
#
# ('10 fresh', {'msm': 0.0, 'fake': 0.0})
#
# ('10 fresh fashion', {'msm': 0.0, 'fake': 0.0})
#
# ('10 global', {'msm': 0.0, 'fake': 0.0})
#
# ('10 global CEOs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 gol', {'msm': 0.0, 'fake': 0.0})
#
# ('10 gol Artilheiros', {'msm': 0.0, 'fake': 0.0})
#
# ('10 governors', {'msm': 0.0, 'fake': 0.0})
#
# ('10 governors shaping', {'msm': 0.0, 'fake': 0.0})
#
# ('10 happiest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 happiest and', {'msm': 0.0, 'fake': 0.0})
#
# ('10 hardestworking', {'msm': 0.0, 'fake': 0.0})
#
# ('10 hardestworking cities', {'msm': 0.0, 'fake': 0.0})
#
# ('10 hits', {'msm': 0.0, 'fake': 0.0})
#
# ('10 hits than', {'msm': 0.0, 'fake': 0.0})
#
# ('10 important', {'msm': 0.0, 'fake': 0.0})
#
# ('10 important questions', {'msm': 0.0, 'fake': 0.0})
#
# ('10 in', {'msm': 0.0, 'fake': 0.0})
#
# ('10 in 10', {'msm': 0.0, 'fake': 0.0})
#
# ('10 in Innovation', {'msm': 0.0, 'fake': 0.0})
#
# ('10 increase', {'msm': 0.0, 'fake': 0.0})
#
# ('10 increase in', {'msm': 0.0, 'fake': 0.0})
#
# ('10 incredibly', {'msm': 0.0, 'fake': 0.0})
#
# ('10 incredibly useful', {'msm': 0.0, 'fake': 0.0})
#
# ('10 lifehacking', {'msm': 0.0, 'fake': 0.0})
#
# ('10 lifehacking books', {'msm': 0.0, 'fake': 0.0})
#
# ('10 list', {'msm': 0.0, 'fake': 0.0})
#
# ('10 lugares', {'msm': 0.0, 'fake': 0.0})
#
# ('10 lugares clave', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million and', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million dogs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million euros', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million in', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million libel', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 minutes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 minutes with', {'msm': 0.0, 'fake': 0.0})
#
# ('10 minutes you', {'msm': 0.0, 'fake': 0.0})
#
# ('10 more', {'msm': 0.0, 'fake': 0.0})
#
# ('10 more killed', {'msm': 0.0, 'fake': 0.0})
#
# ('10 most', {'msm': 0.0, 'fake': 0.0})
#
# ('10 most filling', {'msm': 0.0, 'fake': 0.0})
#
# ('10 most memorable', {'msm': 0.0, 'fake': 0.0})
#
# ('10 most popular', {'msm': 0.0, 'fake': 0.0})
#
# ('10 most valuable', {'msm': 0.0, 'fake': 0.0})
#
# ('10 new', {'msm': 0.0, 'fake': 0.0})
#
# ('10 new books', {'msm': 0.0, 'fake': 0.0})
#
# ('10 o', {'msm': 0.0, 'fake': 0.0})
#
# ('10 o 20', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of Daimler', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of her', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of our', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of population', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of the', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of them', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of your', {'msm': 0.0, 'fake': 0.0})
#
# ('10 on', {'msm': 0.0, 'fake': 0.0})
#
# ('10 on a', {'msm': 0.0, 'fake': 0.0})
#
# ('10 or', {'msm': 0.0, 'fake': 0.0})
#
# ('10 or 15', {'msm': 0.0, 'fake': 0.0})
#
# ('10 or 20', {'msm': 0.0, 'fake': 0.0})
#
# ('10 pages', {'msm': 0.0, 'fake': 0.0})
#
# ('10 pages And', {'msm': 0.0, 'fake': 0.0})
#
# ('10 pages to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 people', {'msm': 0.0, 'fake': 0.0})
#
# ('10 people gave', {'msm': 0.0, 'fake': 0.0})
#
# ('10 people were', {'msm': 0.0, 'fake': 0.0})
#
# ('10 percent', {'msm': 0.0, 'fake': 0.0})
#
# ('10 percent of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 percent stake', {'msm': 0.0, 'fake': 0.0})
#
# ('10 platos', {'msm': 0.0, 'fake': 0.0})
#
# ('10 platos que', {'msm': 0.0, 'fake': 0.0})
#
# ('10 player', {'msm': 0.0, 'fake': 0.0})
#
# ('10 player Article', {'msm': 0.0, 'fake': 0.0})
#
# ('10 players', {'msm': 0.0, 'fake': 0.0})
#
# ('10 players who', {'msm': 0.0, 'fake': 0.0})
#
# ('10 pm', {'msm': 0.0, 'fake': 0.0})
#
# ('10 pm ET', {'msm': 0.0, 'fake': 0.0})
#
# ('10 policies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 policies Iran', {'msm': 0.0, 'fake': 0.0})
#
# ('10 preguntas', {'msm': 0.0, 'fake': 0.0})
#
# ('10 preguntas correctamente', {'msm': 0.0, 'fake': 0.0})
#
# ('10 primeros', {'msm': 0.0, 'fake': 0.0})
#
# ('10 products', {'msm': 0.0, 'fake': 0.0})
#
# ('10 products we', {'msm': 0.0, 'fake': 0.0})
#
# ('10 questions', {'msm': 0.0, 'fake': 0.0})
#
# ('10 quotes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 quotes to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 rebounds', {'msm': 0.0, 'fake': 0.0})
#
# ('10 rebounds as', {'msm': 0.0, 'fake': 0.0})
#
# ('10 rounds', {'msm': 0.0, 'fake': 0.0})
#
# ('10 rounds per', {'msm': 0.0, 'fake': 0.0})
#
# ('10 seasons', {'msm': 0.0, 'fake': 0.0})
#
# ('10 seasons Adam', {'msm': 0.0, 'fake': 0.0})
#
# ('10 signs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 signs you', {'msm': 0.0, 'fake': 0.0})
#
# ('10 smart', {'msm': 0.0, 'fake': 0.0})
#
# ('10 smart travel', {'msm': 0.0, 'fake': 0.0})
#
# ('10 species', {'msm': 0.0, 'fake': 0.0})
#
# ('10 species of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 states', {'msm': 0.0, 'fake': 0.0})
#
# ('10 states are', {'msm': 0.0, 'fake': 0.0})
#
# ('10 states leading', {'msm': 0.0, 'fake': 0.0})
#
# ('10 states where', {'msm': 0.0, 'fake': 0.0})
#
# ('10 stocks', {'msm': 0.0, 'fake': 0.0})
#
# ('10 stocks most', {'msm': 0.0, 'fake': 0.0})
#
# ('10 superrich', {'msm': 0.0, 'fake': 0.0})
#
# ('10 superrich individuals', {'msm': 0.0, 'fake': 0.0})
#
# ('10 superrich people', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ticket', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ticket and', {'msm': 0.0, 'fake': 0.0})
#
# ('10 times', {'msm': 0.0, 'fake': 0.0})
#
# ('10 times as', {'msm': 0.0, 'fake': 0.0})
#
# ('10 times at', {'msm': 0.0, 'fake': 0.0})
#
# ('10 times more', {'msm': 0.0, 'fake': 0.0})
#
# ('10 tips', {'msm': 0.0, 'fake': 0.0})
#
# ('10 tips from', {'msm': 0.0, 'fake': 0.0})
#
# ('10 tips to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 to 14', {'msm': 0.0, 'fake': 0.0})
#
# ('10 today', {'msm': 0.0, 'fake': 0.0})
#
# ('10 today edition', {'msm': 0.0, 'fake': 0.0})
#
# ('10 toprated', {'msm': 0.0, 'fake': 0.0})
#
# ('10 toprated made', {'msm': 0.0, 'fake': 0.0})
#
# ('10 via', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ways', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ways companies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 wealthiest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 wealthiest people', {'msm': 0.0, 'fake': 0.0})
#
# ('10 worst', {'msm': 0.0, 'fake': 0.0})
#
# ('10 worst foods', {'msm': 0.0, 'fake': 0.0})
#
# ('10 years', {'msm': 0.0, 'fake': 0.0})
#
# ('10 years 65', {'msm': 0.0, 'fake': 0.0})
#
# ('10 years Buffett', {'msm': 0.0, 'fake': 0.0})
#
# ('10 years CNBC', {'msm': 0.0, 'fake': 0.0})

# %%
mi_top_msm = sorted([x for x in mi.items()], key=lambda x: x[1]['msm'], reverse=True)

# %%
print("\n\n".join([str(x) for x in mi_top_msm[0:1000]]))
# Out:
# ('0', {'msm': 0.0, 'fake': 0.0})
#
# ('0 0', {'msm': 0.0, 'fake': 0.0})
#
# ('0 0 trading', {'msm': 0.0, 'fake': 0.0})
#
# ('0 0Apple', {'msm': 0.0, 'fake': 0.0})
#
# ('0 0Apple confirms', {'msm': 0.0, 'fake': 0.0})
#
# ('0 Story', {'msm': 0.0, 'fake': 0.0})
#
# ('0 Story w', {'msm': 0.0, 'fake': 0.0})
#
# ('0 These', {'msm': 0.0, 'fake': 0.0})
#
# ('0 These kids', {'msm': 0.0, 'fake': 0.0})
#
# ('0 about', {'msm': 0.0, 'fake': 0.0})
#
# ('0 about legal', {'msm': 0.0, 'fake': 0.0})
#
# ('0 coverage', {'msm': 0.0, 'fake': 0.0})
#
# ('0 coverage And', {'msm': 0.0, 'fake': 0.0})
#
# ('0 data', {'msm': 0.0, 'fake': 0.0})
#
# ('0 data Net', {'msm': 0.0, 'fake': 0.0})
#
# ('0 dead', {'msm': 0.0, 'fake': 0.0})
#
# ('0 trading', {'msm': 0.0, 'fake': 0.0})
#
# ('0 trading PG', {'msm': 0.0, 'fake': 0.0})
#
# ('000 Venezuela', {'msm': 0.0, 'fake': 0.0})
#
# ('000 dollars', {'msm': 0.0, 'fake': 0.0})
#
# ('000 dollars à', {'msm': 0.0, 'fake': 0.0})
#
# ('000 femmes', {'msm': 0.0, 'fake': 0.0})
#
# ('000 femmes victimes', {'msm': 0.0, 'fake': 0.0})
#
# ('000 filles', {'msm': 0.0, 'fake': 0.0})
#
# ('000 filles en', {'msm': 0.0, 'fake': 0.0})
#
# ('000 more', {'msm': 0.0, 'fake': 0.0})
#
# ('000 more per', {'msm': 0.0, 'fake': 0.0})
#
# ('000 price', {'msm': 0.0, 'fake': 0.0})
#
# ('000 price tag', {'msm': 0.0, 'fake': 0.0})
#
# ('000 via', {'msm': 0.0, 'fake': 0.0})
#
# ('002 Disney', {'msm': 0.0, 'fake': 0.0})
#
# ('002 Disney donates', {'msm': 0.0, 'fake': 0.0})
#
# ('007 Who', {'msm': 0.0, 'fake': 0.0})
#
# ('007 Who upset', {'msm': 0.0, 'fake': 0.0})
#
# ('007aec187ad24158bf46954698ef5cd4', {'msm': 0.0, 'fake': 0.0})
#
# ('007s are', {'msm': 0.0, 'fake': 0.0})
#
# ('007s are warning', {'msm': 0.0, 'fake': 0.0})
#
# ('00b9e3fd4c0e43798911ec29ebafc2c4', {'msm': 0.0, 'fake': 0.0})
#
# ('01 in', {'msm': 0.0, 'fake': 0.0})
#
# ('01 in January', {'msm': 0.0, 'fake': 0.0})
#
# ('010161f6f4b340b9a027d966a7859ebd', {'msm': 0.0, 'fake': 0.0})
#
# ('01152013 Washington', {'msm': 0.0, 'fake': 0.0})
#
# ('01152013 Washington Post', {'msm': 0.0, 'fake': 0.0})
#
# ('01202009 is', {'msm': 0.0, 'fake': 0.0})
#
# ('01202009 is solely', {'msm': 0.0, 'fake': 0.0})
#
# ('01596e4447d84a66beb2f53b9e579908', {'msm': 0.0, 'fake': 0.0})
#
# ('02 pct', {'msm': 0.0, 'fake': 0.0})
#
# ('02 pct mm', {'msm': 0.0, 'fake': 0.0})
#
# ('02 takes', {'msm': 0.0, 'fake': 0.0})
#
# ('02 takes the', {'msm': 0.0, 'fake': 0.0})
#
# ('020818 httpstcoVKED4Yp4g1', {'msm': 0.0, 'fake': 0.0})
#
# ('021818 in', {'msm': 0.0, 'fake': 0.0})
#
# ('021818 in greatawakening', {'msm': 0.0, 'fake': 0.0})
#
# ('022318 WHY', {'msm': 0.0, 'fake': 0.0})
#
# ('022318 WHY would', {'msm': 0.0, 'fake': 0.0})
#
# ('022318 Why', {'msm': 0.0, 'fake': 0.0})
#
# ('022318 Why Would', {'msm': 0.0, 'fake': 0.0})
#
# ('02232018 The', {'msm': 0.0, 'fake': 0.0})
#
# ('02232018 The Second', {'msm': 0.0, 'fake': 0.0})
#
# ('022418 Latest', {'msm': 0.0, 'fake': 0.0})
#
# ('022418 Latest QPosts', {'msm': 0.0, 'fake': 0.0})
#
# ('02Feb18 Josh', {'msm': 0.0, 'fake': 0.0})
#
# ('02Feb18 Josh Campbell', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 07時07分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 07時07分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 11時02分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 11時02分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 12時27分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 12時27分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 15時32分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 15時32分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 16時27分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 16時27分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 17時16分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月26日 17時16分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('02月27日 05時27分', {'msm': 0.0, 'fake': 0.0})
#
# ('02月27日 05時27分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('03168bb00b49403bb8918d726ad5fcd9', {'msm': 0.0, 'fake': 0.0})
#
# ('0331 FRIDAY', {'msm': 0.0, 'fake': 0.0})
#
# ('0331 FRIDAY The', {'msm': 0.0, 'fake': 0.0})
#
# ('04 for', {'msm': 0.0, 'fake': 0.0})
#
# ('04 for the', {'msm': 0.0, 'fake': 0.0})
#
# ('04 pct', {'msm': 0.0, 'fake': 0.0})
#
# ('04 the', {'msm': 0.0, 'fake': 0.0})
#
# ('04 the number', {'msm': 0.0, 'fake': 0.0})
#
# ('0406AM yOgA', {'msm': 0.0, 'fake': 0.0})
#
# ('0406AM yOgA AP', {'msm': 0.0, 'fake': 0.0})
#
# ('041117 Where', {'msm': 0.0, 'fake': 0.0})
#
# ('041117 Where is', {'msm': 0.0, 'fake': 0.0})
#
# ('044713042d2c42b385c1e521cc8c386c', {'msm': 0.0, 'fake': 0.0})
#
# ('05 in', {'msm': 0.0, 'fake': 0.0})
#
# ('05 in January', {'msm': 0.0, 'fake': 0.0})
#
# ('05 punti', {'msm': 0.0, 'fake': 0.0})
#
# ('05 punti circa', {'msm': 0.0, 'fake': 0.0})
#
# ('0500AM Click', {'msm': 0.0, 'fake': 0.0})
#
# ('0500AM Click Here', {'msm': 0.0, 'fake': 0.0})
#
# ('0500AM …', {'msm': 0.0, 'fake': 0.0})
#
# ('0500PM An', {'msm': 0.0, 'fake': 0.0})
#
# ('0500PM An 80s', {'msm': 0.0, 'fake': 0.0})
#
# ('0558a210160e46dd900d8c11ee52a5c4', {'msm': 0.0, 'fake': 0.0})
#
# ('05bp and', {'msm': 0.0, 'fake': 0.0})
#
# ('05bp and 30y', {'msm': 0.0, 'fake': 0.0})
#
# ('05時27分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('05時27分 引用元：Reuters ロイター', {'msm': 0.0, 'fake': 0.0})
#
# ('0625PM Two', {'msm': 0.0, 'fake': 0.0})
#
# ('0625PM Two LAPD', {'msm': 0.0, 'fake': 0.0})
#
# ('0630 1730', {'msm': 0.0, 'fake': 0.0})
#
# ('0630 1730 Feb', {'msm': 0.0, 'fake': 0.0})
#
# ('0640PM California', {'msm': 0.0, 'fake': 0.0})
#
# ('0640PM California Sounds', {'msm': 0.0, 'fake': 0.0})
#
# ('0646 JST', {'msm': 0.0, 'fake': 0.0})
#
# ('0646 JST 米投資会社バークシャー…', {'msm': 0.0, 'fake': 0.0})
#
# ('0710AM North', {'msm': 0.0, 'fake': 0.0})
#
# ('0710AM North Hollywood', {'msm': 0.0, 'fake': 0.0})
#
# ('072018 Sharing', {'msm': 0.0, 'fake': 0.0})
#
# ('072018 Sharing some', {'msm': 0.0, 'fake': 0.0})
#
# ('0735PM With', {'msm': 0.0, 'fake': 0.0})
#
# ('0735PM With a', {'msm': 0.0, 'fake': 0.0})
#
# ('07bp 10y', {'msm': 0.0, 'fake': 0.0})
#
# ('07bp 10y fell', {'msm': 0.0, 'fake': 0.0})
#
# ('07時07分 引用元：Reuters', {'msm': 0.0, 'fake': 0.0})
#
# ('07時07分 引用元：Reuters ロイター', {'msm': 0.0, 'fake': 0.0})
#
# ('08 percent', {'msm': 0.0, 'fake': 0.0})
#
# ('08 percent of', {'msm': 0.0, 'fake': 0.0})
#
# ('0800 am', {'msm': 0.0, 'fake': 0.0})
#
# ('0800 am Abend', {'msm': 0.0, 'fake': 0.0})
#
# ('084fc65ce27c42c9961fad9ca1f8a742', {'msm': 0.0, 'fake': 0.0})
#
# ('085 US', {'msm': 0.0, 'fake': 0.0})
#
# ('085 US Code', {'msm': 0.0, 'fake': 0.0})
#
# ('0911 until', {'msm': 0.0, 'fake': 0.0})
#
# ('0911 until now', {'msm': 0.0, 'fake': 0.0})
#
# ('0927bbea38d140ccb911f8fdea538035', {'msm': 0.0, 'fake': 0.0})
#
# ('0930 Feb', {'msm': 0.0, 'fake': 0.0})
#
# ('0930 Feb 28', {'msm': 0.0, 'fake': 0.0})
#
# ('09494d10e57642d1aa802ab503fae850', {'msm': 0.0, 'fake': 0.0})
#
# ('09c7eba347ac407f8698fb51f26e1123', {'msm': 0.0, 'fake': 0.0})
#
# ('09d7a5e2cda2464dad2ec21c66b2eb2a', {'msm': 0.0, 'fake': 0.0})
#
# ('0Apple confirms', {'msm': 0.0, 'fake': 0.0})
#
# ('0Apple confirms it', {'msm': 0.0, 'fake': 0.0})
#
# ('0B0Z0 ampOR', {'msm': 0.0, 'fake': 0.0})
#
# ('0B0Z0 ampOR HILDABEAST', {'msm': 0.0, 'fake': 0.0})
#
# ('0a32e8a02c6b4c239509f64c599d90ed', {'msm': 0.0, 'fake': 0.0})
#
# ('0b8921c64b0d45e7b3d87dcd832296eb', {'msm': 0.0, 'fake': 0.0})
#
# ('0c25b84b74f340f8a2daa46c628eeb1f', {'msm': 0.0, 'fake': 0.0})
#
# ('0c270a2baddc4ac292f169c87e248989', {'msm': 0.0, 'fake': 0.0})
#
# ('0c322a644bf04c078cdd396b0540e130', {'msm': 0.0, 'fake': 0.0})
#
# ('0e564bcca457428ba95c8e9f12bbccc9', {'msm': 0.0, 'fake': 0.0})
#
# ('0fff6249386645debfddd97e4b50d4f9', {'msm': 0.0, 'fake': 0.0})
#
# ('0io9 8', {'msm': 0.0, 'fake': 0.0})
#
# ('0io9 8 Ill', {'msm': 0.0, 'fake': 0.0})
#
# ('0′s and', {'msm': 0.0, 'fake': 0.0})
#
# ('0′s and 1′s', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2 3', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2 Por', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2017', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2017 at', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2018', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2018 GOP', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2018 theyll', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2019', {'msm': 0.0, 'fake': 0.0})
#
# ('1 2019 And', {'msm': 0.0, 'fake': 0.0})
#
# ('1 81', {'msm': 0.0, 'fake': 0.0})
#
# ('1 81 higher', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Adolph', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Adolph Hitler', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Against', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Against Single', {'msm': 0.0, 'fake': 0.0})
#
# ('1 American', {'msm': 0.0, 'fake': 0.0})
#
# ('1 American Dem', {'msm': 0.0, 'fake': 0.0})
#
# ('1 And', {'msm': 0.0, 'fake': 0.0})
#
# ('1 And now', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Apple', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Apple hands', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Arming', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Arming teachers', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Because', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Because this', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Billion', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Billion From', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Billion at', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Billion in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Bitterness', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Bitterness 0', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Bridgeport', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Bridgeport CT', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Brutal', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Brutal Demand', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Brutal Question', {'msm': 0.0, 'fake': 0.0})
#
# ('1 CORINTHIANS', {'msm': 0.0, 'fake': 0.0})
#
# ('1 CORINTHIANS 13', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Captured', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Captured 82', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Characteristic', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Characteristic Every', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Clueless', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Clueless Don', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Coloca', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Coloca caixa', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Congress', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Congress add', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Create', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Create engaging', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Cure', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Curious', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Curious SEO', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DEPUTY', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DEPUTY NOT', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DJ', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DJ has', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DOJ', {'msm': 0.0, 'fake': 0.0})
#
# ('1 DOJ failed', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Darkest', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Darkest Hour', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Day', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Day 553', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Dead', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Dead 3', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Debbie', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Debbie Wasserman', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Democratic', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Democratic turnout', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Detail', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Detail Blows', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Disturbing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Disturbing Detail', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Dow', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Dow adds', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Down', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Down amp', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Duke', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Duke close', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Embarrassing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Embarrassing Problem', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Episode', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Episode 3', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Final', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Final Post', {'msm': 0.0, 'fake': 0.0})
#
# ('1 GOPTaxScam', {'msm': 0.0, 'fake': 0.0})
#
# ('1 GOPTaxScam TheResistance', {'msm': 0.0, 'fake': 0.0})
#
# ('1 His', {'msm': 0.0, 'fake': 0.0})
#
# ('1 His first', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Holy', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Holy shit', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Hour', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Huge', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Huge Change', {'msm': 0.0, 'fake': 0.0})
#
# ('1 I', {'msm': 0.0, 'fake': 0.0})
#
# ('1 I wish', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Important', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Important Detail', {'msm': 0.0, 'fake': 0.0})
#
# ('1 In', {'msm': 0.0, 'fake': 0.0})
#
# ('1 In 3', {'msm': 0.0, 'fake': 0.0})
#
# ('1 India', {'msm': 0.0, 'fake': 0.0})
#
# ('1 India 2', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Ingraham', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Ingraham The', {'msm': 0.0, 'fake': 0.0})
#
# ('1 It', {'msm': 0.0, 'fake': 0.0})
#
# ('1 It occupied', {'msm': 0.0, 'fake': 0.0})
#
# ('1 It totally', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Kylie', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Kylie Jenner', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Leader', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Leader shows', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Lego', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Lego 2', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Lemon', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Lemon Peel', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Less', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Less Than', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Liter', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Liter of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 March', {'msm': 0.0, 'fake': 0.0})
#
# ('1 March Read', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Mile', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Mile Run', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million Bounty', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million Discarded', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million Immigrants', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million Kids', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million Years', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million he', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million to', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Million via', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Monica', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Monica Crowley', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Month', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Month of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 NRA', {'msm': 0.0, 'fake': 0.0})
#
# ('1 NRA 0', {'msm': 0.0, 'fake': 0.0})
#
# ('1 NRA amp', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Nasty', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Nasty Line', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Neo', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Neo Nazis', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Nokia', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Nokia 7', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Official', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Official Hip', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Okay', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Okay so', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Other', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Other Prison', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Percent', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Philip', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Philip Morris', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Poll', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Poll Ranking', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Priority', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Priority HumanResources', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Problem', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Problem TCOT', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Reason', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Reason You', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Russian', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Russian source', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Sick', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Sick Thing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Simple', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Simple Question', {'msm': 0.0, 'fake': 0.0})
#
# ('1 So', {'msm': 0.0, 'fake': 0.0})
#
# ('1 So why', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Some', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Some news', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Surprising', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Surprising Chart', {'msm': 0.0, 'fake': 0.0})
#
# ('1 TO', {'msm': 0.0, 'fake': 0.0})
#
# ('1 TO A', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Tablespoon', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Tablespoon of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Take', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Take a', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Targeted…Sick', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The Cod', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The GOP', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The Gun', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The Supreme', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The album', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The has', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The man', {'msm': 0.0, 'fake': 0.0})
#
# ('1 The work', {'msm': 0.0, 'fake': 0.0})
#
# ('1 TheWall', {'msm': 0.0, 'fake': 0.0})
#
# ('1 TheWall Outcome', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Thing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Thing From', {'msm': 0.0, 'fake': 0.0})
#
# ('1 This', {'msm': 0.0, 'fake': 0.0})
#
# ('1 This is', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Trillion', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Trillion Dollar', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Tweet', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Tweet via', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Two', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Two huge', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Unfortunately', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Unfortunately here', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Virginia', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Virginia allowed', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Virginia cruises', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Way', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Way To', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Who', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Who is', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Woe', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Woe unto', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Working', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Working with', {'msm': 0.0, 'fake': 0.0})
#
# ('1 You', {'msm': 0.0, 'fake': 0.0})
#
# ('1 You Need', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Your', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Your article', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Yuge', {'msm': 0.0, 'fake': 0.0})
#
# ('1 Yuge Problem', {'msm': 0.0, 'fake': 0.0})
#
# ('1 after', {'msm': 0.0, 'fake': 0.0})
#
# ('1 after screaming', {'msm': 0.0, 'fake': 0.0})
#
# ('1 and', {'msm': 0.0, 'fake': 0.0})
#
# ('1 and 2', {'msm': 0.0, 'fake': 0.0})
#
# ('1 and burying', {'msm': 0.0, 'fake': 0.0})
#
# ('1 and displaces', {'msm': 0.0, 'fake': 0.0})
#
# ('1 and lost', {'msm': 0.0, 'fake': 0.0})
#
# ('1 as', {'msm': 0.0, 'fake': 0.0})
#
# ('1 as part', {'msm': 0.0, 'fake': 0.0})
#
# ('1 attack', {'msm': 0.0, 'fake': 0.0})
#
# ('1 attack amp', {'msm': 0.0, 'fake': 0.0})
#
# ('1 away', {'msm': 0.0, 'fake': 0.0})
#
# ('1 away from', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion RealEstate', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion at', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion but', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion club', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion deficit', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion made', {'msm': 0.0, 'fake': 0.0})
#
# ('1 billion real', {'msm': 0.0, 'fake': 0.0})
#
# ('1 brought', {'msm': 0.0, 'fake': 0.0})
#
# ('1 brought record', {'msm': 0.0, 'fake': 0.0})
#
# ('1 businessman', {'msm': 0.0, 'fake': 0.0})
#
# ('1 businessman doing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 but', {'msm': 0.0, 'fake': 0.0})
#
# ('1 but 4', {'msm': 0.0, 'fake': 0.0})
#
# ('1 but 4fucking', {'msm': 0.0, 'fake': 0.0})
#
# ('1 but the', {'msm': 0.0, 'fake': 0.0})
#
# ('1 by', {'msm': 0.0, 'fake': 0.0})
#
# ('1 by THE', {'msm': 0.0, 'fake': 0.0})
#
# ('1 by spending', {'msm': 0.0, 'fake': 0.0})
#
# ('1 cause', {'msm': 0.0, 'fake': 0.0})
#
# ('1 cause of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 communication', {'msm': 0.0, 'fake': 0.0})
#
# ('1 communication mistake', {'msm': 0.0, 'fake': 0.0})
#
# ('1 day', {'msm': 0.0, 'fake': 0.0})
#
# ('1 day be', {'msm': 0.0, 'fake': 0.0})
#
# ('1 deal', {'msm': 0.0, 'fake': 0.0})
#
# ('1 dealampto', {'msm': 0.0, 'fake': 0.0})
#
# ('1 dealampto keep', {'msm': 0.0, 'fake': 0.0})
#
# ('1 deputy', {'msm': 0.0, 'fake': 0.0})
#
# ('1 deputy was', {'msm': 0.0, 'fake': 0.0})
#
# ('1 died', {'msm': 0.0, 'fake': 0.0})
#
# ('1 died in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 do', {'msm': 0.0, 'fake': 0.0})
#
# ('1 do Santa', {'msm': 0.0, 'fake': 0.0})
#
# ('1 do VASFLAPALSANIND', {'msm': 0.0, 'fake': 0.0})
#
# ('1 do Vasco', {'msm': 0.0, 'fake': 0.0})
#
# ('1 dr', {'msm': 0.0, 'fake': 0.0})
#
# ('1 dr 27', {'msm': 0.0, 'fake': 0.0})
#
# ('1 extension', {'msm': 0.0, 'fake': 0.0})
#
# ('1 extension de', {'msm': 0.0, 'fake': 0.0})
#
# ('1 finale', {'msm': 0.0, 'fake': 0.0})
#
# ('1 finale And', {'msm': 0.0, 'fake': 0.0})
#
# ('1 for', {'msm': 0.0, 'fake': 0.0})
#
# ('1 for womenintech', {'msm': 0.0, 'fake': 0.0})
#
# ('1 guard', {'msm': 0.0, 'fake': 0.0})
#
# ('1 guard injured', {'msm': 0.0, 'fake': 0.0})
#
# ('1 her', {'msm': 0.0, 'fake': 0.0})
#
# ('1 her husband', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hired', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hired criminals', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hombre', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hombre 1', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hour', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hour Free', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hour they', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hurt', {'msm': 0.0, 'fake': 0.0})
#
# ('1 hurt News', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in 10', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in 4', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in 5', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in AP', {'msm': 0.0, 'fake': 0.0})
#
# ('1 in diplomatic', {'msm': 0.0, 'fake': 0.0})
#
# ('1 incredibly', {'msm': 0.0, 'fake': 0.0})
#
# ('1 incredibly stupid', {'msm': 0.0, 'fake': 0.0})
#
# ('1 injured', {'msm': 0.0, 'fake': 0.0})
#
# ('1 injured in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 kid', {'msm': 0.0, 'fake': 0.0})
#
# ('1 kid and', {'msm': 0.0, 'fake': 0.0})
#
# ('1 killed', {'msm': 0.0, 'fake': 0.0})
#
# ('1 killed others', {'msm': 0.0, 'fake': 0.0})
#
# ('1 legislative', {'msm': 0.0, 'fake': 0.0})
#
# ('1 legislative act', {'msm': 0.0, 'fake': 0.0})
#
# ('1 manchild', {'msm': 0.0, 'fake': 0.0})
#
# ('1 manchild Call', {'msm': 0.0, 'fake': 0.0})
#
# ('1 mil', {'msm': 0.0, 'fake': 0.0})
#
# ('1 mil from', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million Americans', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million CSGO', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million budget', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million painting', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million refugees', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million wager', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million wholly', {'msm': 0.0, 'fake': 0.0})
#
# ('1 million worth', {'msm': 0.0, 'fake': 0.0})
#
# ('1 mth', {'msm': 0.0, 'fake': 0.0})
#
# ('1 mth after', {'msm': 0.0, 'fake': 0.0})
#
# ('1 number', {'msm': 0.0, 'fake': 0.0})
#
# ('1 number threatens', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of 4', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of 8', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of his', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of many', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of the', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of these', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of those', {'msm': 0.0, 'fake': 0.0})
#
# ('1 of world’s', {'msm': 0.0, 'fake': 0.0})
#
# ('1 on', {'msm': 0.0, 'fake': 0.0})
#
# ('1 on Top', {'msm': 0.0, 'fake': 0.0})
#
# ('1 out', {'msm': 0.0, 'fake': 0.0})
#
# ('1 out of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 pacarana', {'msm': 0.0, 'fake': 0.0})
#
# ('1 pacarana espécie', {'msm': 0.0, 'fake': 0.0})
#
# ('1 per', {'msm': 0.0, 'fake': 0.0})
#
# ('1 per 26', {'msm': 0.0, 'fake': 0.0})
#
# ('1 percent', {'msm': 0.0, 'fake': 0.0})
#
# ('1 percent of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 playoffs', {'msm': 0.0, 'fake': 0.0})
#
# ('1 position', {'msm': 0.0, 'fake': 0.0})
#
# ('1 position in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 president', {'msm': 0.0, 'fake': 0.0})
#
# ('1 president in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 problem', {'msm': 0.0, 'fake': 0.0})
#
# ('1 problem on', {'msm': 0.0, 'fake': 0.0})
#
# ('1 prolife', {'msm': 0.0, 'fake': 0.0})
#
# ('1 prolife state', {'msm': 0.0, 'fake': 0.0})
#
# ('1 rape', {'msm': 0.0, 'fake': 0.0})
#
# ('1 rape accusation', {'msm': 0.0, 'fake': 0.0})
#
# ('1 restaurant', {'msm': 0.0, 'fake': 0.0})
#
# ('1 restaurant in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 scandal', {'msm': 0.0, 'fake': 0.0})
#
# ('1 scandal being', {'msm': 0.0, 'fake': 0.0})
#
# ('1 school', {'msm': 0.0, 'fake': 0.0})
#
# ('1 school I', {'msm': 0.0, 'fake': 0.0})
#
# ('1 school Schools', {'msm': 0.0, 'fake': 0.0})
#
# ('1 schoolSchools', {'msm': 0.0, 'fake': 0.0})
#
# ('1 schoolSchools YOU', {'msm': 0.0, 'fake': 0.0})
#
# ('1 seed', {'msm': 0.0, 'fake': 0.0})
#
# ('1 seed status', {'msm': 0.0, 'fake': 0.0})
#
# ('1 shred', {'msm': 0.0, 'fake': 0.0})
#
# ('1 shred of', {'msm': 0.0, 'fake': 0.0})
#
# ('1 skill', {'msm': 0.0, 'fake': 0.0})
#
# ('1 skill he', {'msm': 0.0, 'fake': 0.0})
#
# ('1 spot', {'msm': 0.0, 'fake': 0.0})
#
# ('1 spot in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 step', {'msm': 0.0, 'fake': 0.0})
#
# ('1 step forward', {'msm': 0.0, 'fake': 0.0})
#
# ('1 stone”', {'msm': 0.0, 'fake': 0.0})
#
# ('1 story', {'msm': 0.0, 'fake': 0.0})
#
# ('1 story today', {'msm': 0.0, 'fake': 0.0})
#
# ('1 stupid', {'msm': 0.0, 'fake': 0.0})
#
# ('1 stupid or', {'msm': 0.0, 'fake': 0.0})
#
# ('1 the', {'msm': 0.0, 'fake': 0.0})
#
# ('1 the IAEA', {'msm': 0.0, 'fake': 0.0})
#
# ('1 thing', {'msm': 0.0, 'fake': 0.0})
#
# ('1 thing I', {'msm': 0.0, 'fake': 0.0})
#
# ('1 to', {'msm': 0.0, 'fake': 0.0})
#
# ('1 to ensure', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trauma', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trauma hospital', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trauma hospitals', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion amp', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion dollar', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion mark', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion market', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion short', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion sovereign', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion this', {'msm': 0.0, 'fake': 0.0})
#
# ('1 trillion valuation', {'msm': 0.0, 'fake': 0.0})
#
# ('1 use', {'msm': 0.0, 'fake': 0.0})
#
# ('1 use their', {'msm': 0.0, 'fake': 0.0})
#
# ('1 vaccines', {'msm': 0.0, 'fake': 0.0})
#
# ('1 vaccines dont', {'msm': 0.0, 'fake': 0.0})
#
# ('1 valeur', {'msm': 0.0, 'fake': 0.0})
#
# ('1 valeur de', {'msm': 0.0, 'fake': 0.0})
#
# ('1 very', {'msm': 0.0, 'fake': 0.0})
#
# ('1 very big', {'msm': 0.0, 'fake': 0.0})
#
# ('1 week', {'msm': 0.0, 'fake': 0.0})
#
# ('1 week old', {'msm': 0.0, 'fake': 0.0})
#
# ('1 week they’re', {'msm': 0.0, 'fake': 0.0})
#
# ('1 why', {'msm': 0.0, 'fake': 0.0})
#
# ('1 why we', {'msm': 0.0, 'fake': 0.0})
#
# ('1 with', {'msm': 0.0, 'fake': 0.0})
#
# ('1 with Dr', {'msm': 0.0, 'fake': 0.0})
#
# ('1 with Duke', {'msm': 0.0, 'fake': 0.0})
#
# ('1 wk', {'msm': 0.0, 'fake': 0.0})
#
# ('1 wk earlier', {'msm': 0.0, 'fake': 0.0})
#
# ('1 would', {'msm': 0.0, 'fake': 0.0})
#
# ('1 would benefit', {'msm': 0.0, 'fake': 0.0})
#
# ('1 wounded', {'msm': 0.0, 'fake': 0.0})
#
# ('1 wounded in', {'msm': 0.0, 'fake': 0.0})
#
# ('1 y', {'msm': 0.0, 'fake': 0.0})
#
# ('1 y 2', {'msm': 0.0, 'fake': 0.0})
#
# ('1 year', {'msm': 0.0, 'fake': 0.0})
#
# ('1 year Obama’s', {'msm': 0.0, 'fake': 0.0})
#
# ('1 year since', {'msm': 0.0, 'fake': 0.0})
#
# ('1 you', {'msm': 0.0, 'fake': 0.0})
#
# ('1 you need', {'msm': 0.0, 'fake': 0.0})
#
# ('1 yr', {'msm': 0.0, 'fake': 0.0})
#
# ('1 yr old', {'msm': 0.0, 'fake': 0.0})
#
# ('1 –', {'msm': 0.0, 'fake': 0.0})
#
# ('1 – 3', {'msm': 0.0, 'fake': 0.0})
#
# ('1 – If', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2013by', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2013by Gunny', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2016', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2016 Obama', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2018', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2018 God', {'msm': 0.0, 'fake': 0.0})
#
# ('10 2018 Moscow', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Amazon', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Amazon deals', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Americans', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Americans killed', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Americans may', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Americans oppose', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Ancient', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Ancient Artifacts', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Auguis', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Auguis sa', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Books', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Environment', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Films', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Online', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Best Pieces', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Billion', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Billion Files', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Breakthrough', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Breakthrough Technologies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Brutally', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Brutally Hilarious', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Budgeting', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Budgeting Tips', {'msm': 0.0, 'fake': 0.0})
#
# ('10 COOLEST', {'msm': 0.0, 'fake': 0.0})
#
# ('10 COOLEST CITIES', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Cities', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Cities For', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Comics', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Comics About', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Comics That', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Common', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Common American', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Common Headache', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Common Link', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Coolest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Coolest Cities', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Customer', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Customer Experience', {'msm': 0.0, 'fake': 0.0})
#
# ('10 DAYS', {'msm': 0.0, 'fake': 0.0})
#
# ('10 DAYS Is', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Days', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Days via', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Deadly', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Deadly Chemicals', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Delicious', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Delicious Ideas', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Dos', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Dos And', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Easy', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Easy Habits', {'msm': 0.0, 'fake': 0.0})
#
# ('10 February', {'msm': 0.0, 'fake': 0.0})
#
# ('10 February 26', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Flags', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Flags AI', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Foods', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Forbes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Forbes 2018', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Global', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Global Beauty', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Great', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Great Quotes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Greatest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Greatest Moments', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Happiest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Happiest Companies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Health', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Health Problems', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Herbs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Herbs and', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hilarious', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hilarious Pregnancy', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hot', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hot AI', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hot Data', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Hot DataSecurity', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Huge', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Huge Doggos', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Immigration', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Immigration Bill', {'msm': 0.0, 'fake': 0.0})
#
# ('10 In', {'msm': 0.0, 'fake': 0.0})
#
# ('10 In This', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Journalism', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Journalism Brands', {'msm': 0.0, 'fake': 0.0})
#
# ('10 June', {'msm': 0.0, 'fake': 0.0})
#
# ('10 June 14th', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Killed', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Killed in', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Live', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Live updates', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Million', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Million Acres', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Million Africans', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Million Beverly', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Million of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Minutes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Minutes 12', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Mistakes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Mistakes Job', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Months', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Months Gluing', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Most', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Most Powerful', {'msm': 0.0, 'fake': 0.0})
#
# ('10 NBA', {'msm': 0.0, 'fake': 0.0})
#
# ('10 NBA general', {'msm': 0.0, 'fake': 0.0})
#
# ('10 National', {'msm': 0.0, 'fake': 0.0})
#
# ('10 National Parks', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Of The', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Of amp039RuPaulamp039s', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Olympic', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Olympic Games', {'msm': 0.0, 'fake': 0.0})
#
# ('10 PM', {'msm': 0.0, 'fake': 0.0})
#
# ('10 PM EST', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Pathogens', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Pathogens Of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Pathogens of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 People', {'msm': 0.0, 'fake': 0.0})
#
# ('10 People Confessed', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Possible', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Possible Causes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Powerful', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Powerful Herbs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Predictions', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Predictions For', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Pro', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Proven', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Proven Ways', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Reasons', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Reasons Why', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Reasons You', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Rohingya', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Rohingya men', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Rounds', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Rounds with', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Russians', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Russians who', {'msm': 0.0, 'fake': 0.0})
#
# ('10 San', {'msm': 0.0, 'fake': 0.0})
#
# ('10 San Bernadino', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Signs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Signs When', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Signs You', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Signs You’re', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Small', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Small Things', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Strategic', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Strategic CIO', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Strategic Insights', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Strongest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Strongest Markets', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Surprising', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Surprising AF', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Tablet', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Tablet Hides', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Tech', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Tech Firms', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things About', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things I', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things Millennials', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things That', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things You', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things Youre', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Things to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Times', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Times More', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Times People', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Times Women', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Trends', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Trends For', {'msm': 0.0, 'fake': 0.0})
#
# ('10 UCLA', {'msm': 0.0, 'fake': 0.0})
#
# ('10 UCLA women', {'msm': 0.0, 'fake': 0.0})
#
# ('10 UCLA…', {'msm': 0.0, 'fake': 0.0})
#
# ('10 US', {'msm': 0.0, 'fake': 0.0})
#
# ('10 US Terroirs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 US wineries', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Vehicles', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Vehicles for', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Vitamin', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Vitamin K', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Warning', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Warning Signs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Ways', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Ways Machine', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Ways MachineLearning', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Worst', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Worst Colleges', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Years', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Years Conservative', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Years In', {'msm': 0.0, 'fake': 0.0})
#
# ('10 Years via', {'msm': 0.0, 'fake': 0.0})
#
# ('10 a', {'msm': 0.0, 'fake': 0.0})
#
# ('10 a Day', {'msm': 0.0, 'fake': 0.0})
#
# ('10 after', {'msm': 0.0, 'fake': 0.0})
#
# ('10 after Robin', {'msm': 0.0, 'fake': 0.0})
#
# ('10 am', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ans', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ans après', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ans l', {'msm': 0.0, 'fake': 0.0})
#
# ('10 arrested', {'msm': 0.0, 'fake': 0.0})
#
# ('10 arrested a', {'msm': 0.0, 'fake': 0.0})
#
# ('10 articles', {'msm': 0.0, 'fake': 0.0})
#
# ('10 articles a', {'msm': 0.0, 'fake': 0.0})
#
# ('10 at', {'msm': 0.0, 'fake': 0.0})
#
# ('10 at Veterans', {'msm': 0.0, 'fake': 0.0})
#
# ('10 at the', {'msm': 0.0, 'fake': 0.0})
#
# ('10 available', {'msm': 0.0, 'fake': 0.0})
#
# ('10 available players', {'msm': 0.0, 'fake': 0.0})
#
# ('10 azioni', {'msm': 0.0, 'fake': 0.0})
#
# ('10 azioni da', {'msm': 0.0, 'fake': 0.0})
#
# ('10 años', {'msm': 0.0, 'fake': 0.0})
#
# ('10 años de', {'msm': 0.0, 'fake': 0.0})
#
# ('10 bachelors', {'msm': 0.0, 'fake': 0.0})
#
# ('10 bachelors on', {'msm': 0.0, 'fake': 0.0})
#
# ('10 believe', {'msm': 0.0, 'fake': 0.0})
#
# ('10 believe Russia', {'msm': 0.0, 'fake': 0.0})
#
# ('10 best', {'msm': 0.0, 'fake': 0.0})
#
# ('10 best encore', {'msm': 0.0, 'fake': 0.0})
#
# ('10 best foods', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion Files', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion files', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion has', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion private', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billion to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billionpound', {'msm': 0.0, 'fake': 0.0})
#
# ('10 billionpound Brexit', {'msm': 0.0, 'fake': 0.0})
#
# ('10 blacks', {'msm': 0.0, 'fake': 0.0})
#
# ('10 blacks are', {'msm': 0.0, 'fake': 0.0})
#
# ('10 breakthrough', {'msm': 0.0, 'fake': 0.0})
#
# ('10 breakthrough technologies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cases', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cases of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cases reported', {'msm': 0.0, 'fake': 0.0})
#
# ('10 categories', {'msm': 0.0, 'fake': 0.0})
#
# ('10 categories for', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cities', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cities for', {'msm': 0.0, 'fake': 0.0})
#
# ('10 college', {'msm': 0.0, 'fake': 0.0})
#
# ('10 college admissions', {'msm': 0.0, 'fake': 0.0})
#
# ('10 compact', {'msm': 0.0, 'fake': 0.0})
#
# ('10 compact cameras', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cruise', {'msm': 0.0, 'fake': 0.0})
#
# ('10 cruise ships', {'msm': 0.0, 'fake': 0.0})
#
# ('10 curiosidades', {'msm': 0.0, 'fake': 0.0})
#
# ('10 curiosidades sobre', {'msm': 0.0, 'fake': 0.0})
#
# ('10 days', {'msm': 0.0, 'fake': 0.0})
#
# ('10 days Only', {'msm': 0.0, 'fake': 0.0})
#
# ('10 days after', {'msm': 0.0, 'fake': 0.0})
#
# ('10 days ago', {'msm': 0.0, 'fake': 0.0})
#
# ('10 days of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 de', {'msm': 0.0, 'fake': 0.0})
#
# ('10 de 10', {'msm': 0.0, 'fake': 0.0})
#
# ('10 de febrero', {'msm': 0.0, 'fake': 0.0})
#
# ('10 de métricas', {'msm': 0.0, 'fake': 0.0})
#
# ('10 deepening', {'msm': 0.0, 'fake': 0.0})
#
# ('10 deepening inequality', {'msm': 0.0, 'fake': 0.0})
#
# ('10 del', {'msm': 0.0, 'fake': 0.0})
#
# ('10 del TLC', {'msm': 0.0, 'fake': 0.0})
#
# ('10 du', {'msm': 0.0, 'fake': 0.0})
#
# ('10 du capital', {'msm': 0.0, 'fake': 0.0})
#
# ('10 earthquakes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 earthquakes a', {'msm': 0.0, 'fake': 0.0})
#
# ('10 economies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 economies have', {'msm': 0.0, 'fake': 0.0})
#
# ('10 edtech', {'msm': 0.0, 'fake': 0.0})
#
# ('10 edtech startups', {'msm': 0.0, 'fake': 0.0})
#
# ('10 favor', {'msm': 0.0, 'fake': 0.0})
#
# ('10 favor tighter', {'msm': 0.0, 'fake': 0.0})
#
# ('10 free', {'msm': 0.0, 'fake': 0.0})
#
# ('10 free fullpage', {'msm': 0.0, 'fake': 0.0})
#
# ('10 fresh', {'msm': 0.0, 'fake': 0.0})
#
# ('10 fresh fashion', {'msm': 0.0, 'fake': 0.0})
#
# ('10 global', {'msm': 0.0, 'fake': 0.0})
#
# ('10 global CEOs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 gol', {'msm': 0.0, 'fake': 0.0})
#
# ('10 gol Artilheiros', {'msm': 0.0, 'fake': 0.0})
#
# ('10 governors', {'msm': 0.0, 'fake': 0.0})
#
# ('10 governors shaping', {'msm': 0.0, 'fake': 0.0})
#
# ('10 happiest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 happiest and', {'msm': 0.0, 'fake': 0.0})
#
# ('10 hardestworking', {'msm': 0.0, 'fake': 0.0})
#
# ('10 hardestworking cities', {'msm': 0.0, 'fake': 0.0})
#
# ('10 hits', {'msm': 0.0, 'fake': 0.0})
#
# ('10 hits than', {'msm': 0.0, 'fake': 0.0})
#
# ('10 important', {'msm': 0.0, 'fake': 0.0})
#
# ('10 important questions', {'msm': 0.0, 'fake': 0.0})
#
# ('10 in', {'msm': 0.0, 'fake': 0.0})
#
# ('10 in 10', {'msm': 0.0, 'fake': 0.0})
#
# ('10 in Innovation', {'msm': 0.0, 'fake': 0.0})
#
# ('10 increase', {'msm': 0.0, 'fake': 0.0})
#
# ('10 increase in', {'msm': 0.0, 'fake': 0.0})
#
# ('10 incredibly', {'msm': 0.0, 'fake': 0.0})
#
# ('10 incredibly useful', {'msm': 0.0, 'fake': 0.0})
#
# ('10 lifehacking', {'msm': 0.0, 'fake': 0.0})
#
# ('10 lifehacking books', {'msm': 0.0, 'fake': 0.0})
#
# ('10 list', {'msm': 0.0, 'fake': 0.0})
#
# ('10 lugares', {'msm': 0.0, 'fake': 0.0})
#
# ('10 lugares clave', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million and', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million dogs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million euros', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million in', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million libel', {'msm': 0.0, 'fake': 0.0})
#
# ('10 million to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 minutes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 minutes with', {'msm': 0.0, 'fake': 0.0})
#
# ('10 minutes you', {'msm': 0.0, 'fake': 0.0})
#
# ('10 more', {'msm': 0.0, 'fake': 0.0})
#
# ('10 more killed', {'msm': 0.0, 'fake': 0.0})
#
# ('10 most', {'msm': 0.0, 'fake': 0.0})
#
# ('10 most filling', {'msm': 0.0, 'fake': 0.0})
#
# ('10 most memorable', {'msm': 0.0, 'fake': 0.0})
#
# ('10 most popular', {'msm': 0.0, 'fake': 0.0})
#
# ('10 most valuable', {'msm': 0.0, 'fake': 0.0})
#
# ('10 new', {'msm': 0.0, 'fake': 0.0})
#
# ('10 new books', {'msm': 0.0, 'fake': 0.0})
#
# ('10 o', {'msm': 0.0, 'fake': 0.0})
#
# ('10 o 20', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of Daimler', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of her', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of our', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of population', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of the', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of them', {'msm': 0.0, 'fake': 0.0})
#
# ('10 of your', {'msm': 0.0, 'fake': 0.0})
#
# ('10 on', {'msm': 0.0, 'fake': 0.0})
#
# ('10 on a', {'msm': 0.0, 'fake': 0.0})
#
# ('10 or', {'msm': 0.0, 'fake': 0.0})
#
# ('10 or 15', {'msm': 0.0, 'fake': 0.0})
#
# ('10 or 20', {'msm': 0.0, 'fake': 0.0})
#
# ('10 pages', {'msm': 0.0, 'fake': 0.0})
#
# ('10 pages And', {'msm': 0.0, 'fake': 0.0})
#
# ('10 pages to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 people', {'msm': 0.0, 'fake': 0.0})
#
# ('10 people gave', {'msm': 0.0, 'fake': 0.0})
#
# ('10 people were', {'msm': 0.0, 'fake': 0.0})
#
# ('10 percent', {'msm': 0.0, 'fake': 0.0})
#
# ('10 percent of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 percent stake', {'msm': 0.0, 'fake': 0.0})
#
# ('10 platos', {'msm': 0.0, 'fake': 0.0})
#
# ('10 platos que', {'msm': 0.0, 'fake': 0.0})
#
# ('10 player', {'msm': 0.0, 'fake': 0.0})
#
# ('10 player Article', {'msm': 0.0, 'fake': 0.0})
#
# ('10 players', {'msm': 0.0, 'fake': 0.0})
#
# ('10 players who', {'msm': 0.0, 'fake': 0.0})
#
# ('10 pm', {'msm': 0.0, 'fake': 0.0})
#
# ('10 pm ET', {'msm': 0.0, 'fake': 0.0})
#
# ('10 policies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 policies Iran', {'msm': 0.0, 'fake': 0.0})
#
# ('10 preguntas', {'msm': 0.0, 'fake': 0.0})
#
# ('10 preguntas correctamente', {'msm': 0.0, 'fake': 0.0})
#
# ('10 primeros', {'msm': 0.0, 'fake': 0.0})
#
# ('10 products', {'msm': 0.0, 'fake': 0.0})
#
# ('10 products we', {'msm': 0.0, 'fake': 0.0})
#
# ('10 questions', {'msm': 0.0, 'fake': 0.0})
#
# ('10 quotes', {'msm': 0.0, 'fake': 0.0})
#
# ('10 quotes to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 rebounds', {'msm': 0.0, 'fake': 0.0})
#
# ('10 rebounds as', {'msm': 0.0, 'fake': 0.0})
#
# ('10 rounds', {'msm': 0.0, 'fake': 0.0})
#
# ('10 rounds per', {'msm': 0.0, 'fake': 0.0})
#
# ('10 seasons', {'msm': 0.0, 'fake': 0.0})
#
# ('10 seasons Adam', {'msm': 0.0, 'fake': 0.0})
#
# ('10 signs', {'msm': 0.0, 'fake': 0.0})
#
# ('10 signs you', {'msm': 0.0, 'fake': 0.0})
#
# ('10 smart', {'msm': 0.0, 'fake': 0.0})
#
# ('10 smart travel', {'msm': 0.0, 'fake': 0.0})
#
# ('10 species', {'msm': 0.0, 'fake': 0.0})
#
# ('10 species of', {'msm': 0.0, 'fake': 0.0})
#
# ('10 states', {'msm': 0.0, 'fake': 0.0})
#
# ('10 states are', {'msm': 0.0, 'fake': 0.0})
#
# ('10 states leading', {'msm': 0.0, 'fake': 0.0})
#
# ('10 states where', {'msm': 0.0, 'fake': 0.0})
#
# ('10 stocks', {'msm': 0.0, 'fake': 0.0})
#
# ('10 stocks most', {'msm': 0.0, 'fake': 0.0})
#
# ('10 superrich', {'msm': 0.0, 'fake': 0.0})
#
# ('10 superrich individuals', {'msm': 0.0, 'fake': 0.0})
#
# ('10 superrich people', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ticket', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ticket and', {'msm': 0.0, 'fake': 0.0})
#
# ('10 times', {'msm': 0.0, 'fake': 0.0})
#
# ('10 times as', {'msm': 0.0, 'fake': 0.0})
#
# ('10 times at', {'msm': 0.0, 'fake': 0.0})
#
# ('10 times more', {'msm': 0.0, 'fake': 0.0})
#
# ('10 tips', {'msm': 0.0, 'fake': 0.0})
#
# ('10 tips from', {'msm': 0.0, 'fake': 0.0})
#
# ('10 tips to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 to', {'msm': 0.0, 'fake': 0.0})
#
# ('10 to 14', {'msm': 0.0, 'fake': 0.0})
#
# ('10 today', {'msm': 0.0, 'fake': 0.0})
#
# ('10 today edition', {'msm': 0.0, 'fake': 0.0})
#
# ('10 toprated', {'msm': 0.0, 'fake': 0.0})
#
# ('10 toprated made', {'msm': 0.0, 'fake': 0.0})
#
# ('10 via', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ways', {'msm': 0.0, 'fake': 0.0})
#
# ('10 ways companies', {'msm': 0.0, 'fake': 0.0})
#
# ('10 wealthiest', {'msm': 0.0, 'fake': 0.0})
#
# ('10 wealthiest people', {'msm': 0.0, 'fake': 0.0})
#
# ('10 worst', {'msm': 0.0, 'fake': 0.0})
#
# ('10 worst foods', {'msm': 0.0, 'fake': 0.0})
#
# ('10 years', {'msm': 0.0, 'fake': 0.0})
#
# ('10 years 65', {'msm': 0.0, 'fake': 0.0})
#
# ('10 years Buffett', {'msm': 0.0, 'fake': 0.0})
#
# ('10 years CNBC', {'msm': 0.0, 'fake': 0.0})

# %%
from sklearn import linear_model
m = linear_model.LogisticRegression()
